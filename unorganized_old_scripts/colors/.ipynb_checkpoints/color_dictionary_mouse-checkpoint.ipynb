# %%
from mouse_colors import mouse_dictionary
# Out:
# INFO:temp_funcs:Read file in as a pandas dataframe

# %%
cluster_dict = mouse_dictionary('c')
cluster_dict
# Out:
# OrderedDict([('100_Sst', '#B36B0C'),
#              ('101_Sst', '#F2B003'),
#              ('102_Sst*', '#CC7E09'),
#              ('103_Sst*', '#FFB800'),
#              ('105_Pvalb', '#8C2734'),
#              ('106_Pvalb', '#CC322E'),
#              ('107_Pvalb', '#99282D'),
#              ('108_Pvalb', '#D93031'),
#              ('109_Pvalb', '#B92C3E'),
#              ('10_Lamp5', '#E6808B'),
#              ('110_Pvalb', '#FF3031'),
#              ('111_Pvalb', '#CC2D41'),
#              ('112_Pvalb', '#B9342C'),
#              ('113_Pvalb', '#8C2A27'),
#              ('114_Pvalb', '#D92D43'),
#              ('115_Pvalb', '#EC2D46'),
#              ('116_Pvalb', '#A62A2F'),
#              ('117_Pvalb', '#EC3031'),
#              ('119_Pvalb Vipr2', '#FF2D4E'),
#              ('11_Lamp5', '#A6666F'),
#              ('120_DG', '#2E3493'),
#              ('121_DG', '#3749D3'),
#              ('122_DG', '#304AA0'),
#              ('124_DG', '#3447B9'),
# ...

# %%
len(cluster_dict)
# Out:
# 306

# %%
seurat_dict = mouse_dictionary('s')
seurat_dict
# Out:
# OrderedDict([('101_Sst', '#CC423D'),
#              ('102_Sst*', '#991F17'),
#              ('103_Sst*', '#FF1800'),
#              ('105_Pvalb', '#CC6A5C'),
#              ('106_Pvalb', '#993F2E'),
#              ('107_Pvalb', '#FF4F26'),
#              ('108_Pvalb', '#CC2D00'),
#              ('109_Pvalb', '#995A45'),
#              ('10_Lamp5', '#FF7373'),
#              ('110_Pvalb', '#CC551F'),
#              ('111_Pvalb', '#993500'),
#              ('112_Pvalb', '#FFA773'),
#              ('113_Pvalb', '#CC773D'),
#              ('114_Pvalb', '#995017'),
#              ('115_Pvalb', '#FF7800'),
#              ('116_Pvalb', '#CC945C'),
#              ('117_Pvalb', '#99672E'),
#              ('119_Pvalb Vipr2', '#FFA026'),
#              ('11_Lamp5', '#FF7F4D'),
#              ('124_DG', '#997945'),
#              ('125_DG', '#FFC24D'),
#              ('127_L2/3 IT PPP', '#CC961F'),
#              ('12_Lamp5', '#CC7900'),
#              ('131_L2 IT RSPv', '#FFDC73'),
# ...

# %%
len(seurat_dict)
# Out:
# 192

# %%
topLeaf_dict = mouse_dictionary('t')
topLeaf_dict
# Out:
# OrderedDict([('100_Sst', '#991C17'),
#              ('101_Sst', '#FF0F00'),
#              ('102_Sst*', '#CC645C'),
#              ('103_Sst*', '#99382E'),
#              ('105_Pvalb', '#FF3F26'),
#              ('106_Pvalb', '#CC1B00'),
#              ('107_Pvalb', '#995245'),
#              ('108_Pvalb', '#FF6B4D'),
#              ('109_Pvalb', '#CC401F'),
#              ('10_Lamp5', '#CC403D'),
#              ('110_Pvalb', '#FF9373'),
#              ('111_Pvalb', '#CC613D'),
#              ('112_Pvalb', '#993A17'),
#              ('113_Pvalb', '#FF4900'),
#              ('114_Pvalb', '#CC7E5C'),
#              ('115_Pvalb', '#99512E'),
#              ('116_Pvalb', '#FF7126'),
#              ('117_Pvalb', '#CC4A00'),
#              ('119_Pvalb Vipr2', '#996545'),
#              ('11_Lamp5', '#992000'),
#              ('120_DG', '#CC671F'),
#              ('121_DG', '#994300'),
#              ('122_DG', '#FFB373'),
#              ('124_DG', '#CC813D'),
# ...

# %%
len(topLeaf_dict)
# Out:
# 315
