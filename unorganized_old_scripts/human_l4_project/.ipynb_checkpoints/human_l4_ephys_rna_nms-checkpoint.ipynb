# %% [markdown]
# # RNA/NMS Groups Counts

# %% [markdown]
# ##### Imports

# %%
import pandas as pd
import numpy as np
import csv
import logging
import os
from scipy.stats import pearsonr

from temp_funcs import read_file, merge_dataframes, drop_cols, drop_nans, filter_date_range, \
filter_df, create_container_col, create_cond_df, create_container_df

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

sns.set(context = "notebook", style = "ticks", font="verdana", font_scale = 1.9)
pd.set_option("display.max_colwidth",150) #Expands the number of characters shown in the columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ##### Functions

# %%
def rna_nms_table(df):
    npass = filter_df(df, "NMS Pass/Fail", "Pass")
    nfail = filter_df(df, "NMS Pass/Fail", "Fail")
    rpass = filter_df(df, "RNA Amp Pass/Fail", "Pass")
    rfail = filter_df(df, "RNA Amp Pass/Fail", "Fail")

    rfail_nfail = filter_df(rfail, "NMS Pass/Fail", "Fail")
    rfail_npass = filter_df(rfail, "NMS Pass/Fail", "Pass")
    rpass_nfail = filter_df(rpass, "NMS Pass/Fail", "Fail")
    rpass_npass = filter_df(rpass, "NMS Pass/Fail", "Pass")

    rfail_nfail["Group"] = "RNA Amp Fail/NMS Fail"
    rfail_npass["Group"] = "RNA Amp Fail/NMS Pass"
    rpass_nfail["Group"] = "RNA Amp Pass/NMS Fail"
    rpass_npass["Group"] = "RNA Amp Pass/NMS Pass"
    
    df = pd.concat([rfail_nfail, rfail_npass, rpass_nfail, rpass_npass])
    df["group_count"] = df.groupby(["Group", "Tree_call"])["Tree_call"].transform("count")
    df["group_total"] = df.groupby("Group")["Tree_call"].transform("count")
    df["proportion"] = df["group_count"] / df["group_total"] * 100
    return df

# %%
def create_proportion_table(df, index_col, val_col):
    df["group_count"] = df.groupby([index_col, val_col])[val_col].transform("count")
    df["group_total"] = df.groupby(index_col)[val_col].transform("count")
    df["proportion"] = df["group_count"] / df["group_total"] * 100
    return df

# %% [markdown]
# #### Paths/Fields

# %%
path = "C:/Users/kumar/Documents/Github/analysis_projects/"
csv_path = os.path.join(path, "csv/")
excel_path = os.path.join(path, "excel/")
plot_path = os.path.join(path, "plot/hl4_plot/")

path_shiny_human = os.path.join(csv_path, "current_shiny_human.csv")
path_ephys = os.path.join(csv_path, "ephys_hIVSCC_MET.csv")

# %%
ephys_list = ["Vm(mV)", "Input Resistance(MΩ)", "Sag Fraction", "τ(s)", "LS AP up/downstoke", "Latency", "F-I Curve"]
region_list = ["FCx", "OCx", "PCx", "TCx"]

fields_ephys = ["name", "vrest", "ri", "sag", "tau",
                "upstroke_downstroke_ratio_long_square", "latency", "f_i_curve_slope"]

fields_shiny = ["cell_name", "roi", "cell_specimen_project", "Norm_Marker_Sum.0.4_label",
                "marker_sum_norm_label", "rna_amplification_pass_fail",
                "percent_cdna_longer_than_400bp", "amplified_quantity_ng", "sample_id", 
                "Tree_call", "seurat_prediction_score_label", "seurat_cluster_label",
                "broad_class_label", "subclass_label"]

shiny_dict = {"Norm_Marker_Sum.0.4_label" : "NMS Pass/Fail",
              "rna_amplification_pass_fail" : "RNA Amp Pass/Fail",
              "marker_sum_norm_label": "NMS score",
              "percent_cdna_longer_than_400bp" : "cDNA quality (%>400 bp)",
              "amplified_quantity_ng" : "Amplified content (ng)",
              "seurat_prediction_score_label": "Seurat prediction score"}

# %% [markdown]
# ##### Filtering shiny

# %%
shiny_human = read_file(path_shiny_human, fields_shiny) #3592 rows
shiny_human.rename(columns=shiny_dict, inplace=True)
# Out:
# INFO:temp_funcs:Read file in as a pandas dataframe

# %%
shiny_human["NMS Pass/Fail"] = shiny_human["NMS Pass/Fail"].replace({True: "Pass", False: "Fail"})

# %%
shiny_human["region"] = pd.np.where(shiny_human.roi.str.contains("FCx"), "FCx", 
                                    pd.np.where(shiny_human.roi.str.contains("OCx"), "OCx", 
                                    pd.np.where(shiny_human.roi.str.contains("PCx"), "PCx",
                                    pd.np.where(shiny_human.roi.str.contains("TCx"), "TCx", "Unknown/Misc"))))

shiny_human["layer"] = pd.np.where(shiny_human.roi.str.contains("L1"), "L1", 
                                   pd.np.where(shiny_human.roi.str.contains("L2"), "L2",
                                   pd.np.where(shiny_human.roi.str.contains("L3"), "L3",
                                   pd.np.where(shiny_human.roi.str.contains("L4"), "L4", 
                                   pd.np.where(shiny_human.roi.str.contains("L5"), "L5",
                                   pd.np.where(shiny_human.roi.str.contains("L6"), "L6",
                                   pd.np.where(shiny_human.roi.str.contains("L2-3"), "L2-3",
                                   pd.np.where(shiny_human.roi.str.contains("L3a"), "L3",
                                   pd.np.where(shiny_human.roi.str.contains("L3b"), "L3",
                                   pd.np.where(shiny_human.roi.str.contains("L3c"), "L3",
                                   pd.np.where(shiny_human.roi.str.contains("L6a"), "L6",
                                   pd.np.where(shiny_human.roi.str.contains("LL1"), "LL1", 
                                   pd.np.where(shiny_human.roi.str.contains("LL2"), "LL2", 
                                   pd.np.where(shiny_human.roi.str.contains("LL3"), "LL3",
                                   pd.np.where(shiny_human.roi.str.contains("LL4"), "LL4", 
                                   pd.np.where(shiny_human.roi.str.contains("LL5"), "LL5", "unknown_layer"))))))))))))))))

# %%
ephys = read_file(path_ephys, fields_ephys) #1449 rows
ephys.rename(columns={"vrest": "Vm(mV)", "ri": "Input Resistance(MΩ)",
                       "sag" : "Sag Fraction", "tau": "τ(s)",
                       "upstroke_downstroke_ratio_long_square": "LS AP up/downstoke", "latency" : "Latency",
                       "f_i_curve_slope" : "F-I Curve"}, inplace=True)
# Out:
# INFO:temp_funcs:Read file in as a pandas dataframe

# %% [markdown]
# ##### Human Layer 4 DF

# %%
h_l4 = filter_df(shiny_human, "layer", "L4")
h_l4 = create_cond_df(h_l4, "region", ["FCx", "OCx", "PCx", "TCx"]) #473 rows

merged = merge_dataframes(h_l4, ephys, "cell_name", "name", "inner") #379 rows
merged.dropna(subset=ephys_list, inplace=True) #311 rows
# Out:
# INFO:temp_funcs:Filtered dataframe based on layer == L4
# INFO:temp_funcs:Created a conditional dataframe based on region containing ['FCx', 'OCx', 'PCx', 'TCx']
# INFO:temp_funcs:Merged two pandas dataframe into one dataframe

# %%
d = dict()
for region_name in region_list:
    d[region_name] = filter_df(merged, "region", region_name)
# Out:
# INFO:temp_funcs:Filtered dataframe based on region == FCx
# INFO:temp_funcs:Filtered dataframe based on region == OCx
# INFO:temp_funcs:Filtered dataframe based on region == PCx
# INFO:temp_funcs:Filtered dataframe based on region == TCx

# %% [markdown]
# ##### Making groupby tables for RNA/NMS Groups

# %%
count_rn = rna_nms_table(merged)
count_fcx = rna_nms_table(d["FCx"])
count_ocx = rna_nms_table(d["OCx"])
count_pcx = rna_nms_table(d["PCx"])
count_tcx = rna_nms_table(d["TCx"])
# Out:
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on RNA Amp Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on RNA Amp Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass
# C:\Users\kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on RNA Amp Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on RNA Amp Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on RNA Amp Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on RNA Amp Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on RNA Amp Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on RNA Amp Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on RNA Amp Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on RNA Amp Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Fail
# INFO:temp_funcs:Filtered dataframe based on NMS Pass/Fail == Pass

# %% [markdown]
# ##### Tables

# %%
merged = create_proportion_table(merged, "region", "Tree_call")
merged
# Out:
#                sample_id               cell_name     roi  \
# 0    P8S4_180718_354_A01  H18.03.313.11.06.01.05  TCx_L4
# 3    P8S4_190618_356_A01  H19.03.314.12.07.01.01  TCx_L4
# 4    P1S4_190813_005_A01  H19.03.319.12.07.01.03  TCx_L4
# 5    PAS4_190123_453_A01  H19.03.302.11.03.01.03  TCx_L4
# 7    PES4_190311_659_A01  H19.03.306.11.06.02.01  TCx_L4
# 8    PFS4_190514_707_A01  H19.03.311.14.09.01.01  TCx_L4
# 9    P8S4_190709_359_A01  H19.03.315.11.01.01.03  TCx_L4
# 10   P8S4_190305_360_A01  H19.03.305.11.10.01.10  TCx_L4
# 11   PES4_190618_656_A01  H19.03.314.12.12.01.04  TCx_L4
# 12   P8S4_190425_355_A01  H19.03.310.11.06.02.04  FCx_L4
# 13   PAS4_190514_451_A01  H19.03.311.14.10.01.01  TCx_L4
# 14   PES4_190311_660_A01  H19.03.306.11.06.02.02  TCx_L4
# 15   PBS4_181211_502_A01  H18.06.371.12.20.01.02  TCx_L4
# 16   PFS4_190709_711_A01  H19.03.315.11.12.01.02  TCx_L4
# 17   P8S4_190416_352_A01  H19.06.353.11.03.01.02  OCx_L4
# 18   PES4_190709_666_A01  H19.03.315.11.07.01.02  TCx_L4
# 19   P8S4_190321_361_A01  H19.06.351.11.06.01.10  TCx_L4
# 20   PBS4_180807_511_A01  H18.03.314.11.10.01.05  TCx_L4
# 21   PAS4_190618_460_A01  H19.03.314.12.13.01.04  TCx_L4
# 22   PAS4_190419_452_A01  H19.03.309.11.10.02.03  FCx_L4
# 23   PES4_190122_659_A01  H19.03.302.11.08.01.03  TCx_L4
# 24   PES4_190425_652_A01  H19.03.310.11.06.01.02  FCx_L4
# 26   PFS4_190108_709_A01  H19.03.301.11.13.01.01  TCx_L4
# 27   PAS4_190604_451_A01  H19.06.356.11.12.02.01  TCx_L4
# 28   PAS4_190305_455_A01  H19.03.305.11.05.01.08  TCx_L4
# 30   PAS4_190514_455_A01  H19.03.311.14.10.01.05  TCx_L4
# 31   PFS4_200121_702_A01  H20.03.302.11.09.02.03  TCx_L4
# 32   PAS4_190419_453_A01  H19.03.309.11.10.02.04  FCx_L4
# 37   P8S4_180508_366_A01     H18.03.010.11.14.10  TCx_L4
# 19                     0.667              Pass               26.523369
# 20                     0.650              Pass               19.310458
# 21                     0.609              Pass               48.854406
# 22                     0.374              Fail               16.029025
# 23                     0.761              Pass               19.734898
# 24                     0.621              Pass               18.283157
# 26                     0.656              Pass               22.458422
# 27                     0.637              Pass               15.797094
# 28                     0.735              Pass               24.603935
# 30                     0.481              Pass               12.257751
# 31                     0.620              Pass               16.829894
# 32                     0.603              Pass               27.564918
# 37                     0.735              Pass               36.359791
# 38                     0.477              Pass               12.407140
# ..                       ...               ...                     ...
# 322                    0.465              Pass                9.328361
# 324                    0.272              Fail                7.176979
# 329                    0.617              Pass               12.564854
# 330                    0.409              Fail              245.717739
# 331                    0.637              Pass               20.714492
# 332                    0.561              Pass                9.324211
# 336                    0.425              Pass                8.708609
# 337                    0.348              Fail                7.841198
# 340                    0.525              Fail                7.502785
# 341                    0.196              Fail                4.487068
# 342                    0.330              Fail                8.033876
# 343                    0.291              Fail                5.597038
# 350                    0.376              Pass               12.163754
# 358                    0.409              Fail                2.663399
# 359                    0.531              Pass               19.175677
# 360                    0.409              Fail                4.983106
# 361                    0.195              Fail                6.072627
# 362                    0.403              Fail                3.804187
# 363                    0.257              Fail                3.726973
# 366                    0.458              Fail                4.773120
# 367                    0.508              Fail                2.665243
# 368                    0.268              Fail                6.730261
# 369                    0.501              Fail                3.271701
# 370                    0.515              Pass                8.008964
# 371                    0.394              Fail                5.501092
# 372                    0.486              Fail                6.933865
# 373                    0.348              Fail                5.640186
# 374                    0.742              Pass               24.062907
# 375                    0.560              Pass                8.214780
# 376                    0.436              Pass               13.414215
#
#     cell_specimen_project  NMS score NMS Pass/Fail  \
# 0              hIVSCC-MET   1.112490          Pass
# 3              hIVSCC-MET   0.988428          Pass
# 4              hIVSCC-MET   1.372332          Pass
# 5              hIVSCC-MET   1.043932          Pass
# 7              hIVSCC-MET   1.401790          Pass
# 8              hIVSCC-MET   0.910007          Pass
# 9              hIVSCC-MET   0.760139          Pass
# 10             hIVSCC-MET   0.814408          Pass
# 11             hIVSCC-MET   1.045758          Pass
# 12             hIVSCC-MET   0.715713          Pass
# 13             hIVSCC-MET   0.889952          Pass
# 14             hIVSCC-MET   0.973835          Pass
# 15             hIVSCC-MET   1.069371          Pass
# 16             hIVSCC-MET   0.958245          Pass
# 17             hIVSCC-MET   1.136011          Pass
# 18             hIVSCC-MET   0.977888          Pass
# 19             hIVSCC-MET   0.880008          Pass
# 20             hIVSCC-MET   0.762277          Pass
# 21             hIVSCC-MET   1.166451          Pass
# 22             hIVSCC-MET   1.151552          Pass
# 23             hIVSCC-MET   1.136641          Pass
# 24             hIVSCC-MET   0.938188          Pass
# 26             hIVSCC-MET   1.014466          Pass
# 27             hIVSCC-MET   0.913379          Pass
# 28             hIVSCC-MET   1.218222          Pass
# 30             hIVSCC-MET   0.712290          Pass
# 31             hIVSCC-MET   0.981118          Pass
# 32             hIVSCC-MET   1.011168          Pass
# 37             hIVSCC-MET   0.886244          Pass
# 38             hIVSCC-MET   0.870500          Pass
# ..                    ...        ...           ...
# 322            hIVSCC-MET   0.566989          Pass
# 324            hIVSCC-MET   0.431724          Pass
# 329            hIVSCC-MET   0.134532          Fail
# 330            hIVSCC-MET   1.097764          Pass
# 331            hIVSCC-MET   0.134778          Fail
# 332            hIVSCC-MET   0.149987          Fail
# 336            hIVSCC-MET   0.075602          Fail
# 337            hIVSCC-MET   0.345571          Fail
# 340            hIVSCC-MET   0.110688          Fail
# 341            hIVSCC-MET   0.207101          Fail
# 342            hIVSCC-MET   0.355668          Fail
# 343            hIVSCC-MET   0.076603          Fail
# 350            hIVSCC-MET   0.416997          Pass
# 358            hIVSCC-MET   0.204168          Fail
# 359            hIVSCC-MET   0.088001          Fail
# 360            hIVSCC-MET   0.118231          Fail
# 361            hIVSCC-MET   0.266372          Fail
# 362            hIVSCC-MET   0.115835          Fail
# 363            hIVSCC-MET   0.119887          Fail
# 366            hIVSCC-MET   0.088517          Fail
# 367            hIVSCC-MET   0.100377          Fail
# 368            hIVSCC-MET   0.260012          Fail
# 369            hIVSCC-MET   0.207982          Fail
# 370            hIVSCC-MET   0.426581          Pass
# 371            hIVSCC-MET   0.323792          Fail
# 372            hIVSCC-MET   0.321862          Fail
# 373            hIVSCC-MET   0.087728          Fail
# 374            hIVSCC-MET   0.086580          Fail
# 375            hIVSCC-MET   0.111813          Fail
# 376            hIVSCC-MET   0.269464          Fail
#
#                    seurat_cluster_label  Seurat prediction score  \
# 0                   Inh L1-2 PAX6 CDH12                 1.000000
# 3         Inh L1-4 LAMP5 LCP2 (rosehip)                 0.984463
# 4             Inh L2-6 LAMP5 CA1 (Igtp)                 1.000000
# 5             Inh L2-6 LAMP5 CA1 (Igtp)                 0.960779
# 7                   Inh L2-4 VIP SPAG17                 0.518578
# 8                   Inh L4-6 SST GXYLT2                 0.788271
# 9                   Inh L4-6 SST GXYLT2                 0.805382
# 10                  Inh L4-5 SST STK32A                 0.878520
# 11                  Inh L4-5 SST STK32A                 0.926072
# 12                  Inh L4-5 PVALB MEPE                 0.752130
# 13                 Inh L2-4 PVALB WFDC2                 0.498395
# 14                  Inh L5-6 PVALB LGR5                 0.457284
# 15                  Inh L4-5 PVALB MEPE                 0.757969
# 16                 Inh L2-4 PVALB WFDC2                 0.436041
# 17                 Inh L2-4 PVALB WFDC2                 0.713256
# 18                 Inh L4-6 PVALB SULF1                 0.383249
# 19                 Inh L4-6 PVALB SULF1                 0.355760
# 20                 Inh L4-6 PVALB SULF1                 0.452340
# 21                 Inh L2-4 PVALB WFDC2                 0.938285
# 22                 Inh L2-4 PVALB WFDC2                 0.985967
# 23                 Inh L2-4 PVALB WFDC2                 0.520974
# 24                 Inh L2-4 PVALB WFDC2                 0.702000
# 26                 Inh L2-4 PVALB WFDC2                 0.943168
# 27                 Inh L2-4 PVALB WFDC2                 0.773631
# 28                 Inh L2-4 PVALB WFDC2                 0.930458
# 30                 Inh L2-4 PVALB WFDC2                 0.414519
# 31                    Inh L2-4 SST FRZB                 0.541618
# 32                 Inh L2-4 PVALB WFDC2                 0.732711
# 37                 Inh L2-4 PVALB WFDC2                 0.722133
# 38                 Inh L2-4 PVALB WFDC2                 0.535096
# ..                                  ...                      ...
# 322                Exc L4-5 RORB FOLH1B                 0.530547
# 324                Inh L2-4 PVALB WFDC2                 0.658735
# 329                   Exc L4-6 RORB C1R                 0.165561
# 330            Exc L2-3 LINC00507 FREM3                 0.390162
# 331                 Inh L4-5 PVALB MEPE                 0.264922
# 332                Inh L2-4 PVALB WFDC2                 0.537888
# 336                Inh L2-4 PVALB WFDC2                 0.193733
# 337                  Inh L1-3 SST CALB1                 0.205165
# 340                Inh L2-4 PVALB WFDC2                 0.810181
# 341                Inh L2-4 PVALB WFDC2                 0.548405
# 342                  Inh L1-3 SST CALB1                 0.259747
# 343                Inh L2-4 PVALB WFDC2                 0.326876
# 350            Exc L2-4 LINC00507 GLP2R                 0.235294
# 358                    Exc L2 LAMP5 LTK                 0.439977
# 359                Inh L2-4 PVALB WFDC2                 0.569458
# 360  Inh L2-5 PVALB SCUBE3 (chandelier)                 0.524761
# 361                Inh L2-4 PVALB WFDC2                 0.388158
# 362                Exc L4-6 RORB SEMA3E                 0.164686
# 363                Inh L2-4 PVALB WFDC2                 0.431248
# 366                Inh L2-4 PVALB WFDC2                 0.562296
# 367                Inh L2-4 PVALB WFDC2                 0.396156
# 368                   Exc L4-6 RORB C1R                 0.371489
# 369  Inh L2-5 PVALB SCUBE3 (chandelier)                 0.921103
# 370                 Inh L4-5 PVALB MEPE                 0.642678
# 371                  Exc L3-5 RORB ESR1                 0.694522
# 372                  Exc L3-5 RORB ESR1                 0.520029
# 373                Inh L2-4 PVALB WFDC2                 0.356891
# 374                Inh L2-4 PVALB WFDC2                 0.561645
# 375                Inh L2-4 PVALB WFDC2                 0.442187
# 376                Inh L2-4 PVALB WFDC2                 0.216202
#
#         broad_class_label    subclass_label Tree_call region layer  \
# 0        GABAergic neuron  LAMP5/PAX6/Other      Core    TCx    L4
# 3        GABAergic neuron  LAMP5/PAX6/Other      Core    TCx    L4
# 4        GABAergic neuron  LAMP5/PAX6/Other      Core    TCx    L4
# 5        GABAergic neuron  LAMP5/PAX6/Other      Core    TCx    L4
# 7        GABAergic neuron               VIP      Core    TCx    L4
# 8        GABAergic neuron               SST      Core    TCx    L4
# 9        GABAergic neuron               SST      Core    TCx    L4
# 10       GABAergic neuron               SST      Core    TCx    L4
# 11       GABAergic neuron               SST      Core    TCx    L4
# 12       GABAergic neuron             PVALB      Core    FCx    L4
# 13       GABAergic neuron             PVALB      Core    TCx    L4
# 14       GABAergic neuron             PVALB      Core    TCx    L4
# 15       GABAergic neuron             PVALB      Core    TCx    L4
# 16       GABAergic neuron             PVALB      Core    TCx    L4
# 17       GABAergic neuron             PVALB      Core    OCx    L4
# 18       GABAergic neuron             PVALB      Core    TCx    L4
# 19       GABAergic neuron             PVALB        I1    TCx    L4
# 20       GABAergic neuron             PVALB        I1    TCx    L4
# 21       GABAergic neuron             PVALB      Core    TCx    L4
# 22       GABAergic neuron             PVALB      Core    FCx    L4
# 23       GABAergic neuron             PVALB      Core    TCx    L4
# 24       GABAergic neuron             PVALB      Core    FCx    L4
# 26       GABAergic neuron             PVALB      Core    TCx    L4
# 27       GABAergic neuron             PVALB      Core    TCx    L4
# 28       GABAergic neuron             PVALB      Core    TCx    L4
# 30       GABAergic neuron             PVALB      Core    TCx    L4
# 31       GABAergic neuron             PVALB      Core    TCx    L4
# 32       GABAergic neuron             PVALB      Core    FCx    L4
# 37       GABAergic neuron             PVALB        I1    TCx    L4
# 38       GABAergic neuron             PVALB      Core    TCx    L4
# ..                    ...               ...       ...    ...   ...
# 322  Glutamatergic neuron         IT (L4-6)     PoorQ    TCx    L4
# 324      GABAergic neuron             PVALB     PoorQ    TCx    L4
# 329      GABAergic neuron             PVALB     PoorQ    TCx    L4
# 330      GABAergic neuron  LAMP5/PAX6/Other     PoorQ    TCx    L4
# 331  Glutamatergic neuron           L5/6 NP     PoorQ    TCx    L4
# 332  Glutamatergic neuron           L5/6 CT     PoorQ    TCx    L4
# 336      GABAergic neuron  LAMP5/PAX6/Other     PoorQ    FCx    L4
# 337  Glutamatergic neuron           L5/6 CT     PoorQ    FCx    L4
# 340      GABAergic neuron             PVALB     PoorQ    TCx    L4
# 341      GABAergic neuron  LAMP5/PAX6/Other     PoorQ    TCx    L4
# 342  Glutamatergic neuron         IT (L2-3)     PoorQ    TCx    L4
# 343  Glutamatergic neuron         IT (L3-5)     PoorQ    TCx    L4
# 350  Glutamatergic neuron           IT (L6)     PoorQ    TCx    L4
# 358  Glutamatergic neuron         IT (L4-6)     PoorQ    TCx    L4
# 359      GABAergic neuron  LAMP5/PAX6/Other     PoorQ    TCx    L4
# 360      GABAergic neuron             PVALB     PoorQ    TCx    L4
# 361      GABAergic neuron             PVALB     PoorQ    TCx    L4
# 362      GABAergic neuron  LAMP5/PAX6/Other     PoorQ    TCx    L4
# 363  Glutamatergic neuron             L5 ET     PoorQ    TCx    L4
# 366  Glutamatergic neuron         IT (L3-5)     PoorQ    FCx    L4
# 367      GABAergic neuron               SST     PoorQ    TCx    L4
# 368  Glutamatergic neuron           IT (L6)     PoorQ    TCx    L4
# 369      GABAergic neuron             PVALB     PoorQ    TCx    L4
# 370      GABAergic neuron             PVALB     PoorQ    TCx    L4
# 371  Glutamatergic neuron         IT (L3-5)     PoorQ    TCx    L4
# 372  Glutamatergic neuron         IT (L4-6)     PoorQ    TCx    L4
# 373  Glutamatergic neuron         IT (L2-3)     PoorQ    TCx    L4
# 374      GABAergic neuron               VIP     PoorQ    TCx    L4
# 375      GABAergic neuron               VIP     PoorQ    TCx    L4
# 376  Glutamatergic neuron         IT (L4-6)     PoorQ    TCx    L4
#
#                        name     Vm(mV)  Input Resistance(MΩ)  Sag Fraction  \
# 0    H18.03.313.11.06.01.05 -63.207101            841.105652      0.147336
# 3    H19.03.314.12.07.01.01 -60.490061            265.750021      0.094790
# 4    H19.03.319.12.07.01.03 -66.055191            249.234408      0.056897
# 5    H19.03.302.11.03.01.03 -59.083222            353.063971      0.022493
# 341  14.422253            1.538046  0.01412   0.794764           42
# 342  15.133807            4.555774  0.04888   0.037500           42
# 343  23.201167            3.304228  0.04430   0.244860           42
# 350  37.315644            4.877361  0.05932   0.123529           42
# 358  26.233336            3.819914  0.04130   0.185000           42
# 359  27.113137            2.428979  0.04144   0.245000           42
# 360  12.554617            1.562970  0.01662   0.680000           42
# 361  10.299584            1.710861  0.01206   0.585981           42
# 362  23.762803            2.963509  0.03070   0.298030           42
# 363  33.868753            3.770203  0.03426   0.170983           42
# 366  27.754678            4.512186  0.03314   0.151429            5
# 367  15.780547            3.557734  0.04250   0.100000           42
# 368  15.874965            2.940731  0.03110   0.295000           42
# 369  13.677424            1.252728  0.00466   1.135333           42
# 370  11.421373            2.117482  0.02506   0.370732           42
# 371  20.440704            3.255874  0.04180   0.351724           42
# 372  21.685570            2.650351  0.03302   0.292367           42
# 373  23.468343            3.336474  0.03832   0.209756           42
# 374  25.009076            2.772645  0.04842   0.174112           42
# 375  26.764876            2.305283  0.04420   0.204977           42
# 376  28.874382            4.151645  0.04824   0.182356           42
#
#      group_total  proportion
# 0            275   60.727273
# 3            275   60.727273
# 4            275   60.727273
# 5            275   60.727273
# 7            275   60.727273
# 8            275   60.727273
# 9            275   60.727273
# 10           275   60.727273
# 11           275   60.727273
# 12            31   54.838710
# 13           275   60.727273
# 14           275   60.727273
# 15           275   60.727273
# 16           275   60.727273
# 17             3   66.666667
# 18           275   60.727273
# 19           275   16.363636
# 20           275   16.363636
# 21           275   60.727273
# 22            31   54.838710
# 23           275   60.727273
# 24            31   54.838710
# 26           275   60.727273
# 27           275   60.727273
# 28           275   60.727273
# 30           275   60.727273
# 31           275   60.727273
# 32            31   54.838710
# 37           275   16.363636
# 38           275   60.727273
# ..           ...         ...
# 322          275   15.272727
# 324          275   15.272727
# 329          275   15.272727
# 330          275   15.272727
# 331          275   15.272727
# 332          275   15.272727
# 336           31   16.129032
# 337           31   16.129032
# 340          275   15.272727
# 341          275   15.272727
# 342          275   15.272727
# 343          275   15.272727
# 350          275   15.272727
# 358          275   15.272727
# 359          275   15.272727
# 360          275   15.272727
# 361          275   15.272727
# 362          275   15.272727
# 363          275   15.272727
# 366           31   16.129032
# 367          275   15.272727
# 368          275   15.272727
# 369          275   15.272727
# 370          275   15.272727
# 371          275   15.272727
# 372          275   15.272727
# 373          275   15.272727
# 374          275   15.272727
# 375          275   15.272727
# 376          275   15.272727
#
# [311 rows x 27 columns]

# %%
proportion_table = pd.pivot_table(count_rn, values="proportion", index=["Group"], columns="Tree_call", fill_value=0)
count_table = pd.pivot_table(count_rn, values="group_count", index=["Group"], columns="Tree_call", fill_value=0)

# %%
count_table = pd.pivot_table(count_ocx, values="group_count", index=["Group"], columns="Tree_call", fill_value=0)
count_table
# Out:
# Tree_call              Core  I2
# Group
# RNA Amp Pass/NMS Pass     2   1

# %%
count_table = pd.pivot_table(count_pcx, values="group_count", index=["Group"], columns="Tree_call", fill_value=0)
count_table
# Out:
# Tree_call              I2
# Group
# RNA Amp Pass/NMS Pass   2

# %% [markdown]
# ##### Plots Region

# %%
tree_colors={"Core": "#41ab5d", "I1": "#2171b5", "I2": "#4292c6", "I3": "#6baed6", "PoorQ": "#ef3b2c"}

# %%
count_table = pd.pivot_table(merged, values="group_count", index=["region"], columns="Tree_call", fill_value=0)
count_table
# Out:
# Tree_call  Core  I1  I2  I3  PoorQ
# region
# FCx          17   6   3   0      5
# OCx           2   0   1   0      0
# PCx           0   0   2   0      0
# TCx         167  45  20   1     42

# %%
f, axes = plt.subplots(figsize=(20, 10))
    
ax = sns.barplot(x="region", y="proportion", data=merged, order=region_list,
                 hue="Tree_call", hue_order=tree_colors, palette=tree_colors, saturation=1)
ax.set(xlabel="Groups", ylabel="Percentage of Cell Proportion")
# Out:
# [Text(0,0.5,'Percentage of Cell Proportion'), Text(0.5,0,'Groups')]

# %% [markdown]
# ##### Plots RNA/NMS

# %%
count_table = pd.pivot_table(count_rn, values="group_count", index=["Group"], columns="Tree_call", fill_value=0)
count_table
# Out:
# Tree_call              Core  I1  I2  I3  PoorQ
# Group
# RNA Amp Fail/NMS Fail     0   0   0   0     19
# RNA Amp Fail/NMS Pass     2   2   0   0      2
# RNA Amp Pass/NMS Fail     1   0   0   0     15
# RNA Amp Pass/NMS Pass   183  49  26   1     11

# %%
f, axes = plt.subplots(figsize=(20, 10))

ax = sns.barplot(x="Group", y="proportion", data=count_rn, 
                 hue="Tree_call", hue_order=tree_colors, palette=tree_colors, saturation=1)
ax.set(xlabel="Groups", ylabel="Percentage of Cell Proportion")
# Out:
# [Text(0,0.5,'Percentage of Cell Proportion'), Text(0.5,0,'Groups')]

# %%
count_table = pd.pivot_table(count_fcx, values="group_count", index=["Group"], columns="Tree_call", fill_value=0)
count_table
# Out:
# Tree_call              Core  I1  I2  PoorQ
# Group
# RNA Amp Fail/NMS Fail     0   0   0      2
# RNA Amp Fail/NMS Pass     1   1   0      0
# RNA Amp Pass/NMS Fail     0   0   0      2
# RNA Amp Pass/NMS Pass    16   5   3      1

# %%
f, axes = plt.subplots(figsize=(20, 10))

ax = sns.barplot(x="Group", y="proportion", data=count_fcx, 
                 hue="Tree_call", hue_order=tree_colors, palette=tree_colors, saturation=1)
ax.set(xlabel="Groups", ylabel="Percentage of Cell Proportion")
# Out:
# [Text(0,0.5,'Percentage of Cell Proportion'), Text(0.5,0,'Groups')]

# %%
count_table = pd.pivot_table(count_tcx, values="group_count", index=["Group"], columns="Tree_call", fill_value=0)
count_table
# Out:
# Tree_call              Core  I1  I2  I3  PoorQ
# Group
# RNA Amp Fail/NMS Fail     0   0   0   0     17
# RNA Amp Fail/NMS Pass     1   1   0   0      2
# RNA Amp Pass/NMS Fail     1   0   0   0     13
# RNA Amp Pass/NMS Pass   165  44  20   1     10

# %%
f, axes = plt.subplots(figsize=(20, 10))

ax = sns.barplot(x="Group", y="proportion", data=count_tcx, 
                 hue="Tree_call", hue_order=tree_colors, palette=tree_colors, saturation=1)
ax.set(xlabel="Groups", ylabel="Percentage of Cell Proportion")
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)
