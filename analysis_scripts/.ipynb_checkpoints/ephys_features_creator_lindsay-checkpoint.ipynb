# %% [markdown]
# ##### Imports

# %%
import pandas as pd 
import pg8000
from lims_funcs import get_lims_dataframe

from allensdk.core.nwb_data_set import NwbDataSet
import allensdk.ephys.ephys_features as aef
import allensdk.ephys.extract_cell_features as ecf

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##### SQL Query

# %%
#c = raw_input('cell name 1: ')
#d = raw_input('cell name 2: ')
#AND cell.name = '{}'
#AND cell.name = '{}' OR cell.name = '{}'
#.format(c)

# %%
q = """
SELECT cell.patched_cell_container, cell.name,
cell.id,
SUBSTRING(cell.patched_cell_container FROM 6 FOR 6) AS container_date,
ef.*
FROM specimens cell 
JOIN ephys_roi_results err ON cell.ephys_roi_result_id = err.id
JOIN projects proj ON cell.project_id = proj.id
LEFT JOIN ephys_features ef on ef.specimen_id = cell.id
AND proj.code = 'mIVSCC-MET'"""

df_2020 = get_lims_dataframe(q)

"""
SELECT cell.patched_cell_container, cell.name,
cell.id,
SUBSTRING(cell.patched_cell_container FROM 6 FOR 6) AS container_date,
ef.*
FROM specimens cell 
JOIN ephys_roi_results err ON cell.ephys_roi_result_id = err.id
JOIN projects proj ON cell.project_id = proj.id
LEFT JOIN ephys_features ef on ef.specimen_id = cell.id
WHERE SUBSTRING(cell.patched_cell_container FROM 6 FOR 6) BETWEEN '200101' AND '201231'
AND proj.code = 'mIVSCC-MET'"""
# Out:
# "\nSELECT cell.patched_cell_container, cell.name,\ncell.id,\nSUBSTRING(cell.patched_cell_container FROM 6 FOR 6) AS container_date,\nef.*\nFROM specimens cell \nJOIN ephys_roi_results err ON cell.ephys_roi_result_id = err.id\nJOIN projects proj ON cell.project_id = proj.id\nLEFT JOIN ephys_features ef on ef.specimen_id = cell.id\nWHERE SUBSTRING(cell.patched_cell_container FROM 6 FOR 6) BETWEEN '200101' AND '201231'\nAND proj.code = 'mIVSCC-MET'"

# %%
df_2020
# Out:
#       b'patched_cell_container'  \
# 0           PFS4_200103_701_A01
# 1                          None
# 2                          None
# 3                          None
# 4           P1S4_190212_001_A01
# ...                         ...
# 26651       P9S4_180112_404_A01
# 26652                      None
# 26653                      None
# 26654                      None
# 26655       P2S4_190514_051_A01
#
#                                                  b'name'        b'id'  \
# 0                     Gad2-IRES-Cre;Ai14-504539.10.01.01  997542689.0
# 1      Vipr2-IRES2-Cre;Pvalb-T2A-FlpO;Ai65-437075.04....  809635936.0
# 2      Vipr2-IRES2-Cre;Pvalb-T2A-FlpO;Ai65-437075.03....  809646086.0
# 3      Vipr2-IRES2-Cre;Pvalb-T2A-FlpO;Ai65-462280.04....  869545617.0
# 4      Htr3a-Cre_NO152;Pvalb-T2A-FlpO;Ai65-440916.04....  821542578.0
# ...                                                  ...          ...
# 26651               Chrna2-Cre_OE25;Ai14-367172.03.01.02          NaN
# 26652                Esr2-IRES2-Cre;Ai14-304376.02.02.01          NaN
# 26653                                H17.06.005.13.05.06          NaN
# 26654  Penk-IRES2-Cre-neo;Slc17a6-IRES2-FlpO-508719-A...          NaN
# 26655                             H19.03.311.14.08.01.01          NaN
#
#       b'container_date'  b'specimen_id'  b'rheobase_sweep_id'  \
# 0                200103     997541435.0           997542112.0
# 1                  None     809615441.0           809630396.0
# 2                  None     809632961.0           809638943.0
# 3                  None     869497896.0           869520631.0
# 4                190212     821522047.0           821532537.0
# ...                 ...             ...                   ...
# 26651            180112             NaN                   NaN
# 26652              None             NaN                   NaN
# 26653              None             NaN                   NaN
# 26654              None             NaN                   NaN
# 26655            190514             NaN                   NaN
#
#        b'thumbnail_sweep_id'   b'vrest'       b'ri'    b'sag'  ...  \
# 0                997542117.0 -65.282120   59.750024  0.148347  ...
# 1                809630410.0 -65.295204   60.312387  0.047297  ...
# 2                809638950.0 -71.158137  101.749994  0.035610  ...
# 3                869520640.0 -68.072316   67.625009  0.075305  ...
# 4                821532548.0 -73.175226   73.312454  0.011772  ...
# ...                      ...        ...         ...       ...  ...
# 26651                    NaN        NaN         NaN       NaN  ...
# 26652                    NaN        NaN         NaN       NaN  ...
# 26653                    NaN        NaN         NaN       NaN  ...
# 26654                    NaN        NaN         NaN       NaN  ...
# 26655                    NaN        NaN         NaN       NaN  ...
#
#        b'threshold_t_long_square'  b'adaptation'  b'latency'  b'avg_isi'  \
# 0                         0.61840       0.054717     0.03164   96.272000
# 1                         0.62050       0.007492     0.04230   31.664138
# 2                         0.51502       0.023410     0.00944   16.127692
# 3                         0.50680            NaN     0.00520         NaN
# 4                         0.52164       0.002700     0.01200   16.213667
# ...                           ...            ...         ...         ...
# 26651                         NaN            NaN         NaN         NaN
# 26652                         NaN            NaN         NaN         NaN
# 26653                         NaN            NaN         NaN         NaN
# 26654                         NaN            NaN         NaN         NaN
# 26655                         NaN            NaN         NaN         NaN
#
#        b'f_i_curve_slope'  b'has_burst'  b'has_pause'  b'has_delay'  \
# 0            1.495327e-01          None          None          None
# 1            6.723404e-01          None          None          None
# 2            6.100000e-01          None          None          None
# 3            9.099119e-19          None          None          None
# 4            6.057692e-01          None          None          None
# ...                   ...           ...           ...           ...
# 26651                 NaN          None          None          None
# 26652                 NaN          None          None          None
# 26653                 NaN          None          None          None
# 26654                 NaN          None          None          None
# 26655                 NaN          None          None          None
#
#                    b'created_at'              b'updated_at'
# 0     2020-01-03 19:32:47.705157 2020-01-03 19:32:47.705157
# 1     2019-01-17 19:12:40.217597 2019-01-17 19:12:40.217597
# 2     2019-01-17 19:32:04.970144 2019-01-17 19:32:04.970144
# 3     2019-05-16 20:06:55.409414 2019-05-16 20:06:55.409414
# 4     2019-02-12 18:57:44.583239 2019-02-12 18:57:44.583239
# ...                          ...                        ...
# 26651                        NaT                        NaT
# 26652                        NaT                        NaT
# 26653                        NaT                        NaT
# 26654                        NaT                        NaT
# 26655                        NaT                        NaT
#
# [26656 rows x 57 columns]

# %% [markdown]
# ##### Writing to csv_file

# %%
csv_path = "C:/Users/ramr/Documents/Github/analysis_projects/csv/"
df_2020.to_csv(csv_path + "mephys_features.csv", index=False)

# %% [markdown]
# ##### Unnecessary imports

# %%
"""
#import os, re
#import numpy as np
#import matplotlib.pyplot as plt
#from matplotlib import pyplot as plt
#import seaborn as sns
#from mpl_toolkits import mplot3d
#from research_ops_tools.lims2_funcs import get_lims_dataframe
#from allensdk.internal.core.lims_utilities import linux_to_windows

#sns.set()
"""
# Out:
# '\n#import os, re\n#import numpy as np\n#import matplotlib.pyplot as plt\n#from matplotlib import pyplot as plt\n#import seaborn as sns\n#from mpl_toolkits import mplot3d\n#from research_ops_tools.lims2_funcs import get_lims_dataframe\n#from allensdk.internal.core.lims_utilities import linux_to_windows\n\n#sns.set()\n'
