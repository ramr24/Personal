# %% [markdown]
# # Coding Project Analysis JEM Forms

# %% [markdown]
# ### Data Output: Date, Specimen ID, Rig Opertator, Layer, Cell Type Prediction (Human)

# %%
import os
import csv
import json
import fnmatch
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
pd.options.display.max_columns = None  #Displays all the columns

# %%
#Still have to fix this and add more definitions for common functions

def gen_fil(df, col, cond):
    '''
    Filters the column with a certain condition
    df: dataframe
    col: column
    cond: condition
    '''
    filtered = df[df[col] == cond]
    return filtered

def gen_cat(df, col):
    '''
    Assigns astype to the column
    df: dataframe
    col: column
    '''    
    category = df[col].astype('category')
    return category

def cell_count(P_num):
    '''
    Counts number of Lims tube id based on P# as number of cells
    df = dataframe
    count() = counts number
    '''
    user = df1[df1['Lims tube id'].str.contains(P_num)]
    return user['Lims tube id'].count()

def P_user(P_num):
    '''
    Prints cell_count 
    '''
    print("Total cells:", cell_count(P_num))

# %%
#Post patch class Script by Rusty

def nucleated(x):
    nuc_high_seal = x[(x['extraction.postPatch'] == 'Nucleated') | 
                      (((x['extraction.postPatch'] == 'nucleus_visible') | 
                      (x['extraction.postPatch'] == 'nucleus_present')) & 
                      (x['extraction.endPipetteR'] >= 500))]
    return nuc_high_seal

def partial_nucleated(y):
    nuc_low_seal = y[(y['extraction.postPatch'] == 'Partial-Nucleus') | 
                     (((y['extraction.postPatch'] == 'nucleus_present') | 
                     (y['extraction.postPatch'] == 'nucleus_visible')) & 
                     (y['extraction.endPipetteR'] <= 499))]
    return nuc_low_seal

def outside_out(z):
    no_high_seal = z[(z['extraction.postPatch'] == 'Outside-Out') | 
                     (((z['extraction.postPatch'] == 'nucleus_absent') | 
                     (z['extraction.postPatch'] == 'no_nucleus_visible')) & 
                     (z['extraction.endPipetteR'] >= 500))]
    return no_high_seal

def no_seal(w): 
    no_low_seal = w[(w['extraction.postPatch'] == 'No-Seal') | 
                    (((w['extraction.postPatch'] == 'nucleus_absent') | 
                    (w['extraction.postPatch'] == 'no_nucleus_visible')) & 
                    (w['extraction.endPipetteR'] <= 499))]
    return no_low_seal
    
def entire_cell(v):
    entire = v[(v['extraction.postPatch'] == 'Entire-Cell') | 
               (v['extraction.postPatch'] == 'entire_cell')]
    return entire

#variable['post_patch'] = 'Term'
#Term is an output displayed in the Post_Patch column

def reclassify(df):
    nu = nucleated(df)
    nu['post_patch'] = 'Nuc-high seal' 
    oo = outside_out(df)
    oo['post_patch'] = 'No-high seal'
    pn = partial_nucleated(df)
    pn['post_patch'] = 'Nuc-low seal'
    ns = no_seal(df)
    ns['post_patch'] = 'No-low seal'
    ec = entire_cell(df)
    ec['post_patch'] = 'Entire cell'
    return  nu, oo, pn, ns, ec

def concat_df(a, b, c, d, e):
    frames = (a, b, c, d, e)
    df = pd.concat(frames)
    return df

def postpatch_reclass(df):
    return concat_df(*reclassify(df))

#json_df = postpatch_reclass(json_df)

# %%
def get_jsons(dirname, expt):
    json_paths = []
    for jfile in os.listdir(dirname):
        if fnmatch.fnmatch(jfile, '*.%s.json' %expt):
            jpath = os.path.join(dirname, jfile)
            json_paths.append(jpath)
    return json_paths

# %%
#make list of json paths for every json file in MIES Experiments directory on 279
json_list = get_jsons("//allen/programs/celltypes/workgroups/279/Patch-Seq/all-metadata-files/", "PS")
#json_list

# %%
def flatten_attempts(slice_info, form_version):
    """Return flattened slice metadata dataframe.
    
    Parameters
    ----------
    slice_info : dict
        A dictionary of slices with nested pipette attempts.
    
    form_version : string
        A string containing the JEM form version.
        (Pre-version 2 contains IVSCC, PatchSeq and Electroporation arrays)
    Returns
    -------
    attempts_slice_df : pandas dataframe
        A dataframe of all pipette attempts along with all slice metadata.
    """
    
    df = json_normalize(slice_info)
    if form_version >= "2":
        ps_array_name = "pipettes"
    else:
        ps_array_name = "pipettesPatchSeqPilot"
    try:
        attempts_df = json_normalize(slice_info[ps_array_name])
        attempts_df["limsSpecName"] = df["limsSpecName"].values[0]
        attempts_df["attempt"] = [p+1 for p in attempts_df.index.values]
        attempts_slice_df = pd.merge(df, attempts_df, how="outer", on="limsSpecName")
        attempts_slice_df.drop(ps_array_name, axis=1, inplace=True)
        return attempts_slice_df
    except IndexError:
        pass

def is_field(df, colname):
    """Determine whether a column name exists in a dataframe.
    
    Parameters
    ----------
    df : a Pandas dataframe
    colname : string
        
    Returns
    -------
    Boolean
        Boolean value indicating if the colname exists in the dataframe.
    """
    
    try:
        df[colname]
        return True
    except KeyError:
        return False

# %% [markdown]
# ### json_df

# %%
json_df = pd.DataFrame()

for json_path in json_list:
    with open(json_path) as data_file:
        slice_info = json.load(data_file)
        if is_field(slice_info, "formVersion"):
            jem_version = slice_info["formVersion"]
        else:
            jem_version = "1.0.0"
        flat_df = flatten_attempts(slice_info, jem_version)
        json_df = pd.concat([json_df, flat_df], axis=0)
        
json_df.head()
# Out:
#   acsfProductionDate approach.anatomicalLocation approach.autoRoi  \
# 0         2018-04-18                         NaN              NaN
# 1         2018-04-18                         NaN              NaN
# 2         2018-04-18                         NaN              NaN
# 3         2018-04-18                         NaN              NaN
# 4         2018-04-18                         NaN              NaN
#
#   approach.cellHealth approach.corticalLayer approach.creCell  approach.depth  \
# 0                   3                    NaN             Cre+             NaN
# 1                   2                    NaN             Cre+             NaN
# 2                   2                    NaN             Cre+             NaN
# 3                   2                    NaN             Cre+             NaN
# 4                   2                    NaN             Cre+             NaN
#
#   approach.detailedLocation approach.manualRoi approach.otherPilotName  \
# 0                       NaN                NaN                     NaN
# 1                       NaN                NaN                     NaN
# 2                       NaN                NaN                     NaN
# 3                       NaN                NaN                     NaN
# 4                       NaN                NaN                     NaN
#
#   approach.pilotName approach.pilotTest01 approach.pilotTest03  \
# 0               None                  NaN                  NaN
# 1               None                  NaN                  NaN
# 2               None                  NaN                  NaN
# 3               None                  NaN                  NaN
# 4               None                  NaN                  NaN
#
#   approach.pilotTest04 approach.pilotTest05 approach.sliceHealth  attempt  \
# 0                  NaN                  NaN                    2      1.0
# 1                  NaN                  NaN                    2      2.0
# 2                  NaN                  NaN                    2      3.0
# 3                  NaN                  NaN                    2      4.0
# 4                  NaN                  NaN                    2      5.0
#
#   autoRoi badSweeps blankFillDate                        date depth  \
# 0    None       NaN    2018-03-22  2018-04-18 13:17:02 -07:00   -50
# 1    None       NaN    2018-03-22  2018-04-18 13:17:02 -07:00   -50
# 2    None       NaN    2018-03-22  2018-04-18 13:17:02 -07:00   -50
# 3    None       NaN    2018-03-22  2018-04-18 13:17:02 -07:00   -50
# 4    None       NaN    2018-03-22  2018-04-18 13:17:02 -07:00   -50
#
#   experimentType extraction.bfiWitness extraction.endPipetteR  \
# 0            NaN                   NaN                   1000
# 1            NaN                   NaN                   1000
# 2            NaN                   NaN                   1000
# 3            NaN                   NaN                   1000
# 4            NaN                   NaN                   1000
#
#   extraction.extractionNotes extraction.extractionObservations  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                        NaN                               NaN
# 4                        NaN                               NaN
#
#   extraction.nucleus extraction.postPatch  extraction.pressureApplied  \
# 0                 no       nucleus_absent                       -80.0
# 1                NaN      nucleus_present                       -80.0
# 2                 no       nucleus_absent                       -80.0
# 3  not_intentionally      nucleus_present                       -80.0
# 4                NaN       nucleus_absent                       -80.0
#
#    extraction.retractionPressureApplied extraction.sampleObservations  \
# 0                                 -80.0                           NaN
# 1                                 -80.0                           NaN
# 2                                 -80.0                           NaN
# 3                                 -80.0                           NaN
# 4                                 -80.0                           NaN
#
#   extraction.timeEnd extraction.timeExtractionEnd  \
# 0                NaN              13:20:14 -07:00
# 1                NaN              13:21:44 -07:00
# 2                NaN              13:22:39 -07:00
# 3                NaN              13:23:59 -07:00
# 4                NaN              13:25:01 -07:00
#
#   extraction.timeExtractionStart extraction.timeRetractionEnd  \
# 0                13:20:13 -07:00              13:20:14 -07:00
# 1                13:21:44 -07:00              13:21:45 -07:00
# 2                13:22:38 -07:00              13:22:39 -07:00
# 3                13:23:58 -07:00              13:23:59 -07:00
# 4                13:25:01 -07:00              13:25:01 -07:00
#
#   extraction.timeRetractionStart    extraction.tubeID failureCause  \
# 0                            NaN  PXS4_180418_551_A01          NaN
# 1                            NaN  PXS4_180418_552_A01          NaN
# 2                            NaN  PXS4_180418_553_A01          NaN
# 3                            NaN  PXS4_180418_554_A01          NaN
# 4                            NaN  PXS4_180418_555_A01          NaN
#
#   failureNotes flipped formVersion freeFailureNotes internalFillDate  \
# 0          NaN      No       2.0.3              NaN       2018-03-29
# 1          NaN      No       2.0.3              NaN       2018-03-29
# 2          NaN      No       2.0.3              NaN       2018-03-29
# 3          NaN      No       2.0.3              NaN       2018-03-29
# 4          NaN      No       2.0.3              NaN       2018-03-29
#
#    internalSolution.concentrationAlexa  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    internalSolution.concentrationBiocytin  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   internalSolution.concentrationRnaseInhibitor internalSolution.version  \
# 0                                          NaN                      NaN
# 1                                          NaN                      NaN
# 2                                          NaN                      NaN
# 3                                          NaN                      NaN
# 4                                          NaN                      NaN
#
#    internalSolution.volume                                       limsSpecName  \
# 0                      NaN  Sim1-Cre_KJ18;Ai139;Sst-IRES-FlpO;Ai65F-386176...
# 1                      NaN  Sim1-Cre_KJ18;Ai139;Sst-IRES-FlpO;Ai65F-386176...
# 2                      NaN  Sim1-Cre_KJ18;Ai139;Sst-IRES-FlpO;Ai65F-386176...
# 3                      NaN  Sim1-Cre_KJ18;Ai139;Sst-IRES-FlpO;Ai65F-386176...
# 4                      NaN  Sim1-Cre_KJ18;Ai139;Sst-IRES-FlpO;Ai65F-386176...
#
#   manualRoi pipetteSpecName qcNotes recording.accessR  \
# 0     VISp5             NaN     NaN               NaN
# 1     VISp5             NaN     NaN               NaN
# 2     VISp5             NaN     NaN               NaN
# 3     VISp5             NaN     NaN               NaN
# 4     VISp5             NaN     NaN               NaN
#
#   recording.humanCellTypePrediction recording.membraneV recording.pipetteR  \
# 0                               NaN                 NaN                  6
# 1                               NaN                 NaN                  6
# 2                               NaN                 NaN                  6
# 3                               NaN                 NaN                  6
# 4                               NaN                 NaN                  6
#
#   recording.rheobase recording.timeStart recording.timeWholeCellStart  \
# 0                NaN     13:19:59 -07:00              13:20:00 -07:00
# 1                NaN     13:21:26 -07:00              13:21:31 -07:00
# 2                NaN     13:22:25 -07:00              13:22:27 -07:00
# 3                NaN     13:23:04 -07:00              13:23:09 -07:00
# 4                NaN     13:24:37 -07:00              13:24:40 -07:00
#
#   rigNumber rigOperator sliceNotes sliceQuality   status successNotes wellID
# 0       MP2      pashad        NaN      Damaged  SUCCESS          NaN    NaN
# 1       MP2      pashad        NaN      Damaged  SUCCESS          NaN    NaN
# 2       MP2      pashad        NaN      Damaged  SUCCESS          NaN    NaN
# 3       MP2      pashad        NaN      Damaged  SUCCESS          NaN    NaN
# 4       MP2      pashad        NaN      Damaged  SUCCESS          NaN    NaN

# %% [markdown]
# ### Date column & include post_patch column

# %%
json_df['date'] = json_df['date'].str[:10] #Strip away the time
json_df['date'] = pd.to_datetime(json_df['date']) #Converting to YYYY-MM-DD
json_df.set_index('date', inplace = True)

# %%
json_df = postpatch_reclass(json_df) #Makes post patch column

# %% [markdown]
# ### Creating new dataframe based on date start selection

# %%
#['Start date' : 'End date'] & Production Start Date = '2017-10-01' 
start_date = input('Enter the start date for your dataframe (YYYY-MM-DD): ')
json_df1 = json_df[start_date:]

json_df1.sort_index(inplace = True)
json_df1 = gen_fil(json_df1, 'status', 'SUCCESS')
# Out:
# Enter the start date for your dataframe (YYYY-MM-DD): 2017-10-01

# %%
json_df1.head()
# Out:
#            acsfProductionDate approach.anatomicalLocation approach.autoRoi  \
# date
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
#
#            approach.cellHealth approach.corticalLayer approach.creCell  \
# date
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
#
#             approach.depth approach.detailedLocation approach.manualRoi  \
# date
# 2017-10-02             NaN                       NaN      VISp, layer 5
# 2017-10-02             NaN                       NaN      VISp, layer 5
# 2017-10-02             NaN                       NaN     VISp, layer 6a
# 2017-10-02             NaN                       NaN      VISp, layer 4
# 2017-10-02             NaN                       NaN      VISp, layer 5
#
#            approach.otherPilotName                     approach.pilotName  \
# date
# 2017-10-02                     NaN  Nucleated Patch - Retraction Pressure
# 2017-10-02                     NaN                                   None
# 2017-10-02                     NaN                                   None
# 2017-10-02                     NaN  Nucleated Patch - Retraction Pressure
# 2017-10-02                     NaN                                   None
#
#            approach.pilotTest01 approach.pilotTest03 approach.pilotTest04  \
# date
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
#
#            approach.pilotTest05 approach.sliceHealth  attempt autoRoi  \
# date
# 2017-10-02                  NaN                    3      4.0     NaN
# 2017-10-02                  NaN                    3      1.0     NaN
# 2017-10-02                  NaN                    2      4.0     NaN
# 2017-10-02                  NaN                    3      1.0     NaN
# 2017-10-02                  NaN                    2      2.0     NaN
#
#            badSweeps blankFillDate depth experimentType extraction.bfiWitness  \
# date
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
#
#            extraction.endPipetteR  \
# date
# 2017-10-02                   1000
# 2017-10-02                   3000
# 2017-10-02                   16.2
# 2017-10-02                     10
# 2017-10-02                     30
#
#                                    extraction.extractionNotes  \
# date
# 2017-10-02                                                NaN
# 2017-10-02  1.5 min retraction time. Can see alexa fill po...
# 2017-10-02                                                NaN
# 2017-10-02                                                NaN
# 2017-10-02                      No alexa fill post experiment
#
#                           extraction.extractionObservations  \
# date
# 2017-10-02                          Fluorescence in Pipette
# 2017-10-02  Fluorescence in Pipette,Cell Dimmed,Cell Shrunk
# 2017-10-02                                              NaN
# 2017-10-02                          Fluorescence in Pipette
# 2017-10-02  Fluorescence in Pipette,Cell Dimmed,Cell Shrunk
#
#            extraction.nucleus extraction.postPatch  \
# date
# 2017-10-02                 no      nucleus_present
# 2017-10-02                 no      nucleus_present
# 2017-10-02                 no       nucleus_absent
# 2017-10-02                 no       nucleus_absent
# 2017-10-02                 no       nucleus_absent
#
#             extraction.pressureApplied  extraction.retractionPressureApplied  \
# date
# 2017-10-02                       -32.0                                 -32.0
# 2017-10-02                       -30.0                                 -30.0
# 2017-10-02                       -30.0                                 -30.0
# 2017-10-02                       -32.5                                 -32.5
# 2017-10-02                       -30.0                                 -30.0
#
#                       extraction.sampleObservations extraction.timeEnd  \
# date
# 2017-10-02                               No Bubbles                NaN
# 2017-10-02                               No Bubbles                NaN
# 2017-10-02                               No Bubbles                NaN
# 2017-10-02  Large Bubbles,Solution in Pipette Shank                NaN
# 2017-10-02                               No Bubbles                NaN
#
#            extraction.timeExtractionEnd extraction.timeExtractionStart  \
# date
# 2017-10-02                     15:43:26                       15:42:58
# 2017-10-02                     15:24:14                       15:22:54
# 2017-10-02                     15:56:38                       15:56:04
# 2017-10-02                     14:48:35                       14:47:57
# 2017-10-02                     15:56:10                       15:55:26
#
#            extraction.timeRetractionEnd extraction.timeRetractionStart  \
# date
# 2017-10-02                     15:45:24                       15:43:27
# 2017-10-02                     15:25:49                       15:24:15
# 2017-10-02                     15:58:43                       15:56:39
# 2017-10-02                     14:51:55                       14:48:36
# 2017-10-02                     16:01:35                       15:56:11
#
#            extraction.tubeID failureCause failureNotes flipped formVersion  \
# date
# 2017-10-02               055          NaN          NaN     Yes       2.0.0
# 2017-10-02               356          NaN          NaN     Yes       2.0.0
# 2017-10-02               406          NaN          NaN     Yes       2.0.0
# 2017-10-02               053          NaN          NaN     Yes       2.0.0
# 2017-10-02               357          NaN          NaN     Yes       2.0.0
#
#            freeFailureNotes internalFillDate  \
# date
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
#
#             internalSolution.concentrationAlexa  \
# date
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
#
#             internalSolution.concentrationBiocytin  \
# date
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
#
#            internalSolution.concentrationRnaseInhibitor  \
# date
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
#
#            internalSolution.version  internalSolution.volume  \
# date
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
#
#                                  limsSpecName manualRoi pipetteSpecName  \
# date
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.04.01       NaN             NaN
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.03.02       NaN             NaN
# 2017-10-02    Gad2-IRES-Cre;Ai14-350672.04.01       NaN             NaN
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.04.01       NaN             NaN
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.03.02       NaN             NaN
#
#            qcNotes recording.accessR recording.humanCellTypePrediction  \
# date
# 2017-10-02     NaN               NaN                               NaN
# 2017-10-02     NaN               NaN                               NaN
# 2017-10-02     NaN               NaN                               NaN
# 2017-10-02     NaN               NaN                               NaN
# 2017-10-02     NaN               NaN                               NaN
#
#            recording.membraneV recording.pipetteR recording.rheobase  \
# date
# 2017-10-02                 NaN                  5                NaN
# 2017-10-02                 NaN                5.3                NaN
# 2017-10-02                 NaN                6.0                NaN
# 2017-10-02                 NaN                  5                NaN
# 2017-10-02                 NaN                5.5                NaN
#
#            recording.timeStart recording.timeWholeCellStart rigNumber  \
# date
# 2017-10-02            15:37:03                     15:38:40         5
# 2017-10-02            15:14:50                     15:16:11         7
# 2017-10-02            15:50:28                     15:51:06         6
# 2017-10-02            14:41:05                     14:42:42         5
# 2017-10-02            15:46:38                     15:47:49         7
#
#            rigOperator sliceNotes sliceQuality   status  \
# date
# 2017-10-02      rustym        NaN          NaN  SUCCESS
# 2017-10-02    lindsayn        NaN          NaN  SUCCESS
# 2017-10-02       lisak        NaN          NaN  SUCCESS
# 2017-10-02      rustym        NaN          NaN  SUCCESS
# 2017-10-02    lindsayn        NaN          NaN  SUCCESS
#
#                            successNotes                 wellID     post_patch
# date
# 2017-10-02                          NaN  EPhys_171002_01_B03_M  Nuc-high seal
# 2017-10-02                          NaN  EPhys_171002_01_B02_M  Nuc-high seal
# 2017-10-02  Access Resistance Increased  EPhys_171002_01_B01_M   No-high seal
# 2017-10-02                          NaN  EPhys_171002_01_B03_M   No-high seal
# 2017-10-02                          NaN  EPhys_171002_01_B02_M   No-high seal

# %% [markdown]
# ### Create a filter for Human & Mouse dataframe

# %%
json_df1['human?'] = json_df1['limsSpecName'].str.match(r"H\d\d") #Creates new boolean column

json_df2 = gen_fil(json_df1, 'human?', True) #HUMAN
json_df3 = gen_fil(json_df1, 'human?', False) #MOUSE
json_df1.head()

#json_df2 = json_df1[json_df1['limsSpecName'].str.match('H1')] #Human
#json_df3 = json_df1[json_df1['limsSpecName'] != 'H'] #Mouse
# Out:
#            acsfProductionDate approach.anatomicalLocation approach.autoRoi  \
# date
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
#
#            approach.cellHealth approach.corticalLayer approach.creCell  \
# date
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
#
#             approach.depth approach.detailedLocation approach.manualRoi  \
# date
# 2017-10-02             NaN                       NaN      VISp, layer 5
# 2017-10-02             NaN                       NaN      VISp, layer 5
# 2017-10-02             NaN                       NaN     VISp, layer 6a
# 2017-10-02             NaN                       NaN      VISp, layer 4
# 2017-10-02             NaN                       NaN      VISp, layer 5
#
#            approach.otherPilotName                     approach.pilotName  \
# date
# 2017-10-02                     NaN  Nucleated Patch - Retraction Pressure
# 2017-10-02                     NaN                                   None
# 2017-10-02                     NaN                                   None
# 2017-10-02                     NaN  Nucleated Patch - Retraction Pressure
# 2017-10-02                     NaN                                   None
#
#            approach.pilotTest01 approach.pilotTest03 approach.pilotTest04  \
# date
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
#
#            approach.pilotTest05 approach.sliceHealth  attempt autoRoi  \
# date
# 2017-10-02                  NaN                    3      4.0     NaN
# 2017-10-02                  NaN                    3      1.0     NaN
# 2017-10-02                  NaN                    2      4.0     NaN
# 2017-10-02                  NaN                    3      1.0     NaN
# 2017-10-02                  NaN                    2      2.0     NaN
#
#            badSweeps blankFillDate depth experimentType extraction.bfiWitness  \
# date
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
#
#            extraction.endPipetteR  \
# date
# 2017-10-02                   1000
# 2017-10-02                   3000
# 2017-10-02                   16.2
# 2017-10-02                     10
# 2017-10-02                     30
#
#                                    extraction.extractionNotes  \
# date
# 2017-10-02                                                NaN
# 2017-10-02  1.5 min retraction time. Can see alexa fill po...
# 2017-10-02                                                NaN
# 2017-10-02                                                NaN
# 2017-10-02                      No alexa fill post experiment
#
#                           extraction.extractionObservations  \
# date
# 2017-10-02                          Fluorescence in Pipette
# 2017-10-02  Fluorescence in Pipette,Cell Dimmed,Cell Shrunk
# 2017-10-02                                              NaN
# 2017-10-02                          Fluorescence in Pipette
# 2017-10-02  Fluorescence in Pipette,Cell Dimmed,Cell Shrunk
#
#            extraction.nucleus extraction.postPatch  \
# date
# 2017-10-02                 no      nucleus_present
# 2017-10-02                 no      nucleus_present
# 2017-10-02                 no       nucleus_absent
# 2017-10-02                 no       nucleus_absent
# 2017-10-02                 no       nucleus_absent
#
#             extraction.pressureApplied  extraction.retractionPressureApplied  \
# date
# 2017-10-02                       -32.0                                 -32.0
# 2017-10-02                       -30.0                                 -30.0
# 2017-10-02                       -30.0                                 -30.0
# 2017-10-02                       -32.5                                 -32.5
# 2017-10-02                       -30.0                                 -30.0
#
#                       extraction.sampleObservations extraction.timeEnd  \
# date
# 2017-10-02                               No Bubbles                NaN
# 2017-10-02                               No Bubbles                NaN
# 2017-10-02                               No Bubbles                NaN
# 2017-10-02  Large Bubbles,Solution in Pipette Shank                NaN
# 2017-10-02                               No Bubbles                NaN
#
#            extraction.timeExtractionEnd extraction.timeExtractionStart  \
# date
# 2017-10-02                     15:43:26                       15:42:58
# 2017-10-02                     15:24:14                       15:22:54
# 2017-10-02                     15:56:38                       15:56:04
# 2017-10-02                     14:48:35                       14:47:57
# 2017-10-02                     15:56:10                       15:55:26
#
#            extraction.timeRetractionEnd extraction.timeRetractionStart  \
# date
# 2017-10-02                     15:45:24                       15:43:27
# 2017-10-02                     15:25:49                       15:24:15
# 2017-10-02                     15:58:43                       15:56:39
# 2017-10-02                     14:51:55                       14:48:36
# 2017-10-02                     16:01:35                       15:56:11
#
#            extraction.tubeID failureCause failureNotes flipped formVersion  \
# date
# 2017-10-02               055          NaN          NaN     Yes       2.0.0
# 2017-10-02               356          NaN          NaN     Yes       2.0.0
# 2017-10-02               406          NaN          NaN     Yes       2.0.0
# 2017-10-02               053          NaN          NaN     Yes       2.0.0
# 2017-10-02               357          NaN          NaN     Yes       2.0.0
#
#            freeFailureNotes internalFillDate  \
# date
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
#
#             internalSolution.concentrationAlexa  \
# date
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
#
#             internalSolution.concentrationBiocytin  \
# date
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
#
#            internalSolution.concentrationRnaseInhibitor  \
# date
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
#
#            internalSolution.version  internalSolution.volume  \
# date
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
#
#                                  limsSpecName manualRoi pipetteSpecName  \
# date
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.04.01       NaN             NaN
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.03.02       NaN             NaN
# 2017-10-02    Gad2-IRES-Cre;Ai14-350672.04.01       NaN             NaN
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.04.01       NaN             NaN
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.03.02       NaN             NaN
#
#            qcNotes recording.accessR recording.humanCellTypePrediction  \
# date
# 2017-10-02     NaN               NaN                               NaN
# 2017-10-02     NaN               NaN                               NaN
# 2017-10-02     NaN               NaN                               NaN
# 2017-10-02     NaN               NaN                               NaN
# 2017-10-02     NaN               NaN                               NaN
#
#            recording.membraneV recording.pipetteR recording.rheobase  \
# date
# 2017-10-02                 NaN                  5                NaN
# 2017-10-02                 NaN                5.3                NaN
# 2017-10-02                 NaN                6.0                NaN
# 2017-10-02                 NaN                  5                NaN
# 2017-10-02                 NaN                5.5                NaN
#
#            recording.timeStart recording.timeWholeCellStart rigNumber  \
# date
# 2017-10-02            15:37:03                     15:38:40         5
# 2017-10-02            15:14:50                     15:16:11         7
# 2017-10-02            15:50:28                     15:51:06         6
# 2017-10-02            14:41:05                     14:42:42         5
# 2017-10-02            15:46:38                     15:47:49         7
#
#            rigOperator sliceNotes sliceQuality   status  \
# date
# 2017-10-02      rustym        NaN          NaN  SUCCESS
# 2017-10-02    lindsayn        NaN          NaN  SUCCESS
# 2017-10-02       lisak        NaN          NaN  SUCCESS
# 2017-10-02      rustym        NaN          NaN  SUCCESS
# 2017-10-02    lindsayn        NaN          NaN  SUCCESS
#
#                            successNotes                 wellID     post_patch  \
# date
# 2017-10-02                          NaN  EPhys_171002_01_B03_M  Nuc-high seal
# 2017-10-02                          NaN  EPhys_171002_01_B02_M  Nuc-high seal
# 2017-10-02  Access Resistance Increased  EPhys_171002_01_B01_M   No-high seal
# 2017-10-02                          NaN  EPhys_171002_01_B03_M   No-high seal
# 2017-10-02                          NaN  EPhys_171002_01_B02_M   No-high seal
#
#             human?
# date
# 2017-10-02   False
# 2017-10-02   False
# 2017-10-02   False
# 2017-10-02   False
# 2017-10-02   False

# %%
#Human
json_df2.head()
# Out:
#            acsfProductionDate approach.anatomicalLocation approach.autoRoi  \
# date
# 2017-10-10         10/09/2017                         NaN             None
# 2017-10-10         10/09/2017                         NaN             None
# 2017-10-10         10/09/2017                         NaN             None
# 2017-10-10         10/09/2017                         NaN             None
# 2017-10-10         10/09/2017                         NaN             None
#
#            approach.cellHealth approach.corticalLayer approach.creCell  \
# date
# 2017-10-10                 NaN                    NaN             None
# 2017-10-10                 NaN                    NaN             None
# 2017-10-10                 NaN                    NaN             None
# 2017-10-10                 NaN                    NaN             None
# 2017-10-10                 NaN                    NaN             None
#
#             approach.depth approach.detailedLocation approach.manualRoi  \
# date
# 2017-10-10             NaN                       NaN       TCx, layer 3
# 2017-10-10             NaN                       NaN       TCx, layer 3
# 2017-10-10             NaN                       NaN    VISp, layer 2/3
# 2017-10-10             NaN                       NaN       TCx, layer 3
# 2017-10-10             NaN                       NaN       TCx, layer 3
#
#            approach.otherPilotName approach.pilotName approach.pilotTest01  \
# date
# 2017-10-10                     NaN               None                  NaN
# 2017-10-10                     NaN               None                  NaN
# 2017-10-10                     NaN               None                  NaN
# 2017-10-10                     NaN               None                  NaN
# 2017-10-10                     NaN               None                  NaN
#
#            approach.pilotTest03 approach.pilotTest04 approach.pilotTest05  \
# date
# 2017-10-10                  NaN                  NaN                  NaN
# 2017-10-10                  NaN                  NaN                  NaN
# 2017-10-10                  NaN                  NaN                  NaN
# 2017-10-10                  NaN                  NaN                  NaN
# 2017-10-10                  NaN                  NaN                  NaN
#
#            approach.sliceHealth  attempt autoRoi badSweeps blankFillDate  \
# date
# 2017-10-10                    3      7.0     NaN       NaN    09/25/2017
# 2017-10-10                    2      6.0     NaN       NaN    09/25/2017
# 2017-10-10                    3      3.0     NaN      4-14    09/25/2017
# 2017-10-10                    2      5.0     NaN       NaN    09/25/2017
# 2017-10-10                    3      4.0     NaN       NaN    09/25/2017
#
#            depth experimentType extraction.bfiWitness extraction.endPipetteR  \
# date
# 2017-10-10   NaN            NaN                   NaN                     10
# 2017-10-10   NaN            NaN                   NaN                     10
# 2017-10-10   NaN            NaN                   NaN                   1400
# 2017-10-10   NaN            NaN                   NaN                      5
# 2017-10-10   NaN            NaN                   NaN                   1000
#
#                        extraction.extractionNotes  \
# date
# 2017-10-10    alexa fill visible post experiment.
# 2017-10-10  alexa fill visible post experiment.\n
# 2017-10-10                                    NaN
# 2017-10-10    alexa fill visible post experiment.
# 2017-10-10    alexa fill visible post experiment.
#
#            extraction.extractionObservations extraction.nucleus  \
# date
# 2017-10-10                               NaN                 no
# 2017-10-10                               NaN                 no
# 2017-10-10                               NaN                 no
# 2017-10-10                               NaN                 no
# 2017-10-10                               NaN                 no
#
#            extraction.postPatch  extraction.pressureApplied  \
# date
# 2017-10-10       nucleus_absent                       -30.0
# 2017-10-10       nucleus_absent                       -80.0
# 2017-10-10       nucleus_absent                       -32.0
# 2017-10-10       nucleus_absent                       -60.0
# 2017-10-10       nucleus_absent                       -50.0
#
#             extraction.retractionPressureApplied  \
# date
# 2017-10-10                                 -50.0
# 2017-10-10                                 -80.0
# 2017-10-10                                 -32.0
# 2017-10-10                                 -80.0
# 2017-10-10                                 -50.0
#
#            extraction.sampleObservations extraction.timeEnd  \
# date
# 2017-10-10                    No Bubbles                NaN
# 2017-10-10                Medium Bubbles                NaN
# 2017-10-10                           NaN                NaN
# 2017-10-10                 Large Bubbles                NaN
# 2017-10-10                    No Bubbles                NaN
#
#            extraction.timeExtractionEnd extraction.timeExtractionStart  \
# date
# 2017-10-10                     18:29:42                       18:29:04
# 2017-10-10                     21:17:16                       21:16:36
# 2017-10-10                     19:56:42                       19:55:33
# 2017-10-10                     20:44:24                       20:43:44
# 2017-10-10                     20:13:41                       20:12:54
#
#            extraction.timeRetractionEnd extraction.timeRetractionStart  \
# date
# 2017-10-10                     18:35:07                       18:29:42
# 2017-10-10                     21:20:36                       21:17:18
# 2017-10-10                     19:56:48                       19:56:48
# 2017-10-10                     20:49:21                       20:44:24
# 2017-10-10                     20:16:52                       20:13:41
#
#            extraction.tubeID failureCause failureNotes flipped formVersion  \
# date
# 2017-10-10               056          NaN          NaN      No       2.0.0
# 2017-10-10               060          NaN          NaN      No       2.0.0
# 2017-10-10               507          NaN          NaN      No       2.0.0
# 2017-10-10               059          NaN          NaN      No       2.0.0
# 2017-10-10               058          NaN          NaN      No       2.0.0
#
#            freeFailureNotes internalFillDate  \
# date
# 2017-10-10              NaN       09/29/2017
# 2017-10-10              NaN       09/29/2017
# 2017-10-10              NaN       09/29/2017
# 2017-10-10              NaN       09/29/2017
# 2017-10-10              NaN       09/29/2017
#
#             internalSolution.concentrationAlexa  \
# date
# 2017-10-10                                  NaN
# 2017-10-10                                  NaN
# 2017-10-10                                  NaN
# 2017-10-10                                  NaN
# 2017-10-10                                  NaN
#
#             internalSolution.concentrationBiocytin  \
# date
# 2017-10-10                                     NaN
# 2017-10-10                                     NaN
# 2017-10-10                                     NaN
# 2017-10-10                                     NaN
# 2017-10-10                                     NaN
#
#            internalSolution.concentrationRnaseInhibitor  \
# date
# 2017-10-10                                          NaN
# 2017-10-10                                          NaN
# 2017-10-10                                          NaN
# 2017-10-10                                          NaN
# 2017-10-10                                          NaN
#
#            internalSolution.version  internalSolution.volume  \
# date
# 2017-10-10                      NaN                      NaN
# 2017-10-10                      NaN                      NaN
# 2017-10-10                      NaN                      NaN
# 2017-10-10                      NaN                      NaN
# 2017-10-10                      NaN                      NaN
#
#                 limsSpecName manualRoi pipetteSpecName qcNotes  \
# date
# 2017-10-10  H17.03.014.11.10       NaN             NaN     NaN
# 2017-10-10  H17.03.014.11.10       NaN             NaN     NaN
# 2017-10-10  H17.03.014.11.04       NaN             NaN     NaN
# 2017-10-10  H17.03.014.11.10       NaN             NaN     NaN
# 2017-10-10  H17.03.014.11.10       NaN             NaN     NaN
#
#            recording.accessR recording.humanCellTypePrediction  \
# date
# 2017-10-10               NaN                               NaN
# 2017-10-10               NaN                         Pyramidal
# 2017-10-10               NaN                               NaN
# 2017-10-10               NaN               Unknown Interneuron
# 2017-10-10               NaN               Unknown Interneuron
#
#            recording.membraneV recording.pipetteR recording.rheobase  \
# date
# 2017-10-10                 NaN                4.8                NaN
# 2017-10-10                 NaN                3.4                NaN
# 2017-10-10                 NaN                4.3                NaN
# 2017-10-10                 NaN                3.7                NaN
# 2017-10-10                 NaN                4.1                NaN
#
#            recording.timeStart recording.timeWholeCellStart rigNumber  \
# date
# 2017-10-10            18:19:05                     18:20:42         7
# 2017-10-10            21:04:54                     21:06:49         7
# 2017-10-10            19:42:22                     19:44:00         4
# 2017-10-10            20:33:08                     20:35:46         7
# 2017-10-10            20:02:42                     20:04:05         7
#
#            rigOperator sliceNotes sliceQuality   status successNotes  \
# date
# 2017-10-10      rustym        NaN          NaN  SUCCESS          NaN
# 2017-10-10      rustym        NaN          NaN  SUCCESS          NaN
# 2017-10-10      dijonh        NaN          NaN  SUCCESS          NaN
# 2017-10-10      rustym        NaN          NaN  SUCCESS          NaN
# 2017-10-10      rustym        NaN          NaN  SUCCESS          NaN
#
#                            wellID    post_patch  human?
# date
# 2017-10-10  EPhys_171009_03_A03_H  No-high seal    True
# 2017-10-10  EPhys_171009_03_A03_H  No-high seal    True
# 2017-10-10  Ephys_171009_03_A02_H  No-high seal    True
# 2017-10-10  EPhys_171009_03_A03_H  No-high seal    True
# 2017-10-10  EPhys_171009_03_A03_H  No-high seal    True

# %%
#Mouse
json_df3.head()
# Out:
#            acsfProductionDate approach.anatomicalLocation approach.autoRoi  \
# date
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
#
#            approach.cellHealth approach.corticalLayer approach.creCell  \
# date
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
#
#             approach.depth approach.detailedLocation approach.manualRoi  \
# date
# 2017-10-02             NaN                       NaN      VISp, layer 5
# 2017-10-02             NaN                       NaN      VISp, layer 5
# 2017-10-02             NaN                       NaN     VISp, layer 6a
# 2017-10-02             NaN                       NaN      VISp, layer 4
# 2017-10-02             NaN                       NaN      VISp, layer 5
#
#            approach.otherPilotName                     approach.pilotName  \
# date
# 2017-10-02                     NaN  Nucleated Patch - Retraction Pressure
# 2017-10-02                     NaN                                   None
# 2017-10-02                     NaN                                   None
# 2017-10-02                     NaN  Nucleated Patch - Retraction Pressure
# 2017-10-02                     NaN                                   None
#
#            approach.pilotTest01 approach.pilotTest03 approach.pilotTest04  \
# date
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
#
#            approach.pilotTest05 approach.sliceHealth  attempt autoRoi  \
# date
# 2017-10-02                  NaN                    3      4.0     NaN
# 2017-10-02                  NaN                    3      1.0     NaN
# 2017-10-02                  NaN                    2      4.0     NaN
# 2017-10-02                  NaN                    3      1.0     NaN
# 2017-10-02                  NaN                    2      2.0     NaN
#
#            badSweeps blankFillDate depth experimentType extraction.bfiWitness  \
# date
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
#
#            extraction.endPipetteR  \
# date
# 2017-10-02                   1000
# 2017-10-02                   3000
# 2017-10-02                   16.2
# 2017-10-02                     10
# 2017-10-02                     30
#
#                                    extraction.extractionNotes  \
# date
# 2017-10-02                                                NaN
# 2017-10-02  1.5 min retraction time. Can see alexa fill po...
# 2017-10-02                                                NaN
# 2017-10-02                                                NaN
# 2017-10-02                      No alexa fill post experiment
#
#                           extraction.extractionObservations  \
# date
# 2017-10-02                          Fluorescence in Pipette
# 2017-10-02  Fluorescence in Pipette,Cell Dimmed,Cell Shrunk
# 2017-10-02                                              NaN
# 2017-10-02                          Fluorescence in Pipette
# 2017-10-02  Fluorescence in Pipette,Cell Dimmed,Cell Shrunk
#
#            extraction.nucleus extraction.postPatch  \
# date
# 2017-10-02                 no      nucleus_present
# 2017-10-02                 no      nucleus_present
# 2017-10-02                 no       nucleus_absent
# 2017-10-02                 no       nucleus_absent
# 2017-10-02                 no       nucleus_absent
#
#             extraction.pressureApplied  extraction.retractionPressureApplied  \
# date
# 2017-10-02                       -32.0                                 -32.0
# 2017-10-02                       -30.0                                 -30.0
# 2017-10-02                       -30.0                                 -30.0
# 2017-10-02                       -32.5                                 -32.5
# 2017-10-02                       -30.0                                 -30.0
#
#                       extraction.sampleObservations extraction.timeEnd  \
# date
# 2017-10-02                               No Bubbles                NaN
# 2017-10-02                               No Bubbles                NaN
# 2017-10-02                               No Bubbles                NaN
# 2017-10-02  Large Bubbles,Solution in Pipette Shank                NaN
# 2017-10-02                               No Bubbles                NaN
#
#            extraction.timeExtractionEnd extraction.timeExtractionStart  \
# date
# 2017-10-02                     15:43:26                       15:42:58
# 2017-10-02                     15:24:14                       15:22:54
# 2017-10-02                     15:56:38                       15:56:04
# 2017-10-02                     14:48:35                       14:47:57
# 2017-10-02                     15:56:10                       15:55:26
#
#            extraction.timeRetractionEnd extraction.timeRetractionStart  \
# date
# 2017-10-02                     15:45:24                       15:43:27
# 2017-10-02                     15:25:49                       15:24:15
# 2017-10-02                     15:58:43                       15:56:39
# 2017-10-02                     14:51:55                       14:48:36
# 2017-10-02                     16:01:35                       15:56:11
#
#            extraction.tubeID failureCause failureNotes flipped formVersion  \
# date
# 2017-10-02               055          NaN          NaN     Yes       2.0.0
# 2017-10-02               356          NaN          NaN     Yes       2.0.0
# 2017-10-02               406          NaN          NaN     Yes       2.0.0
# 2017-10-02               053          NaN          NaN     Yes       2.0.0
# 2017-10-02               357          NaN          NaN     Yes       2.0.0
#
#            freeFailureNotes internalFillDate  \
# date
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
#
#             internalSolution.concentrationAlexa  \
# date
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
#
#             internalSolution.concentrationBiocytin  \
# date
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
#
#            internalSolution.concentrationRnaseInhibitor  \
# date
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
#
#            internalSolution.version  internalSolution.volume  \
# date
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
#
#                                  limsSpecName manualRoi pipetteSpecName  \
# date
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.04.01       NaN             NaN
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.03.02       NaN             NaN
# 2017-10-02    Gad2-IRES-Cre;Ai14-350672.04.01       NaN             NaN
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.04.01       NaN             NaN
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.03.02       NaN             NaN
#
#            qcNotes recording.accessR recording.humanCellTypePrediction  \
# date
# 2017-10-02     NaN               NaN                               NaN
# 2017-10-02     NaN               NaN                               NaN
# 2017-10-02     NaN               NaN                               NaN
# 2017-10-02     NaN               NaN                               NaN
# 2017-10-02     NaN               NaN                               NaN
#
#            recording.membraneV recording.pipetteR recording.rheobase  \
# date
# 2017-10-02                 NaN                  5                NaN
# 2017-10-02                 NaN                5.3                NaN
# 2017-10-02                 NaN                6.0                NaN
# 2017-10-02                 NaN                  5                NaN
# 2017-10-02                 NaN                5.5                NaN
#
#            recording.timeStart recording.timeWholeCellStart rigNumber  \
# date
# 2017-10-02            15:37:03                     15:38:40         5
# 2017-10-02            15:14:50                     15:16:11         7
# 2017-10-02            15:50:28                     15:51:06         6
# 2017-10-02            14:41:05                     14:42:42         5
# 2017-10-02            15:46:38                     15:47:49         7
#
#            rigOperator sliceNotes sliceQuality   status  \
# date
# 2017-10-02      rustym        NaN          NaN  SUCCESS
# 2017-10-02    lindsayn        NaN          NaN  SUCCESS
# 2017-10-02       lisak        NaN          NaN  SUCCESS
# 2017-10-02      rustym        NaN          NaN  SUCCESS
# 2017-10-02    lindsayn        NaN          NaN  SUCCESS
#
#                            successNotes                 wellID     post_patch  \
# date
# 2017-10-02                          NaN  EPhys_171002_01_B03_M  Nuc-high seal
# 2017-10-02                          NaN  EPhys_171002_01_B02_M  Nuc-high seal
# 2017-10-02  Access Resistance Increased  EPhys_171002_01_B01_M   No-high seal
# 2017-10-02                          NaN  EPhys_171002_01_B03_M   No-high seal
# 2017-10-02                          NaN  EPhys_171002_01_B02_M   No-high seal
#
#             human?
# date
# 2017-10-02   False
# 2017-10-02   False
# 2017-10-02   False
# 2017-10-02   False
# 2017-10-02   False

# %% [markdown]
# ### Create value counts to double check Human and Mouse dataframses

# %%
#json_df2['limsSpecName'].value_counts()

# %%
#json_df3['limsSpecName'].value_counts()

# %% [markdown]
# ## HUMAN dataframe

# %%
human_df = json_df2[['limsSpecName',
                     'rigOperator',
                     'approach.manualRoi',
                     'manualRoi', 
                     'recording.humanCellTypePrediction',
                     'post_patch',
                     'extraction.tubeID']]

human_df.sort_index(inplace = True)
#approach.manualRoi available data at 2017-10-10 to 2017-11-27
#manualRoi avaible data at 2017-11-27 to Present
#extraction.tubeID changes from ### to User_Date_###_A01 at 2017-11-27

# %%
human_df.head()
# Out:
#                 limsSpecName rigOperator approach.manualRoi manualRoi  \
# date
# 2017-10-10  H17.03.014.11.10      rustym       TCx, layer 3       NaN
# 2017-10-10  H17.03.014.11.10      rustym       TCx, layer 3       NaN
# 2017-10-10  H17.03.014.11.04      dijonh    VISp, layer 2/3       NaN
# 2017-10-10  H17.03.014.11.10      rustym       TCx, layer 3       NaN
# 2017-10-10  H17.03.014.11.10      rustym       TCx, layer 3       NaN
#
#            recording.humanCellTypePrediction    post_patch extraction.tubeID
# date
# 2017-10-10                               NaN  No-high seal               056
# 2017-10-10                         Pyramidal  No-high seal               060
# 2017-10-10                               NaN  No-high seal               507
# 2017-10-10               Unknown Interneuron  No-high seal               059
# 2017-10-10               Unknown Interneuron  No-high seal               058

# %%
human_df.tail()
# Out:
#                    limsSpecName rigOperator approach.manualRoi manualRoi  \
# date
# 2018-05-22  H18.03.012.11.13.02      dijonh                NaN      TCx3
# 2018-05-22  H18.03.012.11.13.02      dijonh                NaN      TCx2
# 2018-05-22  H18.03.012.11.11.01    lindsayn                NaN      TCx2
# 2018-05-22  H18.03.012.11.13.02      dijonh                NaN      TCx3
# 2018-05-22  H18.03.012.11.13.02      dijonh                NaN      TCx3
#
#            recording.humanCellTypePrediction    post_patch  \
# date
# 2018-05-22                         Pyramidal   No-low seal
# 2018-05-22                    FS Interneuron   No-low seal
# 2018-05-22                         Pyramidal  No-high seal
# 2018-05-22                    FS Interneuron   No-low seal
# 2018-05-22                               NaN   No-low seal
#
#               extraction.tubeID
# date
# 2018-05-22  PBS4_180522_505_A01
# 2018-05-22  PBS4_180522_506_A01
# 2018-05-22  P8S4_180522_353_A01
# 2018-05-22  PBS4_180522_507_A01
# 2018-05-22  PBS4_180522_508_A01

# %%
human_df['post_patch'].value_counts()
# Out:
# No-low seal      123
# No-high seal     108
# Nuc-low seal      49
# Nuc-high seal     36
# Entire cell        3
# Name: post_patch, dtype: int64

# %% [markdown]
# ## MOUSE dataframe

# %%
mouse_df = json_df3[['limsSpecName',
                     'rigOperator',
                     'approach.manualRoi',
                     'manualRoi', 
                     'post_patch',
                     'extraction.tubeID']]

mouse_df.sort_index(inplace = True)
#approach.manualRoi available data at 2017-10-02 to 2017-11-10
#manualRoi avaible data at 2017-11-10 to Present
#extraction.tubeID changes from ### to User_Date_###_A01 at 2017-11-10

# %%
mouse_df.head()
# Out:
#                                  limsSpecName rigOperator approach.manualRoi  \
# date
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.04.01      rustym      VISp, layer 5
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.03.02    lindsayn      VISp, layer 5
# 2017-10-02    Gad2-IRES-Cre;Ai14-350672.04.01       lisak     VISp, layer 6a
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.04.01      rustym      VISp, layer 4
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.03.02    lindsayn      VISp, layer 5
#
#            manualRoi     post_patch extraction.tubeID
# date
# 2017-10-02       NaN  Nuc-high seal               055
# 2017-10-02       NaN  Nuc-high seal               356
# 2017-10-02       NaN   No-high seal               406
# 2017-10-02       NaN   No-high seal               053
# 2017-10-02       NaN   No-high seal               357

# %%
mouse_df.tail()
# Out:
#                                             limsSpecName rigOperator  \
# date
# 2018-05-24  Nos1-CreERT2;Sst-IRES-FlpO;Ai65-391574.03.02    lindsayn
# 2018-05-24  Nos1-CreERT2;Sst-IRES-FlpO;Ai65-391574.03.01      dijonh
# 2018-05-24             Htr3a-Cre_NO152;Ai14-390983.03.01       lisak
# 2018-05-24             Htr3a-Cre_NO152;Ai14-390983.03.01       lisak
# 2018-05-24  Nos1-CreERT2;Sst-IRES-FlpO;Ai65-391574.03.01      dijonh
#
#            approach.manualRoi manualRoi     post_patch    extraction.tubeID
# date
# 2018-05-24                NaN    VISp6a  Nuc-high seal  P8S4_180524_351_A01
# 2018-05-24                NaN     VISp4  Nuc-high seal  PBS4_180524_502_A01
# 2018-05-24                NaN     VISp4   No-high seal  P9S4_180524_404_A01
# 2018-05-24                NaN    VISp6a   No-high seal  P9S4_180524_405_A01
# 2018-05-24                NaN    VISp6a    No-low seal  PBS4_180524_501_A01

# %%
mouse_df['post_patch'].value_counts()
# Out:
# No-high seal     527
# No-low seal      434
# Nuc-high seal    312
# Nuc-low seal     282
# Entire cell       40
# Name: post_patch, dtype: int64
