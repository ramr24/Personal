# %% [markdown]
# # Lindsay's Script

# %%
import os
import pg8000          #pg8000 access SQL databases
import pandas as pd    #paandas will be needed to work in a dataframe
from pandas import ExcelWriter

# %%
#code from Agata
#these are nice functions to open LIMS, make a query and then close LIMS after

def _connect(user="limsreader", host="limsdb2", database="lims2", password="limsro", port=5432):
    conn = pg8000.connect(user=user, host=host, database=database, password=password, port=port)
    return conn, conn.cursor()

def _select(cursor, query):
    cursor.execute(query)
    columns = [ d[0] for d in cursor.description ]
    return [ dict(zip(columns, c)) for c in cursor.fetchall() ]

def limsquery(query, user="limsreader", host="limsdb2", database="lims2", password="limsro", port=5432):
    """A function that takes a string containing a SQL query, connects to the LIMS database and outputs the result."""
    conn, cursor = _connect(user, host, database, password, port)
    try:
        results = _select(cursor, query)
    finally:
        
        #THESE ARE IMPORTANT!!!!!!
        #Every query needs to be closed when done
        cursor.close()             
        conn.close()
    return results


#this last function will take our query results and put them in a dataframe so that they are easy to work with
def get_lims_dataframe(query):
    '''Return a dataframe with lims query'''
    result = limsquery(query)
    try:
        data_df = pd.DataFrame(data=result, columns=result[0].keys())
    except IndexError:
        print "Could not find results for your query."
        data_df = pd.DataFrame()
    return data_df

# %% [markdown]
# ### User Report

# %%
def user_df(P_number):
    """Saves an excel dataframe with all patched cells for a specified user in current directory.
     
    Parameters
    ----------
    P_number : A string. Corresponds to the user's P number in the form of P1, P2, P3, etc.
       
    Returns
    -------
    None
    """
    user = master_df[master_df["patched_cell_container"].str.contains(P_number)]
    user.sort_values("patched_cell_container", axis = 0, inplace = True)
    user = user.loc[:,['name', 'patched_cell_container','recording_date', 'rna_qc', 'go_no_go_63x', 'link_20x']]
    writer = pd.ExcelWriter('user_dataframe.xlsx')
    user.to_excel(writer,'Sheet1')
    return None

def cell_count(P_number, df):
    """Return the number of cells in a specified dataframe for a specified user.
     
    Parameters
    ----------
    P_number : A string. Corresponds to the user's P number in the form of P1, P2, P3, etc.
    df: a pandas dataframe
    
    Returns
    -------
    An integer cell number
    """
    user = df[df["patched_cell_container"].str.contains(P_number)]
    return user["patched_cell_container"].count()

def per_user(P_number):
    """Returns a summary of patcher metrics for a specified user.
     
    Parameters
    ----------
    P_number : A string. Corresponds to the user's P number in the form of P1, P2, P3, etc.
        
    Returns
    -------
    Returns None
    Prints a summary of patcher metrics, including total cells patched, cells that passed RNA seq QC, and QC pass percentage
    """
    print "Total cells patched:", cell_count(P_number,master_df)
    print "Cells that passed RNA seq QC:", cell_count(P_number,qcpass)
    print "QC pass percentage:", float((cell_count(P_number,qcpass)))/float((cell_count(P_number,master_df)))
    print "Cells imaged at 63x:", cell_count(P_number,imagego)

def gen_filter(df, col, cond):
    filtered = df[df[col] == cond]
    return filtered

# %%
query = """
WITH do_63x(cell_id, go) AS (SELECT DISTINCT cell.id, array_to_string(array_agg(DISTINCT tag.name), ' _AND_ ') 
FROM specimens cell JOIN ephys_roi_results err ON err.id = cell.ephys_roi_result_id 
JOIN specimen_tags_specimens sptagsp ON sptagsp.specimen_id = cell.id 
JOIN specimen_tags tag ON tag.id = sptagsp.specimen_tag_id AND tag.id in (602120185,602122082) 
GROUP BY cell.id ORDER BY 1), 
imgs20 AS (WITH tag_list AS (SELECT DISTINCT ims.id AS ims_id, imst.name AS tag FROM image_series ims 
JOIN image_series_image_series_tags ims2imst ON ims2imst.image_series_id = ims.id 
JOIN image_series_tags imst ON imst.id = ims2imst.image_series_tag_id 
ORDER BY 1,2) 
SELECT DISTINCT ims.id AS image_series_id, ims.workflow_state AS workflow_state, ims.specimen_id, 
ARRAY_TO_STRING(ARRAY_AGG(DISTINCT tag_list.tag), '_AND_') AS tags FROM image_series ims 
LEFT JOIN tag_list ON tag_list.ims_id = ims.id 
WHERE ims.type = 'FocalPlaneImageSeries' AND is_stack = false 
GROUP BY ims.id, ims.workflow_state, ims.specimen_id)
SELECT DISTINCT s.patched_cell_container, err.recording_date, do_63x.go AS go_no_go_63x, CASE WHEN ra.id IS NOT NULL THEN (CASE WHEN ra.failed = 't' THEN 'failed' ELSE 'passed' END) ELSE '' END AS rna_qc, s.name,
'=HYPERLINK("http://lims2/focal_plane_image_series?id=' || imgs20.image_series_id || '")' as link_20x
FROM specimens s 
LEFT JOIN projects proj ON s.project_id = proj.id 
LEFT JOIN do_63x ON do_63x.cell_id = s.id 
JOIN specimens slice ON s.parent_id = slice.id
LEFT JOIN ephys_roi_results err ON s.ephys_roi_result_id = err.id 
LEFT JOIN rna_amplification_inputs rai on rai.sample_id = s.id 
LEFT JOIN imgs20 ON slice.id = imgs20.specimen_id 
LEFT JOIN rna_amplifications ra on ra.id = rai.rna_amplification_id 
WHERE proj.code <> 'mMPATCH' AND 
s.patched_cell_container IS NOT NULL 
AND err.recording_date > '2017-10-01'
"""

#AND (err.recording_date > '2017-10-01' OR err.recording_date IS NULL)
#AND err.recording_date > '2017-10-01'

master_df = get_lims_dataframe(query)
master_df
# Out:
#      go_no_go_63x                                               name  \
# 0            None  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-35889...
# 1          63x go             Chat-IRES-Cre-neo;Ai14-367633.05.01.01
# 2            None               Ntsr1-Cre_GN220;Ai14-357985.04.01.02
# 3            None  Npr3-IRES2-Cre;Sst-IRES-FlpO;Ai65-379882.04.02.01
# 4            None                                H18.03.008.11.02.01
# 5            None                  Vip-IRES-Cre;Ai14-381891.05.01.01
# 6            None                                H18.03.010.11.10.01
# 7            None  Crh-IRES-Cre_ZJH;Sst-IRES-FlpO;Ai65-360064.05....
# 8          63x go  Slc17a8-IRES2-Cre;Slc32a1-IRES2-FlpO;Ai65-3547...
# 9            None                  Oxtr-T2A-Cre;Ai14-381904.03.02.02
# 10           None  Crh-IRES-Cre_ZJH;Sst-IRES-FlpO;Ai65-374738.02....
# 11           None                                H18.03.009.11.13.01
# 12      63x no go  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-37811...
# 13           None                  Oxtr-T2A-Cre;Ai14-374536.04.01.01
# 14         63x go                Pvalb-IRES-Cre;Ai14-380351.02.01.01
# 15         63x go                Rbp4-Cre_KL100;Ai14-362155.05.02.04
# 16         63x go                Ctgf-T2A-dgCre;Ai14-374412.06.02.03
# 17           None   Oxtr-T2A-Cre;Pvalb-T2A-FlpO;Ai65-360187.03.02.01
# 18         63x go                Pvalb-IRES-Cre;Ai14-357946.03.02.01
# 19           None                 Gad2-IRES-Cre;Ai14-383745.03.01.02
# 20         63x go                 Sim1-Cre_KJ18;Ai14-354918.04.01.01
# 21      63x no go                                H17.03.016.11.16.02
# 22      63x no go                                H18.06.001.11.09.01
# 23           None                Rbp4-Cre_KL100;Ai14-383389.04.01.01
# 24           None  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-
# 42   2018-01-17 22:48:47  passed    P8S4_180117_351_A01
# ...                  ...     ...                    ...
# 2518 2018-04-04 18:14:31  passed    PBS4_180404_503_A01
# 2519 2018-03-30 21:06:33  passed    P1S4_180330_002_A01
# 2520 2017-10-16 20:13:07  passed    PAS4_171016_452_A01
# 2523 2017-11-01 20:31:16  passed    P8S4_171101_353_A01
# 2524 2018-02-27 19:42:11  passed    PAS4_180227_453_A01
# 2525 2017-10-11 02:48:41  passed    PAS4_171010_452_A01
# 2526 2017-11-14 23:24:29  passed    P9S4_171114_408_A01
# 2528 2018-04-04 22:33:42  passed    P8S4_180404_358_A01
# 2529 2018-04-13 16:33:57  passed    P8S4_180413_351_A01
# 2530 2017-11-16 21:12:39  passed    P9S4_171116_401_A01
# 2531 2017-11-16 23:41:53  passed    PBS4_171116_504_A01
# 2532 2018-02-20 22:44:56  passed    P8S4_180220_356_A01
# 2533 2017-10-25 16:46:24  passed    P8S4_171025_351_A01
# 2534 2017-10-24 20:38:20  passed    P8S4_171024_356_A01
# 2535 2018-03-19 20:40:13  passed    P8S4_180319_354_A01
# 2536 2018-05-01 23:34:09  passed    PBS4_180501_507_A01
# 2537 2018-05-02 20:35:30  passed    P1S4_180502_001_A01
# 2539 2017-11-22 18:05:13  passed    P9S4_171122_401_A01
# 2541 2018-01-25 18:35:34  passed    P9S4_180125_401_A01
# 2543 2018-05-02 17:27:58  passed    PAS4_180502_451_A01
# 2544 2018-03-27 02:15:13  passed    PBS4_180326_510_A01
# 2546 2018-03-28 21:41:32  passed    P8S4_180328_354_A01
# 2548 2018-01-22 22:46:24  passed    PBS4_180122_502_A01
# 2550 2018-04-03 17:34:51  passed    P9S4_180403_403_A01
# 2553 2017-10-05 22:39:22  passed    PBS4_171005_505_A01
# 2554 2018-04-13 20:52:39  passed    P8S4_180413_356_A01
# 2555 2018-05-01 17:39:38  passed    P8S4_180501_353_A01
# 2557 2017-11-29 23:02:41  passed    P9S4_171129_402_A01
# 2558 2018-01-23 01:20:22  passed    P2S4_180122_055_A01
# 2560 2018-03-07 18:14:58  passed    PBS4_180307_501_A01
#
#                                                link_20x
# 0     =HYPERLINK("http://lims2/focal_plane_image_ser...
# 1     =HYPERLINK("http://lims2/focal_plane_image_ser...
# 8     =HYPERLINK("http://lims2/focal_plane_image_ser...
# 9     =HYPERLINK("http://lims2/focal_plane_image_ser...
# 10    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 11    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 12    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 14    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 15    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 16    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 17                                                 None
# 18    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 19    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 20    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 21    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 22    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 24    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 25    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 26    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 27    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 29    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 31                                                 None
# 32    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 33    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 35    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 36    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 37                                                 None
# 40    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 41    =HYPERLINK("http://lims2/focal_plane_image_ser...
# 42    =HYPERLINK("http://lims2/focal_plane_image_ser...
# ...                                                 ...
# 2518  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2519  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2520  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2523  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2524  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2525  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2526  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2528  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2529  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2530  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2531  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2532  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2533  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2534  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2535  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2536                                               None
# 2537                                               None
# 2539  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2541  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2543                                               None
# 2544  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2546  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2548  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2550  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2553  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2554  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2555                                               None
# 2557  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2558  =HYPERLINK("http://lims2/focal_plane_image_ser...
# 2560  =HYPERLINK("http://lims2/focal_plane_image_ser...
#
# [1759 rows x 6 columns]

# %%
imagego = gen_filter(master_df,'go_no_go_63x', '63x go')

# %%
user_df('PA') #Outputs an excel sheet based on 'User'
# Out:
# C:\Users\ramr\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
per_user('PA') #Outputs print commands with results based on 'User'
# Out:
# Total cells patched: 286
# Cells that passed RNA seq QC: 184
# QC pass percentage: 0.643356643357
# Cells imaged at 63x: 67
