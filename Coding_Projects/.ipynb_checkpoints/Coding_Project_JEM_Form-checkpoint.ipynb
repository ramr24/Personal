# %% [markdown]
# # Coding Project Analysis JEM Forms

# %% [markdown]
# ### Data Output: Date, Specimen ID, Rig Opertator, Layer, Cell Type Prediction (Human), Patch Duration(min)

# %%
import os
import csv
import json
import fnmatch
import numpy as np
import pandas as pd

import JEM_post_patch as pp #post patch script
#post_patch_column = 'extraction.postPatch'
#post_patch_pipette_column = 'extraction.endPipetteR'

from pandas.io.json import json_normalize
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
pd.options.display.max_columns = None  #Displays all the columns 

#Used csv from 5/25/2018
shiny_human_df = pd.read_csv('C:/users/ramr/documents/github/personal-projects/csv/shiny_human.csv')
shiny_mouse_df = pd.read_csv('C:/users/ramr/documents/github/personal-projects/csv/shiny_mouse.csv')

# %%
def gen_fil(df, col, cond):
    '''
    Filters the column with a certain condition
    df: dataframe
    col: column
    cond: condition
    '''
    filtered = df[df[col] == cond]
    return filtered

# %%
def get_jsons(dirname, expt):
    json_paths = []
    for jfile in os.listdir(dirname):
        if fnmatch.fnmatch(jfile, '*.%s.json' %expt):
            jpath = os.path.join(dirname, jfile)
            json_paths.append(jpath)
    return json_paths

# %%
#make list of json paths for every json file in MIES Experiments directory on 279
json_list = get_jsons("//allen/programs/celltypes/workgroups/279/Patch-Seq/all-metadata-files/", "PS")
#json_list

# %%
def flatten_attempts(slice_info, form_version):
    """Return flattened slice metadata dataframe.
    
    Parameters
    ----------
    slice_info : dict
        A dictionary of slices with nested pipette attempts.
    
    form_version : string
        A string containing the JEM form version.
        (Pre-version 2 contains IVSCC, PatchSeq and Electroporation arrays)
    Returns
    -------
    attempts_slice_df : pandas dataframe
        A dataframe of all pipette attempts along with all slice metadata.
    """
    
    df = json_normalize(slice_info)
    if form_version >= "2":
        ps_array_name = "pipettes"
    else:
        ps_array_name = "pipettesPatchSeqPilot"
    try:
        attempts_df = json_normalize(slice_info[ps_array_name])
        attempts_df["limsSpecName"] = df["limsSpecName"].values[0]
        attempts_df["attempt"] = [p+1 for p in attempts_df.index.values]
        attempts_slice_df = pd.merge(df, attempts_df, how="outer", on="limsSpecName")
        attempts_slice_df.drop(ps_array_name, axis=1, inplace=True)
        return attempts_slice_df
    except IndexError:
        pass

def is_field(df, colname):
    """Determine whether a column name exists in a dataframe.
    
    Parameters
    ----------
    df : a Pandas dataframe
    colname : string
        
    Returns
    -------
    Boolean
        Boolean value indicating if the colname exists in the dataframe.
    """
    
    try:
        df[colname]
        return True
    except KeyError:
        return False

# %% [markdown]
# ### json_df

# %%
json_df = pd.DataFrame()

for json_path in json_list:
    with open(json_path) as data_file:
        slice_info = json.load(data_file)
        if is_field(slice_info, "formVersion"):
            jem_version = slice_info["formVersion"]
        else:
            jem_version = "1.0.0"
        flat_df = flatten_attempts(slice_info, jem_version)
        json_df = pd.concat([json_df, flat_df], axis=0)

# %%
#Creates patch_duration column and outputs in minutes
json_df['patch_duration'] = pd.to_datetime(json_df['extraction.timeRetractionEnd']) - pd.to_datetime(json_df['recording.timeWholeCellStart'])
json_df['patch_duration'] = (json_df['patch_duration'].astype('timedelta64[s]'))/60
json_df.head()
# Out:
#   acsfProductionDate approach.anatomicalLocation approach.autoRoi  \
# 0         2018-04-18                         NaN              NaN
# 1         2018-04-18                         NaN              NaN
# 2         2018-04-18                         NaN              NaN
# 3         2018-04-18                         NaN              NaN
# 4         2018-04-18                         NaN              NaN
#
#   approach.cellHealth approach.corticalLayer approach.creCell  approach.depth  \
# 0                   3                    NaN             Cre+             NaN
# 1                   2                    NaN             Cre+             NaN
# 2                   2                    NaN             Cre+             NaN
# 3                   2                    NaN             Cre+             NaN
# 4                   2                    NaN             Cre+             NaN
#
#   approach.detailedLocation approach.manualRoi approach.otherPilotName  \
# 0                       NaN                NaN                     NaN
# 1                       NaN                NaN                     NaN
# 2                       NaN                NaN                     NaN
# 3                       NaN                NaN                     NaN
# 4                       NaN                NaN                     NaN
#
#   approach.pilotName approach.pilotTest01 approach.pilotTest03  \
# 0               None                  NaN                  NaN
# 1               None                  NaN                  NaN
# 2               None                  NaN                  NaN
# 3               None                  NaN                  NaN
# 4               None                  NaN                  NaN
#
#   approach.pilotTest04 approach.pilotTest05 approach.sliceHealth  attempt  \
# 0                  NaN                  NaN                    2      1.0
# 1                  NaN                  NaN                    2      2.0
# 2                  NaN                  NaN                    2      3.0
# 3                  NaN                  NaN                    2      4.0
# 4                  NaN                  NaN                    2      5.0
#
#   autoRoi badSweeps blankFillDate                        date depth  \
# 0    None       NaN    2018-03-22  2018-04-18 13:17:02 -07:00   -50
# 1    None       NaN    2018-03-22  2018-04-18 13:17:02 -07:00   -50
# 2    None       NaN    2018-03-22  2018-04-18 13:17:02 -07:00   -50
# 3    None       NaN    2018-03-22  2018-04-18 13:17:02 -07:00   -50
# 4    None       NaN    2018-03-22  2018-04-18 13:17:02 -07:00   -50
#
#   experimentType extraction.bfiWitness extraction.endPipetteR  \
# 0            NaN                   NaN                   1000
# 1            NaN                   NaN                   1000
# 2            NaN                   NaN                   1000
# 3            NaN                   NaN                   1000
# 4            NaN                   NaN                   1000
#
#   extraction.extractionNotes extraction.extractionObservations  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                        NaN                               NaN
# 4                        NaN                               NaN
#
#   extraction.nucleus extraction.postPatch  extraction.pressureApplied  \
# 0                 no       nucleus_absent                       -80.0
# 1                NaN      nucleus_present                       -80.0
# 2                 no       nucleus_absent                       -80.0
# 3  not_intentionally      nucleus_present                       -80.0
# 4                NaN       nucleus_absent                       -80.0
#
#    extraction.retractionPressureApplied extraction.sampleObservations  \
# 0                                 -80.0                           NaN
# 1                                 -80.0                           NaN
# 2                                 -80.0                           NaN
# 3                                 -80.0                           NaN
# 4                                 -80.0                           NaN
#
#   extraction.timeEnd extraction.timeExtractionEnd  \
# 0                NaN              13:20:14 -07:00
# 1                NaN              13:21:44 -07:00
# 2                NaN              13:22:39 -07:00
# 3                NaN              13:23:59 -07:00
# 4                NaN              13:25:01 -07:00
#
#   extraction.timeExtractionStart extraction.timeRetractionEnd  \
# 0                13:20:13 -07:00              13:20:14 -07:00
# 1                13:21:44 -07:00              13:21:45 -07:00
# 2                13:22:38 -07:00              13:22:39 -07:00
# 3                13:23:58 -07:00              13:23:59 -07:00
# 4                13:25:01 -07:00              13:25:01 -07:00
#
#   extraction.timeRetractionStart    extraction.tubeID failureCause  \
# 0                            NaN  PXS4_180418_551_A01          NaN
# 1                            NaN  PXS4_180418_552_A01          NaN
# 2                            NaN  PXS4_180418_553_A01          NaN
# 3                            NaN  PXS4_180418_554_A01          NaN
# 4                            NaN  PXS4_180418_555_A01          NaN
#
#   failureNotes flipped formVersion freeFailureNotes internalFillDate  \
# 0          NaN      No       2.0.3              NaN       2018-03-29
# 1          NaN      No       2.0.3              NaN       2018-03-29
# 2          NaN      No       2.0.3              NaN       2018-03-29
# 3          NaN      No       2.0.3              NaN       2018-03-29
# 4          NaN      No       2.0.3              NaN       2018-03-29
#
#    internalSolution.concentrationAlexa  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    internalSolution.concentrationBiocytin  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   internalSolution.concentrationRnaseInhibitor internalSolution.version  \
# 0                                          NaN                      NaN
# 1                                          NaN                      NaN
# 2                                          NaN                      NaN
# 3                                          NaN                      NaN
# 4                                          NaN                      NaN
#
#    internalSolution.volume                                       limsSpecName  \
# 0                      NaN  Sim1-Cre_KJ18;Ai139;Sst-IRES-FlpO;Ai65F-386176...
# 1                      NaN  Sim1-Cre_KJ18;Ai139;Sst-IRES-FlpO;Ai65F-386176...
# 2                      NaN  Sim1-Cre_KJ18;Ai139;Sst-IRES-FlpO;Ai65F-386176...
# 3                      NaN  Sim1-Cre_KJ18;Ai139;Sst-IRES-FlpO;Ai65F-386176...
# 4                      NaN  Sim1-Cre_KJ18;Ai139;Sst-IRES-FlpO;Ai65F-386176...
#
#   manualRoi pipetteSpecName qcNotes recording.accessR  \
# 0     VISp5             NaN     NaN               NaN
# 1     VISp5             NaN     NaN               NaN
# 2     VISp5             NaN     NaN               NaN
# 3     VISp5             NaN     NaN               NaN
# 4     VISp5             NaN     NaN               NaN
#
#   recording.humanCellTypePrediction recording.membraneV recording.pipetteR  \
# 0                               NaN                 NaN                  6
# 1                               NaN                 NaN                  6
# 2                               NaN                 NaN                  6
# 3                               NaN                 NaN                  6
# 4                               NaN                 NaN                  6
#
#   recording.rheobase recording.timeStart recording.timeWholeCellStart  \
# 0                NaN     13:19:59 -07:00              13:20:00 -07:00
# 1                NaN     13:21:26 -07:00              13:21:31 -07:00
# 2                NaN     13:22:25 -07:00              13:22:27 -07:00
# 3                NaN     13:23:04 -07:00              13:23:09 -07:00
# 4                NaN     13:24:37 -07:00              13:24:40 -07:00
#
#   rigNumber rigOperator sliceNotes sliceQuality   status successNotes wellID  \
# 0       MP2      pashad        NaN      Damaged  SUCCESS          NaN    NaN
# 1       MP2      pashad        NaN      Damaged  SUCCESS          NaN    NaN
# 2       MP2      pashad        NaN      Damaged  SUCCESS          NaN    NaN
# 3       MP2      pashad        NaN      Damaged  SUCCESS          NaN    NaN
# 4       MP2      pashad        NaN      Damaged  SUCCESS          NaN    NaN
#
#    patch_duration
# 0        0.233333
# 1        0.233333
# 2        0.200000
# 3        0.833333
# 4        0.350000

# %% [markdown]
# ### Fixing up date column & adding post patch column

# %%
json_df['date'] = json_df['date'].str[:10] #Strip away the time
json_df['date'] = pd.to_datetime(json_df['date']) #Converting to YYYY-MM-DD
json_df.set_index('date', inplace = True)
json_df = pp.postpatch_reclass(json_df) #Makes post patch column with the script
json_df.sort_index(inplace = True) #Sort the date column just in case

#start_date = input('Enter the start date for your dataframe (YYYY-MM-DD): ')
start_date = '2017-10-01'
json_df1 = json_df[start_date:]
json_df1 = gen_fil(json_df1, 'status', 'SUCCESS') 
json_df1.sort_index(inplace = True) #Sort the date column just in case

# %%
json_df1.head()
# Out:
#            acsfProductionDate approach.anatomicalLocation approach.autoRoi  \
# date
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
#
#            approach.cellHealth approach.corticalLayer approach.creCell  \
# date
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
#
#             approach.depth approach.detailedLocation approach.manualRoi  \
# date
# 2017-10-02             NaN                       NaN      VISp, layer 5
# 2017-10-02             NaN                       NaN      VISp, layer 4
# 2017-10-02             NaN                       NaN      VISp, layer 4
# 2017-10-02             NaN                       NaN      VISp, layer 5
# 2017-10-02             NaN                       NaN      VISp, layer 5
#
#            approach.otherPilotName                     approach.pilotName  \
# date
# 2017-10-02                     NaN                                   None
# 2017-10-02                     NaN                                   None
# 2017-10-02                     NaN                                   None
# 2017-10-02                     NaN  Nucleated Patch - Retraction Pressure
# 2017-10-02                     NaN  Nucleated Patch - Retraction Pressure
#
#            approach.pilotTest01 approach.pilotTest03 approach.pilotTest04  \
# date
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
#
#            approach.pilotTest05 approach.sliceHealth  attempt autoRoi  \
# date
# 2017-10-02                  NaN                    3      1.0     NaN
# 2017-10-02                  NaN                    3      2.0     NaN
# 2017-10-02                  NaN                    2      1.0     NaN
# 2017-10-02                  NaN                    4      2.0     NaN
# 2017-10-02                  NaN                    3      4.0     NaN
#
#            badSweeps blankFillDate depth experimentType extraction.bfiWitness  \
# date
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
#
#            extraction.endPipetteR  \
# date
# 2017-10-02                   3000
# 2017-10-02                    930
# 2017-10-02                   10.2
# 2017-10-02                   1000
# 2017-10-02                   1000
#
#                                    extraction.extractionNotes  \
# date
# 2017-10-02  1.5 min retraction time. Can see alexa fill po...
# 2017-10-02                                                NaN
# 2017-10-02                                                NaN
# 2017-10-02                                                NaN
# 2017-10-02                                                NaN
#
#                           extraction.extractionObservations  \
# date
# 2017-10-02  Fluorescence in Pipette,Cell Dimmed,Cell Shrunk
# 2017-10-02                                              NaN
# 2017-10-02                                      Cell Dimmed
# 2017-10-02                          Fluorescence in Pipette
# 2017-10-02                          Fluorescence in Pipette
#
#            extraction.nucleus extraction.postPatch  \
# date
# 2017-10-02                 no      nucleus_present
# 2017-10-02                 no      nucleus_present
# 2017-10-02  not_intentionally       nucleus_absent
# 2017-10-02                 no      nucleus_present
# 2017-10-02                 no      nucleus_present
#
#             extraction.pressureApplied  extraction.retractionPressureApplied  \
# date
# 2017-10-02                       -30.0                                 -30.0
# 2017-10-02                       -26.6                                 -26.6
# 2017-10-02                       -35.0                                 -35.0
# 2017-10-02                       -30.0                                 -30.0
# 2017-10-02                       -32.0                                 -32.0
#
#            extraction.sampleObservations extraction.timeEnd  \
# date
# 2017-10-02                    No Bubbles                NaN
# 2017-10-02                    No Bubbles                NaN
# 2017-10-02                    No Bubbles                NaN
# 2017-10-02                    No Bubbles                NaN
# 2017-10-02                    No Bubbles                NaN
#
#            extraction.timeExtractionEnd extraction.timeExtractionStart  \
# date
# 2017-10-02                     15:24:14                       15:22:54
# 2017-10-02                     15:29:19                       15:28:58
# 2017-10-02                     13:57:41                       13:57:21
# 2017-10-02                     15:14:09                       15:13:24
# 2017-10-02                     15:43:26                       15:42:58
#
#            extraction.timeRetractionEnd extraction.timeRetractionStart  \
# date
# 2017-10-02                     15:25:49                       15:24:15
# 2017-10-02                     15:31:31                       15:29:19
# 2017-10-02                     14:00:00                       13:58:00
# 2017-10-02                     15:15:45                       15:14:10
# 2017-10-02                     15:45:24                       15:43:27
#
#            extraction.tubeID failureCause failureNotes flipped formVersion  \
# date
# 2017-10-02               356          NaN          NaN     Yes       2.0.0
# 2017-10-02               404          NaN          NaN     Yes       2.0.0
# 2017-10-02               451          NaN          NaN     Yes       2.0.0
# 2017-10-02               054          NaN          NaN     Yes       2.0.0
# 2017-10-02               055          NaN          NaN     Yes       2.0.0
#
#            freeFailureNotes internalFillDate  \
# date
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
#
#             internalSolution.concentrationAlexa  \
# date
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
#
#             internalSolution.concentrationBiocytin  \
# date
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
#
#            internalSolution.concentrationRnaseInhibitor  \
# date
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
#
#            internalSolution.version  internalSolution.volume  \
# date
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
#
#                                  limsSpecName manualRoi pipetteSpecName  \
# date
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.03.02       NaN             NaN
# 2017-10-02    Gad2-IRES-Cre;Ai14-350672.04.01       NaN             NaN
# 2017-10-02    Gad2-IRES-Cre;Ai14-350672.06.02       NaN             NaN
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.04.01       NaN             NaN
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.04.01       NaN             NaN
#
#                            qcNotes recording.accessR  \
# date
# 2017-10-02                     NaN               NaN
# 2017-10-02                     NaN               NaN
# 2017-10-02  Recording Time = 8 min               NaN
# 2017-10-02                     NaN               NaN
# 2017-10-02                     NaN               NaN
#
#            recording.humanCellTypePrediction recording.membraneV  \
# date
# 2017-10-02                               NaN                 NaN
# 2017-10-02                               NaN                 NaN
# 2017-10-02                               NaN                 NaN
# 2017-10-02                               NaN                 NaN
# 2017-10-02                               NaN                 NaN
#
#            recording.pipetteR recording.rheobase recording.timeStart  \
# date
# 2017-10-02                5.3                NaN            15:14:50
# 2017-10-02                6.2                NaN            15:24:12
# 2017-10-02                5.0                NaN            13:46:41
# 2017-10-02                  6                NaN            15:05:18
# 2017-10-02                  5                NaN            15:37:03
#
#            recording.timeWholeCellStart rigNumber rigOperator  \
# date
# 2017-10-02                     15:16:11         7    lindsayn
# 2017-10-02                     15:25:01         6       lisak
# 2017-10-02                     13:48:08         4        ramr
# 2017-10-02                     15:07:24         5      rustym
# 2017-10-02                     15:38:40         5      rustym
#
#                                     sliceNotes sliceQuality   status  \
# date
# 2017-10-02                                 NaN          NaN  SUCCESS
# 2017-10-02                                 NaN          NaN  SUCCESS
# 2017-10-02  Wave of Death started after 30 min          NaN  SUCCESS
# 2017-10-02                                 NaN          NaN  SUCCESS
# 2017-10-02                                 NaN          NaN  SUCCESS
#
#                                                  successNotes  \
# date
# 2017-10-02                                                NaN
# 2017-10-02                                                NaN
# 2017-10-02  Patch/Cell Unstable,Patch Became Leaky,Ended A...
# 2017-10-02                                                NaN
# 2017-10-02                                                NaN
#
#                            wellID  patch_duration     post_patch
# date
# 2017-10-02  EPhys_171002_01_B02_M        9.633333  Nuc-high seal
# 2017-10-02  EPhys_171002_01_B01_M        6.500000  Nuc-high seal
# 2017-10-02  EPhys_171002_01_A04_M       11.866667   No-high seal
# 2017-10-02  EPhys_171002_01_B03_M        8.350000  Nuc-high seal
# 2017-10-02  EPhys_171002_01_B03_M        6.733333  Nuc-high seal

# %%
json_df1.tail()
# Out:
#            acsfProductionDate approach.anatomicalLocation approach.autoRoi  \
# date
# 2018-06-04         2018-06-01                         NaN              NaN
# 2018-06-04         2018-06-01                         NaN              NaN
# 2018-06-04         2018-06-01                         NaN              NaN
# 2018-06-04         2018-06-01                         NaN              NaN
# 2018-06-04         2018-06-01                         NaN              NaN
#
#            approach.cellHealth approach.corticalLayer approach.creCell  \
# date
# 2018-06-04                   4                    NaN             Cre+
# 2018-06-04                   4                    NaN             Cre+
# 2018-06-04                   3                    NaN             Cre+
# 2018-06-04                   3                    NaN             Cre+
# 2018-06-04                   3                    NaN             Cre+
#
#             approach.depth approach.detailedLocation approach.manualRoi  \
# date
# 2018-06-04             NaN                       NaN                NaN
# 2018-06-04             NaN                       NaN                NaN
# 2018-06-04             NaN                       NaN                NaN
# 2018-06-04             NaN                       NaN                NaN
# 2018-06-04             NaN                       NaN                NaN
#
#            approach.otherPilotName approach.pilotName approach.pilotTest01  \
# date
# 2018-06-04                     NaN               None                  NaN
# 2018-06-04                     NaN               None                  NaN
# 2018-06-04                     NaN               None                  NaN
# 2018-06-04                     NaN               None                  NaN
# 2018-06-04                     NaN               None                  NaN
#
#            approach.pilotTest03 approach.pilotTest04 approach.pilotTest05  \
# date
# 2018-06-04                  NaN                  NaN                  NaN
# 2018-06-04                  NaN                  NaN                  NaN
# 2018-06-04                  NaN                  NaN                  NaN
# 2018-06-04                  NaN                  NaN                  NaN
# 2018-06-04                  NaN                  NaN                  NaN
#
#            approach.sliceHealth  attempt autoRoi badSweeps blankFillDate  \
# date
# 2018-06-04                    3      2.0    None       NaN    2018-06-11
# 2018-06-04                    4      1.0    None       NaN    2018-05-11
# 2018-06-04                    3      3.0    None       NaN    2018-05-11
# 2018-06-04                    3      3.0    None       NaN    2018-06-11
# 2018-06-04                    2      4.0    None       NaN    2018-05-11
#
#            depth experimentType extraction.bfiWitness extraction.endPipetteR  \
# date
# 2018-06-04    66            NaN                   NaN                    200
# 2018-06-04  44.3            NaN                   NaN                   2000
# 2018-06-04     0            NaN                   NaN                    500
# 2018-06-04    48            NaN                   NaN                      6
# 2018-06-04  42.5            NaN                   NaN                   1000
#
#                      extraction.extractionNotes  \
# date
# 2018-06-04                                  NaN
# 2018-06-04  Outside-out and alexa fill visible.
# 2018-06-04                                  NaN
# 2018-06-04                                  NaN
# 2018-06-04  Alexa fill visible post experiment.
#
#            extraction.extractionObservations extraction.nucleus  \
# date
# 2018-06-04                               NaN                 no
# 2018-06-04          Cell Dimmed,Cell Swelled                 no
# 2018-06-04                               NaN                 no
# 2018-06-04                      Cell Swelled                 no
# 2018-06-04                               NaN                 no
#
#            extraction.postPatch  extraction.pressureApplied  \
# date
# 2018-06-04       nucleus_absent                       -47.0
# 2018-06-04       nucleus_absent                       -38.0
# 2018-06-04       nucleus_absent                       -20.0
# 2018-06-04       nucleus_absent                       -50.0
# 2018-06-04      nucleus_present                       -30.0
#
#             extraction.retractionPressureApplied  \
# date
# 2018-06-04                                 -47.0
# 2018-06-04                                 -38.0
# 2018-06-04                                 -20.0
# 2018-06-04                                 -50.0
# 2018-06-04                                 -30.0
#
#            extraction.sampleObservations extraction.timeEnd  \
# date
# 2018-06-04                    No Bubbles                NaN
# 2018-06-04                    No Bubbles                NaN
# 2018-06-04                    No Bubbles                NaN
# 2018-06-04                 Small Bubbles                NaN
# 2018-06-04                Medium Bubbles                NaN
#
#            extraction.timeExtractionEnd extraction.timeExtractionStart  \
# date
# 2018-06-04              11:52:56 -07:00                11:50:58 -07:00
# 2018-06-04              11:40:43 -07:00                11:38:50 -07:00
# 2018-06-04              14:21:31 -07:00                14:21:16 -07:00
# 2018-06-04              12:12:06 -07:00                12:11:10 -07:00
# 2018-06-04              13:22:42 -07:00                13:21:55 -07:00
#
#            extraction.timeRetractionEnd extraction.timeRetractionStart  \
# date
# 2018-06-04              11:52:56 -07:00                            NaN
# 2018-06-04              11:42:53 -07:00                            NaN
# 2018-06-04              14:23:03 -07:00                            NaN
# 2018-06-04              12:12:07 -07:00                            NaN
# 2018-06-04              13:24:59 -07:00                            NaN
#
#               extraction.tubeID failureCause failureNotes flipped formVersion  \
# date
# 2018-06-04  PBS4_180604_502_A01          NaN          NaN     Yes       2.0.3
# 2018-06-04  PAS4_180604_451_A01          NaN          NaN     Yes       2.0.3
# 2018-06-04  P1S4_180604_006_A01          NaN          NaN     Yes       2.0.3
# 2018-06-04  PBS4_180604_503_A01          NaN          NaN     Yes       2.0.3
# 2018-06-04  P2S4_180604_053_A01          NaN          NaN     Yes       2.0.3
#
#            freeFailureNotes internalFillDate  \
# date
# 2018-06-04              NaN       2018-04-09
# 2018-06-04              NaN       2018-04-09
# 2018-06-04              NaN       2018-04-09
# 2018-06-04              NaN       2018-04-09
# 2018-06-04              NaN       2018-04-09
#
#             internalSolution.concentrationAlexa  \
# date
# 2018-06-04                                  NaN
# 2018-06-04                                  NaN
# 2018-06-04                                  NaN
# 2018-06-04                                  NaN
# 2018-06-04                                  NaN
#
#             internalSolution.concentrationBiocytin  \
# date
# 2018-06-04                                     NaN
# 2018-06-04                                     NaN
# 2018-06-04                                     NaN
# 2018-06-04                                     NaN
# 2018-06-04                                     NaN
#
#            internalSolution.concentrationRnaseInhibitor  \
# date
# 2018-06-04                                          NaN
# 2018-06-04                                          NaN
# 2018-06-04                                          NaN
# 2018-06-04                                          NaN
# 2018-06-04                                          NaN
#
#            internalSolution.version  internalSolution.volume  \
# date
# 2018-06-04                      NaN                      NaN
# 2018-06-04                      NaN                      NaN
# 2018-06-04                      NaN                      NaN
# 2018-06-04                      NaN                      NaN
# 2018-06-04                      NaN                      NaN
#
#                               limsSpecName manualRoi pipetteSpecName  \
# date
# 2018-06-04  Sst-IRES-Cre;Ai14-392701.03.01   VISp2/3             NaN
# 2018-06-04  Sst-IRES-Cre;Ai14-392701.03.02     VISp5             NaN
# 2018-06-04  Sst-IRES-Cre;Ai14-392703.04.01     VISp4             NaN
# 2018-06-04  Sst-IRES-Cre;Ai14-392701.03.01     VISp5             NaN
# 2018-06-04  Sst-IRES-Cre;Ai14-392701.05.02     VISp5             NaN
#
#                     qcNotes recording.accessR  \
# date
# 2018-06-04              NaN               NaN
# 2018-06-04  Ended after C2.               NaN
# 2018-06-04              NaN               NaN
# 2018-06-04              NaN               NaN
# 2018-06-04              NaN               NaN
#
#            recording.humanCellTypePrediction recording.membraneV  \
# date
# 2018-06-04                               NaN                 NaN
# 2018-06-04                               NaN                 NaN
# 2018-06-04                               NaN                 NaN
# 2018-06-04                               NaN                 NaN
# 2018-06-04                               NaN                 NaN
#
#            recording.pipetteR recording.rheobase recording.timeStart  \
# date
# 2018-06-04                3.6                NaN     11:40:02 -07:00
# 2018-06-04                6.2                NaN     11:24:19 -07:00
# 2018-06-04                4.5                NaN     14:15:34 -07:00
# 2018-06-04                3.8                NaN     11:59:00 -07:00
# 2018-06-04                4.5                NaN     13:07:24 -07:00
#
#            recording.timeWholeCellStart rigNumber rigOperator  \
# date
# 2018-06-04              11:42:04 -07:00         7      dijonh
# 2018-06-04              11:26:14 -07:00         7        ramr
# 2018-06-04              14:16:41 -07:00         4    kristenh
# 2018-06-04              12:00:30 -07:00         7      dijonh
# 2018-06-04              13:09:07 -07:00         2      rustym
#
#                                                    sliceNotes  \
# date
# 2018-06-04                                          #Schedule
# 2018-06-04                                            #Health
# 2018-06-04                                working outside WSE
# 2018-06-04                                          #Schedule
# 2018-06-04  #ROIgone.  Tissue got a little cloudy in spots...
#
#                sliceQuality   status         successNotes wellID  \
# date
# 2018-06-04             Good  SUCCESS                  NaN    NaN
# 2018-06-04  'Wave of Death'  SUCCESS  Cell Hyperpolarized    NaN
# 2018-06-04             Good  SUCCESS                  NaN    NaN
# 2018-06-04             Good  SUCCESS   Patch Became Leaky    NaN
# 2018-06-04             Good  SUCCESS                  NaN    NaN
#
#             patch_duration     post_patch
# date
# 2018-06-04       10.866667    No-low seal
# 2018-06-04       16.650000   No-high seal
# 2018-06-04        6.366667   No-high seal
# 2018-06-04       11.616667    No-low seal
# 2018-06-04       15.866667  Nuc-high seal

# %% [markdown]
# ### Filter for Human & Mouse dataframe

# %%
json_df1['human?'] = json_df1['limsSpecName'].str.match(r"H\d\d") #Creates new boolean column

json_df2 = gen_fil(json_df1, 'human?', True) #HUMAN
json_df3 = gen_fil(json_df1, 'human?', False) #MOUSE
json_df1.head()
# Out:
#            acsfProductionDate approach.anatomicalLocation approach.autoRoi  \
# date
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
# 2017-10-02         09/29/2017                         NaN             None
#
#            approach.cellHealth approach.corticalLayer approach.creCell  \
# date
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
# 2017-10-02                 NaN                    NaN             Cre+
#
#             approach.depth approach.detailedLocation approach.manualRoi  \
# date
# 2017-10-02             NaN                       NaN      VISp, layer 5
# 2017-10-02             NaN                       NaN      VISp, layer 4
# 2017-10-02             NaN                       NaN      VISp, layer 4
# 2017-10-02             NaN                       NaN      VISp, layer 5
# 2017-10-02             NaN                       NaN      VISp, layer 5
#
#            approach.otherPilotName                     approach.pilotName  \
# date
# 2017-10-02                     NaN                                   None
# 2017-10-02                     NaN                                   None
# 2017-10-02                     NaN                                   None
# 2017-10-02                     NaN  Nucleated Patch - Retraction Pressure
# 2017-10-02                     NaN  Nucleated Patch - Retraction Pressure
#
#            approach.pilotTest01 approach.pilotTest03 approach.pilotTest04  \
# date
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
# 2017-10-02                  NaN                  NaN                  NaN
#
#            approach.pilotTest05 approach.sliceHealth  attempt autoRoi  \
# date
# 2017-10-02                  NaN                    3      1.0     NaN
# 2017-10-02                  NaN                    3      2.0     NaN
# 2017-10-02                  NaN                    2      1.0     NaN
# 2017-10-02                  NaN                    4      2.0     NaN
# 2017-10-02                  NaN                    3      4.0     NaN
#
#            badSweeps blankFillDate depth experimentType extraction.bfiWitness  \
# date
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
# 2017-10-02       NaN    09/25/2017   NaN            NaN                   NaN
#
#            extraction.endPipetteR  \
# date
# 2017-10-02                   3000
# 2017-10-02                    930
# 2017-10-02                   10.2
# 2017-10-02                   1000
# 2017-10-02                   1000
#
#                                    extraction.extractionNotes  \
# date
# 2017-10-02  1.5 min retraction time. Can see alexa fill po...
# 2017-10-02                                                NaN
# 2017-10-02                                                NaN
# 2017-10-02                                                NaN
# 2017-10-02                                                NaN
#
#                           extraction.extractionObservations  \
# date
# 2017-10-02  Fluorescence in Pipette,Cell Dimmed,Cell Shrunk
# 2017-10-02                                              NaN
# 2017-10-02                                      Cell Dimmed
# 2017-10-02                          Fluorescence in Pipette
# 2017-10-02                          Fluorescence in Pipette
#
#            extraction.nucleus extraction.postPatch  \
# date
# 2017-10-02                 no      nucleus_present
# 2017-10-02                 no      nucleus_present
# 2017-10-02  not_intentionally       nucleus_absent
# 2017-10-02                 no      nucleus_present
# 2017-10-02                 no      nucleus_present
#
#             extraction.pressureApplied  extraction.retractionPressureApplied  \
# date
# 2017-10-02                       -30.0                                 -30.0
# 2017-10-02                       -26.6                                 -26.6
# 2017-10-02                       -35.0                                 -35.0
# 2017-10-02                       -30.0                                 -30.0
# 2017-10-02                       -32.0                                 -32.0
#
#            extraction.sampleObservations extraction.timeEnd  \
# date
# 2017-10-02                    No Bubbles                NaN
# 2017-10-02                    No Bubbles                NaN
# 2017-10-02                    No Bubbles                NaN
# 2017-10-02                    No Bubbles                NaN
# 2017-10-02                    No Bubbles                NaN
#
#            extraction.timeExtractionEnd extraction.timeExtractionStart  \
# date
# 2017-10-02                     15:24:14                       15:22:54
# 2017-10-02                     15:29:19                       15:28:58
# 2017-10-02                     13:57:41                       13:57:21
# 2017-10-02                     15:14:09                       15:13:24
# 2017-10-02                     15:43:26                       15:42:58
#
#            extraction.timeRetractionEnd extraction.timeRetractionStart  \
# date
# 2017-10-02                     15:25:49                       15:24:15
# 2017-10-02                     15:31:31                       15:29:19
# 2017-10-02                     14:00:00                       13:58:00
# 2017-10-02                     15:15:45                       15:14:10
# 2017-10-02                     15:45:24                       15:43:27
#
#            extraction.tubeID failureCause failureNotes flipped formVersion  \
# date
# 2017-10-02               356          NaN          NaN     Yes       2.0.0
# 2017-10-02               404          NaN          NaN     Yes       2.0.0
# 2017-10-02               451          NaN          NaN     Yes       2.0.0
# 2017-10-02               054          NaN          NaN     Yes       2.0.0
# 2017-10-02               055          NaN          NaN     Yes       2.0.0
#
#            freeFailureNotes internalFillDate  \
# date
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
# 2017-10-02              NaN       09/29/2017
#
#             internalSolution.concentrationAlexa  \
# date
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
# 2017-10-02                                  NaN
#
#             internalSolution.concentrationBiocytin  \
# date
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
# 2017-10-02                                     NaN
#
#            internalSolution.concentrationRnaseInhibitor  \
# date
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
# 2017-10-02                                          NaN
#
#            internalSolution.version  internalSolution.volume  \
# date
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
# 2017-10-02                      NaN                      NaN
#
#                                  limsSpecName manualRoi pipetteSpecName  \
# date
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.03.02       NaN             NaN
# 2017-10-02    Gad2-IRES-Cre;Ai14-350672.04.01       NaN             NaN
# 2017-10-02    Gad2-IRES-Cre;Ai14-350672.06.02       NaN             NaN
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.04.01       NaN             NaN
# 2017-10-02  Chrna2-Cre_OE25;Ai14-351067.04.01       NaN             NaN
#
#                            qcNotes recording.accessR  \
# date
# 2017-10-02                     NaN               NaN
# 2017-10-02                     NaN               NaN
# 2017-10-02  Recording Time = 8 min               NaN
# 2017-10-02                     NaN               NaN
# 2017-10-02                     NaN               NaN
#
#            recording.humanCellTypePrediction recording.membraneV  \
# date
# 2017-10-02                               NaN                 NaN
# 2017-10-02                               NaN                 NaN
# 2017-10-02                               NaN                 NaN
# 2017-10-02                               NaN                 NaN
# 2017-10-02                               NaN                 NaN
#
#            recording.pipetteR recording.rheobase recording.timeStart  \
# date
# 2017-10-02                5.3                NaN            15:14:50
# 2017-10-02                6.2                NaN            15:24:12
# 2017-10-02                5.0                NaN            13:46:41
# 2017-10-02                  6                NaN            15:05:18
# 2017-10-02                  5                NaN            15:37:03
#
#            recording.timeWholeCellStart rigNumber rigOperator  \
# date
# 2017-10-02                     15:16:11         7    lindsayn
# 2017-10-02                     15:25:01         6       lisak
# 2017-10-02                     13:48:08         4        ramr
# 2017-10-02                     15:07:24         5      rustym
# 2017-10-02                     15:38:40         5      rustym
#
#                                     sliceNotes sliceQuality   status  \
# date
# 2017-10-02                                 NaN          NaN  SUCCESS
# 2017-10-02                                 NaN          NaN  SUCCESS
# 2017-10-02  Wave of Death started after 30 min          NaN  SUCCESS
# 2017-10-02                                 NaN          NaN  SUCCESS
# 2017-10-02                                 NaN          NaN  SUCCESS
#
#                                                  successNotes  \
# date
# 2017-10-02                                                NaN
# 2017-10-02                                                NaN
# 2017-10-02  Patch/Cell Unstable,Patch Became Leaky,Ended A...
# 2017-10-02                                                NaN
# 2017-10-02                                                NaN
#
#                            wellID  patch_duration     post_patch  human?
# date
# 2017-10-02  EPhys_171002_01_B02_M        9.633333  Nuc-high seal   False
# 2017-10-02  EPhys_171002_01_B01_M        6.500000  Nuc-high seal   False
# 2017-10-02  EPhys_171002_01_A04_M       11.866667   No-high seal   False
# 2017-10-02  EPhys_171002_01_B03_M        8.350000  Nuc-high seal   False
# 2017-10-02  EPhys_171002_01_B03_M        6.733333  Nuc-high seal   False

# %% [markdown]
# ## HUMAN dataframe

# %%
json_df2 = json_df2.reset_index()
human_df = json_df2[['date',
                     'limsSpecName',
                     'rigOperator',
                     'approach.manualRoi',
                     'manualRoi', 
                     'recording.humanCellTypePrediction',
                     'post_patch',
                     'patch_duration',
                     'extraction.tubeID']]

human_df.sort_index(inplace = True)
#approach.manualRoi available data at 2017-10-10 to 2017-11-27
#manualRoi avaible data at 2017-11-27 to Present
#extraction.tubeID changes from ### to User_Date_###_A01 at 2017-11-27

shiny_human_df = shiny_human_df.loc[:,['sample_id',
                                    'res_index_label']]

final_H_df = pd.merge(left = human_df, 
                      right = shiny_human_df, 
                      left_on = 'extraction.tubeID', 
                      right_on = 'sample_id', 
                      how = 'inner')

final_H_df.drop('sample_id', axis=1, inplace=True)

# %%
final_H_df.head()
# Out:
#         date      limsSpecName rigOperator approach.manualRoi manualRoi  \
# 0 2017-11-27  H17.26.003.11.14      dijonh                NaN      TCx3
# 1 2017-11-27  H17.26.003.11.14      dijonh                NaN      TCx5
# 2 2017-11-27  H17.26.003.11.13      dijonh                NaN      TCx4
# 3 2017-11-27  H17.26.003.11.25      aarono                NaN      TCx3
# 4 2017-11-27  H17.26.003.11.16    lindsayn                NaN      TCx5
#
#   recording.humanCellTypePrediction     post_patch  patch_duration  \
# 0                               NaN  Nuc-high seal       23.716667
# 1                               NaN  Nuc-high seal       22.050000
# 2                         Pyramidal  Nuc-high seal       24.483333
# 3                         Pyramidal   No-high seal       20.850000
# 4               Unknown Interneuron   No-high seal       13.016667
#
#      extraction.tubeID  res_index_label
# 0  PBS4_171127_501_A01         1.000000
# 1  PBS4_171127_502_A01         1.000000
# 2  PBS4_171127_503_A01         0.681172
# 3  P6S4_171127_251_A01         0.254718
# 4  P8S4_171127_351_A01         0.386299

# %%
final_H_df.tail()
# Out:
#           date      limsSpecName rigOperator approach.manualRoi manualRoi  \
# 225 2018-03-20  H18.03.005.11.09      rustym                NaN      TCx2
# 226 2018-03-21  H18.03.005.11.04        ramr                NaN      TCx2
# 227 2018-03-27  H18.03.007.11.05      rustym                NaN      TCx3
# 228 2018-03-27  H18.03.007.11.05      rustym                NaN      TCx2
# 229 2018-03-27  H18.03.007.11.05      rustym                NaN      TCx2
#
#     recording.humanCellTypePrediction     post_patch  patch_duration  \
# 225                         Pyramidal   Nuc-low seal       21.116667
# 226               Unknown Interneuron    No-low seal       20.533333
# 227                         Pyramidal  Nuc-high seal        9.883333
# 228                         Pyramidal  Nuc-high seal       18.750000
# 229                         Pyramidal   No-high seal       25.083333
#
#        extraction.tubeID  res_index_label
# 225  P2S4_180320_057_A01         0.537958
# 226  PAS4_180321_451_A01         1.000000
# 227  P2S4_180327_055_A01         1.000000
# 228  P2S4_180327_056_A01         1.000000
# 229  P2S4_180327_057_A01         0.365141

# %% [markdown]
# ## MOUSE dataframe

# %%
json_df3 = json_df3.reset_index()
mouse_df = json_df3[['date',
                     'limsSpecName',
                     'rigOperator',
                     'approach.manualRoi',
                     'manualRoi', 
                     'post_patch',
                     'patch_duration',
                     'extraction.tubeID']]

mouse_df.sort_index(inplace = True)
#approach.manualRoi available data at 2017-10-02 to 2017-11-10
#manualRoi avaible data at 2017-11-10 to Present
#extraction.tubeID changes from ### to User_Date_###_A01 at 2017-11-10

shiny_mouse_df = shiny_mouse_df.loc[:,['sample_id',
                                       'res_index_label']]

final_M_df = pd.merge(left = mouse_df, 
                      right = shiny_mouse_df, 
                      left_on = 'extraction.tubeID', 
                      right_on = 'sample_id', 
                      how = 'inner')

final_M_df.drop('sample_id', axis=1, inplace=True)

# %%
final_M_df.head()
# Out:
#         date                                  limsSpecName rigOperator  \
# 0 2017-11-08              Pvalb-IRES-Cre;Ai14-357946.02.01      aarono
# 1 2017-11-10                Sst-IRES-Cre;Ai14-357932.04.01       lisak
# 2 2017-11-10  Nos1-CreERT2;Sst-IRES-FlpO;Ai65-357672.03.02    lindsayn
# 3 2017-11-10                Sst-IRES-Cre;Ai14-357932.02.02       lisak
# 4 2017-11-10              Nkx2-1-CreERT2;Ai14-357183.06.02        ramr
#
#   approach.manualRoi manualRoi     post_patch  patch_duration  \
# 0                NaN   VISp2/3   No-high seal       12.433333
# 1                NaN     VISp5    Entire cell        5.583333
# 2                NaN     VISp5   No-high seal       11.066667
# 3                NaN    VISp6a  Nuc-high seal        7.183333
# 4                NaN   VISp2/3   No-high seal        5.983333
#
#      extraction.tubeID  res_index_label
# 0  PXS4_171108_251_A01         0.458638
# 1  P9S4_171110_401_A01         0.329975
# 2  P8S4_171110_352_A01         0.458638
# 3  P9S4_171110_402_A01         1.000000
# 4  PAS4_171110_451_A01         0.329975

# %%
final_M_df.tail()
# Out:
#            date                        limsSpecName rigOperator  \
# 1318 2018-04-09      Vip-IRES-Cre;Ai14-383084.03.02    kristenh
# 1319 2018-04-10  Slc32a1-IRES-Cre;Ai14-384210.03.01    kristenh
# 1320 2018-04-10      Vip-IRES-Cre;Ai14-383085.03.02      rustym
# 1321 2018-04-10      Vip-IRES-Cre;Ai14-383085.05.01    kristenh
# 1322 2018-04-10      Vip-IRES-Cre;Ai14-383085.05.01    kristenh
#
#      approach.manualRoi manualRoi    post_patch  patch_duration  \
# 1318                NaN   VISp2/3  No-high seal        6.650000
# 1319                NaN   VISp2/3  No-high seal       15.733333
# 1320                NaN   VISp2/3  No-high seal       16.550000
# 1321                NaN   VISp2/3   Entire cell       13.316667
# 1322                NaN   VISp2/3   No-low seal        4.516667
#
#         extraction.tubeID  res_index_label
# 1318  P1S4_180409_002_A01         0.000000
# 1319  P1S4_180410_003_A01         0.688578
# 1320  P2S4_180410_051_A01         0.562351
# 1321  P1S4_180410_001_A01         1.000000
# 1322  P1S4_180410_002_A01         0.458638

# %% [markdown]
# ## Extra (Just messing around with code)

# %%
human_df['post_patch'].value_counts()
# Out:
# Nuc-high seal    183
# No-low seal      123
# No-high seal     108
# Nuc-low seal      49
# Entire cell        3
# Name: post_patch, dtype: int64

# %%
final_H_df['post_patch'].value_counts()
# Out:
# Nuc-high seal    79
# No-low seal      65
# No-high seal     59
# Nuc-low seal     25
# Entire cell       2
# Name: post_patch, dtype: int64

# %%
mouse_df['post_patch'].value_counts()
# Out:
# Nuc-high seal    1466
# No-high seal      541
# No-low seal       454
# Nuc-low seal      303
# Entire cell        41
# Name: post_patch, dtype: int64

# %%
final_M_df['post_patch'].value_counts()
# Out:
# Nuc-high seal    649
# No-low seal      257
# No-high seal     228
# Nuc-low seal     171
# Entire cell       18
# Name: post_patch, dtype: int64

# %%
def nuc_count(df):
    #user = str(input('Enter the user number (P#): '))
    user = 'PA'
    
    nh = df[df['post_patch'].str.contains('Nuc-high seal') & 
            df['extraction.tubeID'].str.contains(user)]
    nh = nh['post_patch'].count()

    nl = df[df['post_patch'].str.contains('Nuc-low seal') & 
            df['extraction.tubeID'].str.contains(user)]
    nl = nl['post_patch'].count()

    noh = df[df['post_patch'].str.contains('No-high seal') & 
             df['extraction.tubeID'].str.contains(user)]
    noh = noh['post_patch'].count()

    nol = df[df['post_patch'].str.contains('No-low seal') & 
             df['extraction.tubeID'].str.contains(user)]
    nol = nol['post_patch'].count()

    en = df[df['post_patch'].str.contains('Entire cell') & 
            df['extraction.tubeID'].str.contains(user)]
    en = en['post_patch'].count()
    

    print 'Nucleated:', nh
    print 'Partial nucleated', nl
    print 'Outside-out:', noh
    print 'No seal:', nol
    print 'Entire cell:', en

# %%
nuc_count(mouse_df)
# Out:
# Nucleated: 146
# Partial nucleated 61
# Outside-out: 11
# No seal: 42
# Entire cell: 8

# %%
nuc_count(final_M_df)
# Out:
# Nucleated: 93
# Partial nucleated 37
# Outside-out: 7
# No seal: 26
# Entire cell: 7

# %%
nuc_count(human_df)
# Out:
# Nucleated: 2
# Partial nucleated 4
# Outside-out: 2
# No seal: 10
# Entire cell: 0

# %%
nuc_count(final_H_df)
# Out:
# Nucleated: 2
# Partial nucleated 2
# Outside-out: 2
# No seal: 2
# Entire cell: 0
