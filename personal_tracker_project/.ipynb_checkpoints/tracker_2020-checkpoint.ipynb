# %% [markdown]
# # Personal Tracker 2020

# %%
"""
Tracker:
1) Count number of Mouse samples
2) Count number of Acute Human samples
3) Count number of Culture Human samples
4) COunt number of 63x go vs no go
5) Date Range Tracker Mouse/Human

"""
# Out:
# '\nTracker:\n1) Count number of Mouse samples\n2) Count number of Acute Human samples\n3) Count number of Culture Human samples\n4) COunt number of 63x go vs no go\n5) Date Range Tracker Mouse/Human\n\n'

# %% [markdown]
# ##### Imports

# %%
import os
import pandas as pd
import csv
import logging

import seaborn as sns
import matplotlib.pyplot as plt

# %%
from temp_funcs import read_file, merge_dataframes, drop_cols, drop_nans, filter_date_range, \
filter_df, create_container_col, create_cond_df, create_container_df

# %%
sns.set(context = "notebook", style = "ticks", font="verdana", font_scale = 1.35)
pd.set_option("display.max_colwidth",150) #Expands the number of characters shown in the columns
pd.set_option('display.max_columns', None)

# %%
path = "C:/Users/kumar/Documents/Github/analysis_projects/"
csv_path = os.path.join(path, "csv/")
#excel_path = os.path.join(path, "excel/")
#plot_path = os.path.join(path, "plot/")

path_jem = os.path.join(csv_path, "jem_metadata.csv")

# %%
fields_jem = ["approach.creCell",
              "container",
              "date",
              "extraction.extractionNotes",
              "name",
              "organism_name",
              "rigOperator",
              "roi_major",
              "roi_minor",
              "status"]

# %%
def main():
    """
    Main output
    
    global variables: jem
    """
    
    global jem
    
    jem = read_file(path_jem, fields_jem)
    jem = filter_df(jem, "rigOperator", "ramr")
    jem = filter_date_range(jem, "date")

# %%
if __name__ == "__main__":
    main()
# Out:
# INFO:temp_funcs:Read file in as a pandas dataframe
# INFO:temp_funcs:Filtered dataframe based on rigOperator == ramr
# C:\Users\kumar\Documents\GitHub\analysis_projects\personal_tracker_project\temp_funcs.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df.sort_values([date_col], inplace=True)
# INFO:temp_funcs:Filtered dataframe: 2020-01-01 - 2020-12-31

# %%
jem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 10990 to 11754
# Data columns (total 10 columns):
# organism_name                 152 non-null object
# name                          152 non-null object
# approach.creCell              152 non-null object
# date                          152 non-null object
# extraction.extractionNotes    152 non-null object
# rigOperator                   152 non-null object
# status                        152 non-null object
# roi_major                     152 non-null object
# roi_minor                     152 non-null object
# container                     152 non-null object
# dtypes: object(10)
# memory usage: 13.1+ KB

# %%
jem["date"] = jem["date"].str[:10]
jem["date"] = jem["date"].astype('datetime64[ns]')
jem["month"] = jem["date"].dt.strftime('%b')

# %%
jem
# Out:
#       organism_name  \
# 10990         Mouse
# 11004         Mouse
# 11033         Mouse
# 11034         Mouse
# 11035         Mouse
# 11036         Mouse
# 11045         Mouse
# 11046         Mouse
# 11053         Mouse
# 11052         Mouse
# 11064         Mouse
# 11068         Mouse
# 11069         Mouse
# 11070         Mouse
# 11081         Mouse
# 11078         Mouse
# 11079         Mouse
# 11080         Mouse
# 11104         Mouse
# 11102         Mouse
# 11103         Mouse
# 11110         Mouse
# 11111         Mouse
# 11112         Mouse
# 11121         Human
# 11122         Human
# 11123         Human
# 11128         Mouse
# 11127         Mouse
# 11129         Mouse
# 11651             None 2020-02-25
# 11675             Cre+ 2020-02-27
# 11676             Cre+ 2020-02-27
# 11682             Cre+ 2020-02-27
# 11685             Cre- 2020-02-27
# 11686             Cre- 2020-02-27
# 11694             Cre+ 2020-02-28
# 11695             Cre+ 2020-02-28
# 11707             Cre+ 2020-02-28
# 11708             Cre- 2020-02-28
# 11712             Cre- 2020-02-28
# 11713             Cre- 2020-02-28
# 11720             Cre+ 2020-03-02
# 11725             Cre+ 2020-03-02
# 11727             Cre+ 2020-03-02
# 11739             Cre+ 2020-03-03
# 11738             Cre+ 2020-03-03
# 11740             Cre+ 2020-03-03
# 11748             Cre+ 2020-03-03
# 11747             Cre+ 2020-03-03
# 11754             Cre+ 2020-03-03
#
#                             extraction.extractionNotes rigOperator   status  \
# 10990                                              #ND        ramr  SUCCESS
# 11004                                              #ND        ramr  SUCCESS
# 11033                                              #PD        ramr  SUCCESS
# 11034                                              #PL        ramr  SUCCESS
# 11035                                              #ND        ramr  SUCCESS
# 11036                                              #PD        ramr  SUCCESS
# 11045                                              #ND        ramr  SUCCESS
# 11046                                              #ND        ramr  SUCCESS
# 11053                                        #PD, asc.        ramr  SUCCESS
# 11052                                        #PL, asc.        ramr  SUCCESS
# 11064                                        #PD, des.        ramr  SUCCESS
# 11068                                        #NL, asc.        ramr  SUCCESS
# 11069                                        #ND, asc.        ramr  SUCCESS
# 11070                #comp WC 8.129, RS 80%. #ND, des.        ramr  SUCCESS
# 11081                                        #ND, asc.        ramr  SUCCESS
# 11078                                        #ND, asc.        ramr  SUCCESS
# 11079                                        #ND, des.        ramr  SUCCESS
# 11080                                        #ND, asc.        ramr  SUCCESS
# 11104                                        #NL, asc.        ramr  SUCCESS
# 11102                                        #NL, asc.        ramr  SUCCESS
# 11103                                        #PD, des.        ramr  SUCCESS
# 11110                                        #PD, des.        ramr  SUCCESS
# 11111                                        #PL, asc.        ramr  SUCCESS
# 11112                                        #ND, asc.        ramr  SUCCESS
# 11121                                        #PD, des.        ramr  SUCCESS
# 11122                                        #ND, asc.        ramr  SUCCESS
# 11123                                        #PL, asc.        ramr  SUCCESS
# 11128                                        #ND, des.        ramr  SUCCESS
# 11127                                        #ND, des.        ramr  SUCCESS
# 11129                                        #ND, asc.        ramr  SUCCESS
# ...                                                ...         ...      ...
# 11580                                              #PL        ramr  SUCCESS
# 11591                                        #ND, des.        ramr  SUCCESS
# 11592            #rs comp 31.863 MOhms, 80%. #ND, asc.        ramr  SUCCESS
# 11593                                         #PD, des        ramr  SUCCESS
# 11626                                         #PD, asc        ramr  SUCCESS
# 11627                                         #ND, asc        ramr  SUCCESS
# 11638                                        #NL, asc.        ramr  SUCCESS
# 11639                                        #PD, asc.        ramr  SUCCESS
# 11652                                         #PL, des        ramr  SUCCESS
# 11651                                         #ND, des        ramr  SUCCESS
# 11675                                        #ND, des.        ramr  SUCCESS
# 11676                                              #PL        ramr  SUCCESS
# 11682                                        #ND, des.        ramr  SUCCESS
# 11685                                        #ND, des.        ramr  SUCCESS
# 11686  #rs comp WC: 5.367 MOhms, corr: 80%. #NL, des.         ramr  SUCCESS
# 11694                                        #ND, asc.        ramr  SUCCESS
# 11695                                        #NL, asc.        ramr  SUCCESS
# 11707                                        #ND, asc.        ramr  SUCCESS
# 11708                                        #ND, asc.        ramr  SUCCESS
# 11712                                         #PD, des        ramr  SUCCESS
# 11713                                         #ND, asc        ramr  SUCCESS
# 11720                                        #ND, des.        ramr  SUCCESS
# 11725                                        #PL, des.        ramr  SUCCESS
# 11727                    #rs comp corr: 80%. #ND, des.        ramr  SUCCESS
# 11739                                        #ND, des.        ramr  SUCCESS
# 11738                                        #PL, des.        ramr  SUCCESS
# 11740                                        #PL, asc.        ramr  SUCCESS
# 11748                                        #NL, des.        ramr  SUCCESS
# 11747            #rs comp WC: 32.861 MOhms, corr: 80%.        ramr  SUCCESS
# 11754                                        #ND, asc.        ramr  SUCCESS
#
#       roi_major  roi_minor            container month
# 10990       MOp  layer 2/3  PAS4_200107_451_A01   Jan
# 11004      RSPd    layer 5  PAS4_200107_452_A01   Jan
# 11033       SSp    layer 5  PAS4_200110_454_A01   Jan
# 11034      RSPd    layer 5  PAS4_200110_452_A01   Jan
# 11035       SSp  layer 2/3  PAS4_200110_453_A01   Jan
# 11036       MOp    layer 5  PAS4_200110_451_A01   Jan
# 11045      RSPv  layer 2/3  PAS4_200110_455_A01   Jan
# 11046      RSPv  layer 2/3  PAS4_200110_456_A01   Jan
# 11053       ORB    layer 5  PAS4_200113_452_A01   Jan
# 11052       ORB    layer 5  PAS4_200113_451_A01   Jan
# 11064       SSp    layer 5  PAS4_200113_453_A01   Jan
# 11068       ORB  layer 2/3  PAS4_200114_453_A01   Jan
# 11069       ORB  layer 2/3  PAS4_200114_452_A01   Jan
# 11070     CTXsp        CLA  PAS4_200114_451_A01   Jan
# 11081      VISp    layer 5  PAS4_200114_454_A01   Jan
# 11078      RSPv    layer 5  PAS4_200114_456_A01   Jan
# 11079      RSPd  layer 2/3  PAS4_200114_457_A01   Jan
# 11080      VISp    layer 5  PAS4_200114_455_A01   Jan
# 11104       ORB    layer 5  PAS4_200116_452_A01   Jan
# 11102       MOp    layer 5  PAS4_200116_453_A01   Jan
# 11103     CTXsp        CLA  PAS4_200116_451_A01   Jan
# 11110      RSPd    layer 5  PAS4_200116_455_A01   Jan
# 11111      VISp    layer 5  PAS4_200116_454_A01   Jan
# 11112      RSPd  layer 2/3  PAS4_200116_456_A01   Jan
# 11121       TCx    layer 4  PAS4_200116_458_A01   Jan
# 11122       TCx    layer 4  PAS4_200116_459_A01   Jan
# 11123       TCx    layer 4  PAS4_200116_457_A01   Jan
# 11128      RSPv    layer 5  PAS4_200117_452_A01   Jan
# 11127      RSPv  layer 2/3  PAS4_200117_453_A01   Jan
# 11129      RSPd    layer 5  PAS4_200117_451_A01   Jan
# ...         ...        ...                  ...   ...
# 11580      RSPv  layer 2/3  PAS4_200220_455_A01   Feb
# 11591       ORB  layer 2/3  PAS4_200221_453_A01   Feb
# 11592       ORB    layer 5  PAS4_200221_451_A01   Feb
# 11593       ORB    layer 5  PAS4_200221_452_A01   Feb
# 11626       ORB  layer 2/3  PAS4_200225_452_A01   Feb
# 11627       ORB    layer 5  PAS4_200225_451_A01   Feb
# 11638      RSPv    layer 5  PAS4_200225_453_A01   Feb
# 11639      RSPv    layer 5  PAS4_200225_454_A01   Feb
# 11652       PCx    layer 4  PAS4_200225_456_A01   Feb
# 11651       PCx    layer 4  PAS4_200225_455_A01   Feb
# 11675      VISp   layer 6b  PAS4_200227_452_A01   Feb
# 11676      VISp   layer 6b  PAS4_200227_451_A01   Feb
# 11682      VISp   layer 6b  PAS4_200227_453_A01   Feb
# 11685      RSPv    layer 5  PAS4_200227_454_A01   Feb
# 11686      RSPd    layer 5  PAS4_200227_455_A01   Feb
# 11694      VISp   layer 6b  PAS4_200228_451_A01   Feb
# 11695      VISp   layer 6b  PAS4_200228_452_A01   Feb
# 11707      RSPd    layer 5  PAS4_200228_453_A01   Feb
# 11708      RSPd  layer 2/3  PAS4_200228_454_A01   Feb
# 11712      RSPv    layer 5  PAS4_200228_456_A01   Feb
# 11713      RSPd    layer 5  PAS4_200228_455_A01   Feb
# 11720       MOs    layer 5  PAS4_200302_451_A01   Mar
# 11725      RSPv  layer 2/3  PAS4_200302_452_A01   Mar
# 11727       MOs    layer 5  PAS4_200302_453_A01   Mar
# 11739       ORB  layer 2/3  PAS4_200303_452_A01   Mar
# 11738       ORB    layer 5  PAS4_200303_453_A01   Mar
# 11740       ORB    layer 5  PAS4_200303_451_A01   Mar
# 11748       MOp  layer 2/3  PAS4_200303_454_A01   Mar
# 11747       MOs    layer 1  PAS4_200303_455_A01   Mar
# 11754      RSPd    layer 5  PAS4_200303_456_A01   Mar
#
# [152 rows x 11 columns]

# %%
jem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 10990 to 11754
# Data columns (total 11 columns):
# organism_name                 152 non-null object
# name                          152 non-null object
# approach.creCell              152 non-null object
# date                          152 non-null datetime64[ns]
# extraction.extractionNotes    152 non-null object
# rigOperator                   152 non-null object
# status                        152 non-null object
# roi_major                     152 non-null object
# roi_minor                     152 non-null object
# container                     152 non-null object
# month                         152 non-null object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 14.2+ KB

# %%
f, axes = plt.subplots(figsize=(20, 20))
sns.countplot(x="month", data=jem, hue="organism_name")

# %%
sns.distplot(jem)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-7005d085624d> in <module>()
# ----> 1 sns.distplot(jem)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     196             line, = ax.plot(0, a.mean())
#     197         else:
# --> 198             line, = ax.plot(a.mean(), 0)
#     199         color = line.get_color()
#     200         line.remove()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__radd__()
#
# TypeError: unsupported operand type(s) for +: 'Timestamp' and 'str'

# %%
org_jem = jem[["date", "organism_name", "name", "container", "rigOperator", "status",
              "approach.creCell", "roi_major", "roi_minor", "extraction.extractionNotes"]]
