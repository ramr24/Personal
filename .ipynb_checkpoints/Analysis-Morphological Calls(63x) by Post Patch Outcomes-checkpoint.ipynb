# %% [markdown]
# ## Morphological Calls(63x) by Post Patch Outcomes

# %% [markdown]
# ##### Date: 4/03/18 Updated 63x.csv & shiny.csv

# %%
import csv
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline

from IPython.display import display #Found this to display all columns in a table

sns.set_style('whitegrid') #Makes a white backround with gray horizontal gridmarks at y-values
sns.set_context('notebook')

# %% [markdown]
# ##### postpatch_func.py by Rusty from Stash

# %%
def nucleated(x):
    nuc_high_seal = x[(x['anno.postPatch_label'] == 'Nucleated') | 
                      (((x['anno.postPatch_label'] == 'nucleus_visible') | 
                      (x['anno.postPatch_label'] == 'nucleus_present')) & 
                      (x['anno.endPipetteR_label'] >= 500))]
    return nuc_high_seal

def partial_nucleated(y):
    nuc_low_seal = y[(y['anno.postPatch_label'] == 'Partial-Nucleus') | 
                     (((y['anno.postPatch_label'] == 'nucleus_present') | 
                     (y['anno.postPatch_label'] == 'nucleus_visible')) & 
                     (y["anno.endPipetteR_label"] <= 499))]
    return nuc_low_seal

def outside_out(z):
    no_high_seal = z[(z['anno.postPatch_label'] == 'Outside-Out') | 
                     (((z['anno.postPatch_label'] == 'nucleus_absent') | 
                     (z['anno.postPatch_label'] == 'no_nucleus_visible')) & 
                     (z['anno.endPipetteR_label'] >= 500))]
    return no_high_seal

def no_seal(w): 
    no_low_seal = w[(w['anno.postPatch_label'] == 'No-Seal') | 
                    (((w['anno.postPatch_label'] == 'nucleus_absent') | 
                    (w['anno.postPatch_label'] == 'no_nucleus_visible')) & 
                    (w['anno.endPipetteR_label'] <= 499))]
    return no_low_seal
    
def entire_cell(v):
    entire = v[(v['anno.postPatch_label'] == 'Entire-Cell') | 
               (v['anno.postPatch_label'] == 'entire_cell')]
    return entire

#variable['post_patch'] = 'Term'
#Term is an output displayed in the Post_Patch column

def reclassify(df):
    nu = nucleated(df)
    nu['post_patch'] = 'Nuc-high seal' 
    oo = outside_out(df)
    oo['post_patch'] = 'No-high seal'
    pn = partial_nucleated(df)
    pn['post_patch'] = 'Nuc-low seal'
    ns = no_seal(df)
    ns['post_patch'] = 'No-low seal'
    ec = entire_cell(df)
    ec['post_patch'] = 'Entire cell'
    return  nu, oo, pn, ns, ec

def concat_df(a, b, c, d, e):
    frames = (a, b, c, d, e)
    df = pd.concat(frames)
    return df

def postpatch_reclass(df):
    return concat_df(*reclassify(df))

#final_df = postpatch_reclass(final_df)

# %% [markdown]
# ##### Reads 63x.csv & shiny.csv

# %%
morph_df = pd.read_csv("63x.csv")
shiny_df = pd.read_csv("shiny.csv")

# %% [markdown]
# ##### Creating shiny_df from shiny.csv

# %%
shiny_initial = ['anno.sample_id',
                 'anno.postPatch_label',
                 'anno.endPipetteR_label']
shiny_df = shiny_df[shiny_initial]
shiny_df.head()
# Out:
#         anno.sample_id anno.postPatch_label  anno.endPipetteR_label
# 0  P1S4_160318_069_A01                  O/O                     0.0
# 1  P1S4_160407_108_A01      nucleated patch                     0.0
# 2  P1S4_160407_109_A01      partial nucleus                     0.0
# 3  P1S4_160407_112_A01                  o/o                     0.0
# 4  P1S4_160407_113_A01                    0                     0.0

# %% [markdown]
# ##### Creating morph_df from 63x.csv

# %%
morph_initial = ['patched_cell_container',
                 'ims63x_go_no_go',
                 'project']
morph_df = morph_df[morph_initial]
morph_df.tail()
# Out:
#      patched_cell_container ims63x_go_no_go     project
# 6120    P2S4_180109_052_A01             NaN  mIVSCC-MET
# 6121    PAS4_180109_452_A01             NaN  mIVSCC-MET
# 6122    P8S4_180110_353_A01             NaN  mIVSCC-MET
# 6123    P8S4_180110_354_A01       63x no go  mIVSCC-MET
# 6124    PAS4_180110_454_A01             NaN  mIVSCC-MET

# %% [markdown]
# ##### Merging morph_df with shiny_lims_df to create final_df

# %%
#Inner merge = contains only matching data of both morph_df and shiny_df

final_df = pd.merge(left = morph_df, 
                    right = shiny_df, 
                    left_on = 'patched_cell_container', 
                    right_on = 'anno.sample_id', 
                    how = 'inner')

# %%
final_df.head()
# Out:
#   patched_cell_container ims63x_go_no_go     project       anno.sample_id  \
# 0    P8S4_180103_351_A01             NaN  mIVSCC-MET  P8S4_180103_351_A01
# 1    P8S4_180103_352_A01       63x no go  mIVSCC-MET  P8S4_180103_352_A01
# 2    P1S4_160517_001_A01             NaN       T301x  P1S4_160517_001_A01
# 3    P1S4_160517_003_A01             NaN       T301x  P1S4_160517_003_A01
# 4    P1S4_160517_004_A01             NaN       T301x  P1S4_160517_004_A01
#
#   anno.postPatch_label  anno.endPipetteR_label
# 0       nucleus_absent                    35.0
# 1      nucleus_present                     8.5
# 2      Partial nucleus                     0.0
# 3                  o/o                     0.0
# 4                  o/o                     0.0

# %% [markdown]
# ##### Creating Date column using patched_cell_container column

# %%
final_df['Date'] = final_df['patched_cell_container'].str[5:11]

# %%
final_df.tail()
# Out:
#      patched_cell_container ims63x_go_no_go     project       anno.sample_id  \
# 2675    P2S4_180109_052_A01             NaN  mIVSCC-MET  P2S4_180109_052_A01
# 2676    PAS4_180109_452_A01             NaN  mIVSCC-MET  PAS4_180109_452_A01
# 2677    P8S4_180110_353_A01             NaN  mIVSCC-MET  P8S4_180110_353_A01
# 2678    P8S4_180110_354_A01       63x no go  mIVSCC-MET  P8S4_180110_354_A01
# 2679    PAS4_180110_454_A01             NaN  mIVSCC-MET  PAS4_180110_454_A01
#
#      anno.postPatch_label  anno.endPipetteR_label    Date
# 2675      nucleus_present                  1000.0  180109
# 2676      nucleus_present                  1500.0  180109
# 2677       nucleus_absent                   100.0  180110
# 2678      nucleus_present                  1000.0  180110
# 2679      nucleus_present                  1000.0  180110

# %% [markdown]
# ##### Indexing Date column then sorting by date index

# %%
final_df = final_df.set_index('Date')
final_df = final_df.sort_index()

# %%
final_df.head()
# Out:
#        patched_cell_container ims63x_go_no_go project       anno.sample_id  \
# Date
# 160510    P1S4_160510_455_A01             NaN   T301x  P1S4_160510_455_A01
# 160511    P1S4_160511_473_A01             NaN   T301x  P1S4_160511_473_A01
# 160511    P1S4_160511_472_A01             NaN   T301x  P1S4_160511_472_A01
# 160511    P1S4_160511_471_A01             NaN   T301x  P1S4_160511_471_A01
# 160512    P1S4_160512_485_A01             NaN   T301x  P1S4_160512_485_A01
#
#        anno.postPatch_label  anno.endPipetteR_label
# Date
# 160510                    0                     0.0
# 160511                    0                     0.0
# 160511      Partial nucleus                     0.0
# 160511                    0                     0.0
# 160512                  o/o                     0.0

# %%
final_df.tail()
# Out:
#        patched_cell_container ims63x_go_no_go     project  \
# Date
# 180221    P2S4_180221_052_A01             NaN  mIVSCC-MET
# 180221    P8S4_180221_353_A01             NaN  mIVSCC-MET
# 180221    P8S4_180221_352_A01             NaN  mIVSCC-MET
# 180221    P9S4_180221_401_A01             NaN  mIVSCC-MET
# 180221    P1S4_180221_001_A01             NaN  mIVSCC-MET
#
#              anno.sample_id anno.postPatch_label  anno.endPipetteR_label
# Date
# 180221  P2S4_180221_052_A01       nucleus_absent                    10.0
# 180221  P8S4_180221_353_A01      nucleus_present                   100.0
# 180221  P8S4_180221_352_A01      nucleus_present                   400.0
# 180221  P9S4_180221_401_A01      nucleus_present                  2500.0
# 180221  P1S4_180221_001_A01      nucleus_present                  3000.0

# %% [markdown]
# ##### final_df start at production date to present date

# %%
final_df = final_df['170901':]

# %%
final_df.head()
# Out:
#        patched_cell_container ims63x_go_no_go project       anno.sample_id  \
# Date
# 170901    P8S4_170901_355_A01          63x go   T301x  P8S4_170901_355_A01
# 170901    P2S4_170901_051_A01          63x go   T301x  P2S4_170901_051_A01
# 170901    P8S4_170901_353_A01       63x no go   T301x  P8S4_170901_353_A01
# 170901    P2S4_170901_054_A01          63x go   T301x  P2S4_170901_054_A01
# 170901    P2S4_170901_052_A01          63x go   T301x  P2S4_170901_052_A01
#
#        anno.postPatch_label  anno.endPipetteR_label
# Date
# 170901              No-Seal                     0.0
# 170901            Nucleated                     0.0
# 170901              No-Seal                     0.0
# 170901      Partial-Nucleus                     0.0
# 170901            Nucleated                     0.0

# %%
final_df.tail()
# Out:
#        patched_cell_container ims63x_go_no_go     project  \
# Date
# 180221    P2S4_180221_052_A01             NaN  mIVSCC-MET
# 180221    P8S4_180221_353_A01             NaN  mIVSCC-MET
# 180221    P8S4_180221_352_A01             NaN  mIVSCC-MET
# 180221    P9S4_180221_401_A01             NaN  mIVSCC-MET
# 180221    P1S4_180221_001_A01             NaN  mIVSCC-MET
#
#              anno.sample_id anno.postPatch_label  anno.endPipetteR_label
# Date
# 180221  P2S4_180221_052_A01       nucleus_absent                    10.0
# 180221  P8S4_180221_353_A01      nucleus_present                   100.0
# 180221  P8S4_180221_352_A01      nucleus_present                   400.0
# 180221  P9S4_180221_401_A01      nucleus_present                  2500.0
# 180221  P1S4_180221_001_A01      nucleus_present                  3000.0

# %% [markdown]
# ##### Renaming Columns

# %%
#Duration columns are in seconds
final_df.rename(columns = {'ims63x_go_no_go' : 'morphology'}, inplace = True)

# %%
final_df.head()
# Out:
#        patched_cell_container morphology project       anno.sample_id  \
# Date
# 170901    P8S4_170901_355_A01     63x go   T301x  P8S4_170901_355_A01
# 170901    P2S4_170901_051_A01     63x go   T301x  P2S4_170901_051_A01
# 170901    P8S4_170901_353_A01  63x no go   T301x  P8S4_170901_353_A01
# 170901    P2S4_170901_054_A01     63x go   T301x  P2S4_170901_054_A01
# 170901    P2S4_170901_052_A01     63x go   T301x  P2S4_170901_052_A01
#
#        anno.postPatch_label  anno.endPipetteR_label
# Date
# 170901              No-Seal                     0.0
# 170901            Nucleated                     0.0
# 170901              No-Seal                     0.0
# 170901      Partial-Nucleus                     0.0
# 170901            Nucleated                     0.0

# %%
final_df.tail()
# Out:
#        patched_cell_container morphology     project       anno.sample_id  \
# Date
# 180221    P2S4_180221_052_A01        NaN  mIVSCC-MET  P2S4_180221_052_A01
# 180221    P8S4_180221_353_A01        NaN  mIVSCC-MET  P8S4_180221_353_A01
# 180221    P8S4_180221_352_A01        NaN  mIVSCC-MET  P8S4_180221_352_A01
# 180221    P9S4_180221_401_A01        NaN  mIVSCC-MET  P9S4_180221_401_A01
# 180221    P1S4_180221_001_A01        NaN  mIVSCC-MET  P1S4_180221_001_A01
#
#        anno.postPatch_label  anno.endPipetteR_label
# Date
# 180221       nucleus_absent                    10.0
# 180221      nucleus_present                   100.0
# 180221      nucleus_present                   400.0
# 180221      nucleus_present                  2500.0
# 180221      nucleus_present                  3000.0

# %% [markdown]
# ##### Adding post_patch column to the end of final_df

# %%
final_df = postpatch_reclass(final_df)
final_df.tail()
# Out:
# C:\Users\ramr\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ramr\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ramr\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ramr\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ramr\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        patched_cell_container morphology     project       anno.sample_id  \
# Date
# 180124    P9S4_180124_405_A01        NaN  mIVSCC-MET  P9S4_180124_405_A01
# 180126    P9S4_180126_404_A01        NaN  mIVSCC-MET  P9S4_180126_404_A01
# 180205    P1S4_180205_003_A01  63x no go  mIVSCC-MET  P1S4_180205_003_A01
# 180207    P1S4_180207_003_A01        NaN  mIVSCC-MET  P1S4_180207_003_A01
# 180220    PAS4_180220_451_A01        NaN  mIVSCC-MET  PAS4_180220_451_A01
#
#        anno.postPatch_label  anno.endPipetteR_label   post_patch
# Date
# 180124          entire_cell                     4.0  Entire cell
# 180126          entire_cell                    11.5  Entire cell
# 180205          entire_cell                     5.0  Entire cell
# 180207          entire_cell                     3.0  Entire cell
# 180220          entire_cell                     5.7  Entire cell

# %% [markdown]
# ##### Dropping columns

# %%
final_df.drop(['patched_cell_container', 'project', 'anno.sample_id', 'anno.endPipetteR_label'], axis=1, inplace=True)
final_df.head()
# Out:
#        morphology anno.postPatch_label     post_patch
# Date
# 170901     63x go            Nucleated  Nuc-high seal
# 170901     63x go            Nucleated  Nuc-high seal
# 170901        NaN            Nucleated  Nuc-high seal
# 170901  63x no go            Nucleated  Nuc-high seal
# 170906     63x go            Nucleated  Nuc-high seal

# %%
final_df.tail()
# Out:
#        morphology anno.postPatch_label   post_patch
# Date
# 180124        NaN          entire_cell  Entire cell
# 180126        NaN          entire_cell  Entire cell
# 180205  63x no go          entire_cell  Entire cell
# 180207        NaN          entire_cell  Entire cell
# 180220        NaN          entire_cell  Entire cell

# %% [markdown]
# ##### Filters columns that have NaN

# %%
final_df.dropna(subset = ['morphology'], inplace = True)

# %%
final_df.head()
# Out:
#        morphology anno.postPatch_label     post_patch
# Date
# 170901     63x go            Nucleated  Nuc-high seal
# 170901     63x go            Nucleated  Nuc-high seal
# 170901  63x no go            Nucleated  Nuc-high seal
# 170906     63x go            Nucleated  Nuc-high seal
# 170906  63x no go            Nucleated  Nuc-high seal

# %%
final_df.tail()
# Out:
#        morphology anno.postPatch_label   post_patch
# Date
# 171101  63x no go          entire_cell  Entire cell
# 171102     63x go          entire_cell  Entire cell
# 171116     63x go          entire_cell  Entire cell
# 171211  63x no go          entire_cell  Entire cell
# 180205  63x no go          entire_cell  Entire cell

# %%
#Categorical
final_df['morphology'] = final_df['morphology'].astype('category')
final_df['post_patch'] = final_df['post_patch'].astype('category')

#Numerical
#final_df['anno.endPipetteR_label'] = final_df['anno.endPipetteR_label'].astype('float')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 170901 to 180205
# Data columns (total 3 columns):
# morphology              891 non-null category
# anno.postPatch_label    891 non-null object
# post_patch              891 non-null category
# dtypes: category(2), object(1)
# memory usage: 16.0+ KB

# %% [markdown]
# ### Creating pivot table

# %%
final_df1 = final_df[['post_patch', 'morphology', 'anno.postPatch_label']]
final_df1.head()
# Out:
#            post_patch morphology anno.postPatch_label
# Date
# 170901  Nuc-high seal     63x go            Nucleated
# 170901  Nuc-high seal     63x go            Nucleated
# 170901  Nuc-high seal  63x no go            Nucleated
# 170906  Nuc-high seal     63x go            Nucleated
# 170906  Nuc-high seal  63x no go            Nucleated

# %%
final_df1 = final_df.groupby(['post_patch', 'morphology']).count()

# %%
final_df1
# Out:
#                           anno.postPatch_label
# post_patch    morphology
# Entire cell   63x go                         4
#               63x no go                      8
# No-high seal  63x go                        18
#               63x no go                     11
# No-low seal   63x go                        17
#               63x no go                    137
# Nuc-high seal 63x go                       407
#               63x no go                    169
# Nuc-low seal  63x go                        41
#               63x no go                     79

# %%
final_df1 = final_df1.rename(columns = {'anno.postPatch_label' : ''})

# %%
final_df1
# Out:
#
# post_patch    morphology
# Entire cell   63x go        4
#               63x no go     8
# No-high seal  63x go       18
#               63x no go    11
# No-low seal   63x go       17
#               63x no go   137
# Nuc-high seal 63x go      407
#               63x no go   169
# Nuc-low seal  63x go       41
#               63x no go    79

# %%
final_df1.reset_index(inplace = True)

# %%
final_df1
# Out:
#       post_patch morphology
# 0    Entire cell     63x go    4
# 1    Entire cell  63x no go    8
# 2   No-high seal     63x go   18
# 3   No-high seal  63x no go   11
# 4    No-low seal     63x go   17
# 5    No-low seal  63x no go  137
# 6  Nuc-high seal     63x go  407
# 7  Nuc-high seal  63x no go  169
# 8   Nuc-low seal     63x go   41
# 9   Nuc-low seal  63x no go   79

# %%
final_df1 = final_df1.pivot_table(values=[''], 
                                  index=['post_patch'], 
                                  columns = ['morphology'], 
                                  aggfunc='sum')

# %%
final_df1
# Out:
#
# morphology    63x go 63x no go
# post_patch
# Entire cell        4         8
# No-high seal      18        11
# No-low seal       17       137
# Nuc-high seal    407       169
# Nuc-low seal      41        79

# %% [markdown]
# ##### Adding total counts

# %%
#Rusty's Method figure it out later
post_patch_totals = list(final_df1.sum(1))
post_patch_totals = [int(x) for x in post_patch_totals]

# %% [markdown]
# ##### Aaron's method for Plot: Morphological Calls(63x) by Post Patch Outcomes

# %%
x = ['Nuc-high seal', 'Nuc-low seal', 'No-high seal', 'No-low seal', 'Entire cell']
morph = ['63x go', '63x no go']
#color = ["r", "g"]

bottom = np.zeros(len(x))
y = np.zeros(len(x))
for mp in morph:
    bottom = bottom + y
    y = [len(final_df[(final_df['post_patch'] == f) & (final_df['morphology'] == mp)]) for f in x]
    plt.bar(x, y, bottom = bottom, label = mp)
    
plt.xlabel('Post Patch Outcomes')
plt.ylabel('Count of Morphological Calls')
plt.legend()
plt.title('Count of Morphological Calls by Post Patch Outcomes')
#plt.savefig("count_patch_duration_vs_morph")
# Out:
# Text(0.5,1,u'Count of Morphological Calls by Post Patch Outcomes')

# %% [markdown]
# ##### Same Plot as Aaron's Method

# %%
my_colors = ['#74c476', '#de2d26']
bp = final_df1.plot.bar(stacked=True, color = my_colors)

bp.legend(loc = 0, bbox_to_anchor=(1, 1))
bp.set(xlabel = 'Post Patch Outcomes', ylabel = 'Count')
# Out:
# [Text(0,0.5,u'Count'), Text(0.5,0,u'Post Patch Outcomes')]

# %% [markdown]
# ##### Vertical Bar Plot

# %% [markdown]
# ##### Changed final_df1 from ratios to percentages

# %%
final_df1 = final_df1.div(final_df1.sum(1), axis=0) * 100

# %%
final_df1
# Out:
#
# morphology        63x go  63x no go
# post_patch
# Entire cell    33.333333  66.666667
# No-high seal   62.068966  37.931034
# No-low seal    11.038961  88.961039
# Nuc-high seal  70.659722  29.340278
# Nuc-low seal   34.166667  65.833333

# %% [markdown]
# ### Stacked Percentage Bar Plot: Morphological Calls(63x) by Post Patch Outcomes

# %% [markdown]
# ### Vertical Bar Plot with Percentages

# %%
my_colors = ['#74c476', '#de2d26']
bp = final_df1.plot.bar(stacked = True, 
                        color = my_colors, 
                        figsize= (10,8),
                        rot = 0)

bp.legend(['63x go', '63x no go', ], loc = 0, bbox_to_anchor=(1, 1), frameon = True, fontsize = 10)
plt.subplots_adjust(left = 0.1, right = 0.85, bottom = None, top = None, wspace=None, hspace=None)
#This helps if axis labels are getting cutoff when saving final image

#Rusty's Method figure it out later
rects = bp.patches
labels = post_patch_totals

#Rusty's Method figure it out later
for rect, label in zip (rects, labels):
    height = 100
    x_value = rect.get_x() + rect.get_width() / 2
    bp.text(rect.get_x() + rect.get_width()/2, height, label, ha='center', va='bottom', size = 12)

bp.set_title('Percentage of Morphological Calls(63x) by Post Patch Outcomes')
bp.set(xlabel = 'Post Patch Outcomes', ylabel = 'Percentage')
plt.savefig('Stacked_Percentage_Barplot_M_by_PP')

# %% [markdown]
# ##### Horizontal Bar Plot with Percentages

# %%
#plt.subplots(figsize=(12,10))
#Doesn't work if plot already has option to change fig size

my_colors = ['#74c476', '#de2d26']
bp = final_df1.plot(kind = 'barh', 
                    stacked = True, 
                    color = my_colors,
                    figsize= (8,5))

bp.set(xlabel = 'Percentage', ylabel = 'Post Patch Outcomes')
bp.legend(loc = 0, bbox_to_anchor=(1, 1))
