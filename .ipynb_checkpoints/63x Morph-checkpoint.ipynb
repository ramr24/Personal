# %% [markdown]
# ## Patch Duration vs. Morphological Calls(63x) per Post Patch Outcomes

# %% [markdown]
# ##### Date: 9/01/2017-2/16/2018 & Update to recent csv by custom reports cell report card 'T301x', 'mIVSCC-MET'

# %%
#Import necessary functions
import csv
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline
import pg8000          #pg8000 access SQL databases
import pandas as pd    #pandas will be needed to work in a dataframe

#Makes a white backround with gray horizontal gridmarks at y-values
sns.set_style('whitegrid')
sns.set_context('notebook')

from IPython.display import display #Found this to display all columns in a table

#Context: paper
#Context: notebook
#Context: talk
#Context: poster

# %%
#Code from Agata
#Opens LIMS, makes a query and then closes LIMS after

def _connect(user="limsreader", host="limsdb2", database="lims2", password="limsro", port=5432):
    conn = pg8000.connect(user=user, host=host, database=database, password=password, port=port)
    return conn, conn.cursor()

def _select(cursor, query):
    cursor.execute(query)
    columns = [ d[0] for d in cursor.description ]
    return [ dict(zip(columns, c)) for c in cursor.fetchall() ]

def limsquery(query, user="limsreader", host="limsdb2", database="lims2", password="limsro", port=5432):
    """A function that takes a string containing a SQL query, connects to the LIMS database and outputs the result."""
    conn, cursor = _connect(user, host, database, password, port)
    try:
        results = _select(cursor, query)
    finally:
        #THESE ARE IMPORTANT!!!!!! (Every query needs to be closed when done)
        #This closes query
        cursor.close()             
        conn.close()
    return results


#This last function will take our query results and put them in a dataframe so that they are easy to work with
def get_lims_dataframe(query):
    '''Return a dataframe with lims query'''
    result = limsquery(query)
    try:
        data_df = pd.DataFrame(data=result, columns=result[0].keys())
    except IndexError:
        print "Could not find results for your query."
        data_df = pd.DataFrame()
    return data_df

# %%
my_query = 'SELECT specimens.name, specimens.patched_cell_container FROM specimens'

lims_df = get_lims_dataframe(my_query)
lims_df.tail()
# Out:
#        patched_cell_container                                          name
# 437750    P8S4_171016_356_A01          Chrna2-Cre_OE25;Ai14-355016.05.02.02
# 437751    PBS4_180306_502_A01           Pvalb-IRES-Cre;Ai14-378390.04.02.01
# 437752                   None                Nr5a1-Cre;Ai14-378059.10.06.01
# 437753                   None                Nr5a1-Cre;Ai14-378059.11.06.01
# 437754                   None  Nos1-CreERT2;Sst-IRES-FlpO;Ai65-377372.06.02

# %%
df = pd.read_csv("63x.csv")
shiny_df = pd.read_csv("shiny.csv")

# %%
shiny_initial = ['anno.sample_id',
                 'anno.Total_time_label',
                 'anno.Ephys_time_label',
                 'anno.Retraction_time_label',
                 'anno.postPatch_label',
                 'anno.endPipetteR_label']
shiny_df = shiny_df[shiny_initial]
shiny_df.head()
# Out:
#         anno.sample_id  anno.Total_time_label  anno.Ephys_time_label  \
# 0  P1S4_160318_069_A01                      0                      0
# 1  P1S4_160407_108_A01                      0                      0
# 2  P1S4_160407_109_A01                      0                      0
# 3  P1S4_160407_112_A01                      0                      0
# 4  P1S4_160407_113_A01                      0                      0
#
#    anno.Retraction_time_label anno.postPatch_label  anno.endPipetteR_label
# 0                           0                  O/O                     0.0
# 1                           0      nucleated patch                     0.0
# 2                           0      partial nucleus                     0.0
# 3                           0                  o/o                     0.0
# 4                           0                    0                     0.0

# %%
shinyLIMS_df = pd.merge(left = shiny_df, right = lims_df, left_on = 'anno.sample_id', right_on = 'patched_cell_container', how = 'left')

# %%
display(shinyLIMS_df)
# Out:
#            anno.sample_id  anno.Total_time_label  anno.Ephys_time_label  \
# 0     P1S4_160318_069_A01                      0                      0
# 1     P1S4_160407_108_A01                      0                      0
# 2     P1S4_160407_109_A01                      0                      0
# 3     P1S4_160407_112_A01                      0                      0
# 4     P1S4_160407_113_A01                      0                      0
# 5     P1S4_160407_114_A01                      0                      0
# 6     P1S4_160408_121_A01                      0                      0
# 7     P1S4_160408_123_A01                      0                      0
# 8     P1S4_160408_124_A01                      0                      0
# 9     P1S4_160408_125_A01                      0                      0
# 10    P1S4_160408_126_A01                      0                      0
# 11    P1S4_160318_072_A01                      0                      0
# ...

# %%
#list_initial = list with specific columns used from csv file
list_initial = ['recording_date',
                'project', 
                'cell_specimen_name', 
                'ims63x_go_no_go',
                'ephys_seal_gohm']
df = df[list_initial]
df.tail()
# Out:
#      recording_date     project  \
# 6028            NaN  mIVSCC-MET
# 6029            NaN  mIVSCC-MET
# 6030            NaN  mIVSCC-MET
# 6031            NaN  mIVSCC-MET
# 6032            NaN  mIVSCC-MET
#
#                                      cell_specimen_name ims63x_go_no_go  \
# 6028                  Vip-IRES-Cre;Ai14-363633.04.01.01             NaN
# 6029                  Vip-IRES-Cre;Ai14-363633.04.01.02          63x go
# 6030  Vipr2-IRES2-Cre;Pvalb-T2A-FlpO;Ai65-349552.03....             NaN
# 6031  Vipr2-IRES2-Cre;Pvalb-T2A-FlpO;Ai65-349552.05....             NaN
# 6032  Vipr2-IRES2-Cre;Pvalb-T2A-FlpO;Ai65-349552.06....             NaN
#
#       ephys_seal_gohm
# 6028              NaN
# 6029              NaN
# 6030              NaN
# 6031              NaN
# 6032              NaN

# %%
final_df = pd.merge(left = df, right = shinyLIMS_df, left_on = 'cell_specimen_name', right_on = 'name', how = 'inner')

# %%
final_df.tail(50)
# Out:
#                recording_date     project  \
# recording_date
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT       T301x
# NaT                       NaT       T301x
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT       T301x
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT       T301x
# NaT                       NaT       T301x
# NaT                       NaT       T301x
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT       T301x
# NaT                       NaT       T301x
# NaT                       NaT  mIVSCC-MET
# ...

# %%
final_df['month'] = final_df['recording_date'].str.split('/').str[0]
final_df['day'] = final_df['recording_date'].str.split('/').str[1]
final_df['year'] = final_df['recording_date'].str.split('/').str[2]

# %%
final_df['month'] = final_df['month'].apply(lambda x: '{0:0>2}'.format(x))
final_df['day'] = final_df['day'].apply(lambda x: '{0:0>2}'.format(x))
final_df['year'] = final_df['year'].str[:4]

# %%
final_df['recording_date'] = final_df['month'] + final_df['day'] + final_df['year']
final_df.head()
# Out:
#   recording_date project                     cell_specimen_name  \
# 0       05102016   T301x  Rorb-IRES2-Cre-D;Ai14-245133.07.01.01
# 1       05112016   T301x    Scnn1a-Tg2-Cre;Ai14-245345.02.02.01
# 2       05112016   T301x    Scnn1a-Tg2-Cre;Ai14-245345.07.01.01
# 3       05112016   T301x    Scnn1a-Tg2-Cre;Ai14-245345.07.01.02
# 4       05122016   T301x  Rorb-IRES2-Cre-D;Ai14-245132.07.02.04
#
#   ims63x_go_no_go  ephys_seal_gohm       anno.sample_id  \
# 0             NaN         1.158136  P1S4_160510_455_A01
# 1             NaN         1.045532  P1S4_160511_471_A01
# 2             NaN         4.639288  P1S4_160511_472_A01
# 3             NaN         1.187988  P1S4_160511_473_A01
# 4             NaN         3.153809  P1S4_160512_485_A01
#
#    anno.Total_time_label  anno.Ephys_time_label  anno.Retraction_time_label  \
# 0                      0                      0                           0
# 1                      0                      0                           0
# ...

# %%
final_df['recording_date'] = pd.to_datetime(final_df['recording_date'], format = '%m%d%Y')
final_df.tail()
# Out:
# C:\Users\ramr\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                recording_date     project  \
# recording_date
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
#
#                                                cell_specimen_name  \
# recording_date
# NaT                             Vip-IRES-Cre;Ai14-363633.04.01.01
# NaT                             Vip-IRES-Cre;Ai14-363633.04.01.02
# NaT             Vipr2-IRES2-Cre;Pvalb-T2A-FlpO;Ai65-349552.03....
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2649 entries, 0 to 2648
# Data columns (total 16 columns):
# recording_date                2540 non-null datetime64[ns]
# project                       2649 non-null object
# cell_specimen_name            2649 non-null object
# ims63x_go_no_go               1494 non-null object
# ephys_seal_gohm               2520 non-null float64
# anno.sample_id                2649 non-null object
# anno.Total_time_label         2649 non-null int64
# anno.Ephys_time_label         2649 non-null int64
# anno.Retraction_time_label    2649 non-null int64
# anno.postPatch_label          2641 non-null object
# anno.endPipetteR_label        2649 non-null float64
# patched_cell_container        2649 non-null object
# name                          2649 non-null object
# month                         2649 non-null object
# day                           2649 non-null object
# year                          2540 non-null object
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2649 entries, 0 to 2648
# Data columns (total 16 columns):
# recording_date                2540 non-null datetime64[ns]
# project                       2649 non-null object
# cell_specimen_name            2649 non-null object
# ims63x_go_no_go               1494 non-null object
# ephys_seal_gohm               2520 non-null float64
# anno.sample_id                2649 non-null object
# anno.Total_time_label         2649 non-null int64
# anno.Ephys_time_label         2649 non-null int64
# anno.Retraction_time_label    2649 non-null int64
# anno.postPatch_label          2641 non-null object
# anno.endPipetteR_label        2649 non-null float64
# patched_cell_container        2649 non-null object
# name                          2649 non-null object
# month                         2649 non-null object
# day                           2649 non-null object
# year                          2540 non-null object
# ...

# %%
final_df = final_df.set_index(final_df['recording_date'])
final_df
# Out:
#                recording_date     project  \
# recording_date
# 2016-05-10         2016-05-10       T301x
# 2016-05-11         2016-05-11       T301x
# 2016-05-11         2016-05-11       T301x
# 2016-05-11         2016-05-11       T301x
# 2016-05-12         2016-05-12       T301x
# 2016-05-12         2016-05-12       T301x
# 2016-05-13         2016-05-13       T301x
# 2016-05-13         2016-05-13       T301x
# 2016-05-13         2016-05-13       T301x
# 2016-05-16         2016-05-16       T301x
# 2016-05-16         2016-05-16       T301x
# 2016-05-16         2016-05-16       T301x
# 2016-05-16         2016-05-16       T301x
# 2016-05-16         2016-05-16       T301x
# 2016-05-17         2016-05-17       T301x
# 2016-05-17         2016-05-17       T301x
# 2016-05-17         2016-05-17       T301x
# 2016-05-17         2016-05-17       T301x
# 2016-05-18         2016-05-18       T301x
# 2016-05-18         2016-05-18       T301x
# 2016-05-18         2016-05-18       T301x
# ...

# %%
final_df = final_df['20170901':]

# %%
final_df.tail()
# Out:
#                recording_date     project  \
# recording_date
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
# NaT                       NaT  mIVSCC-MET
#
#                                                cell_specimen_name  \
# recording_date
# NaT                             Vip-IRES-Cre;Ai14-363633.04.01.01
# NaT                             Vip-IRES-Cre;Ai14-363633.04.01.02
# NaT             Vipr2-IRES2-Cre;Pvalb-T2A-FlpO;Ai65-349552.03....
# NaT             Vipr2-IRES2-Cre;Pvalb-T2A-FlpO;Ai65-349552.05....
# NaT             Vipr2-IRES2-Cre;Pvalb-T2A-FlpO;Ai65-349552.06....
#
#                ims63x_go_no_go  ephys_seal_gohm       anno.sample_id  \
# recording_date
# NaT                        NaN              NaN  P6S4_171219_251_A01
# NaT                     63x go              NaN  P6S4_171219_252_A01
# ...

# %%
final_df['date'] = final_df['anno.sample_id'].str.split('_').str[1]
# Out:
# C:\Users\ramr\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
final_df
# Out:
#                recording_date     project  \
# recording_date
# 2017-09-01         2017-09-01       T301x
# 2017-09-01         2017-09-01       T301x
# 2017-09-01         2017-09-01       T301x
# 2017-09-01         2017-09-01       T301x
# 2017-09-01         2017-09-01       T301x
# 2017-09-01         2017-09-01       T301x
# 2017-09-01         2017-09-01       T301x
# 2017-09-01         2017-09-01       T301x
# 2017-09-01         2017-09-01       T301x
# 2017-09-06         2017-09-06       T301x
# 2017-09-06         2017-09-06       T301x
# 2017-09-11         2017-09-11       T301x
# 2017-09-11         2017-09-11       T301x
# 2017-09-11         2017-09-11       T301x
# 2017-09-12         2017-09-12       T301x
# 2017-09-12         2017-09-12       T301x
# 2017-09-12         2017-09-12       T301x
# 2017-09-12         2017-09-12       T301x
# 2017-09-12         2017-09-12       T301x
# 2017-09-13         2017-09-13       T301x
# 2017-09-13         2017-09-13       T301x
# ...

# %%
#Drops all rows that have NaN specifically in column 63x go or no
df.dropna(subset = ['ims63x_go_no_go'], inplace = True)

# %% [markdown]
# ##### Split dataframe (Production Date to Present)

# %%
df.head(800) #look at 3894
# Out:
#         recording_date project                        cell_specimen_name  \
# 241    5/26/2016 10:30   T301x  Vip-IRES-Cre;Ai14(IVSCC)-247697.03.01.01
# 304    6/15/2016 10:50   T301x     Nos1-CreERT2;Ai14(BT)-251975.03.01.01
# 445     8/1/2016 12:11   T301x        Chat-IRES-Cre;Ai14-261748.03.01.02
# 458     8/3/2016 10:57   T301x        Chat-IRES-Cre;Ai14-261746.03.01.01
# 1138  10/24/2016 11:21   T301x        Gad2-IRES-Cre;Ai14-280180.07.01.02
# 1150  10/25/2016 10:58   T301x        Gad2-IRES-Cre;Ai14-280036.07.02.01
# 1157  10/25/2016 14:08   T301x        Gad2-IRES-Cre;Ai14-280036.07.01.04
# 1172  10/26/2016 13:34   T301x        Gad2-IRES-Cre;Ai14-280035.07.02.02
# 1177  10/26/2016 14:51   T301x        Gad2-IRES-Cre;Ai14-280035.07.02.04
# 1181  10/27/2016 11:09   T301x        Gad2-IRES-Cre;Ai14-280034.08.01.01
# 1182  10/27/2016 11:25   T301x        Gad2-IRES-Cre;Ai14-280034.07.01.03
# 1245   11/2/2016 11:01   T301x        Gad2-IRES-Cre;Ai14-280183.07.01.01
# ...

# %%
#Creating new dataframe by splitting at loc 3894
#3894 is where 9/01/2017 starts (production date)
df1 = df.loc[3894:]
df1.head()
# Out:
#       recording_date project                    cell_specimen_name  \
# 3894  9/1/2017 17:36   T301x  Htr3a-Cre_NO152;Ai14-343221.05.02.01
# 3895  9/1/2017 17:46   T301x  Htr3a-Cre_NO152;Ai14-343221.05.01.01
# 3896  9/1/2017 17:56   T301x  Htr3a-Cre_NO152;Ai14-343221.05.02.02
# 3897  9/1/2017 18:16   T301x  Htr3a-Cre_NO152;Ai14-343221.05.01.02
# 3899  9/1/2017 20:09   T301x   Scnn1a-Tg3-Cre;Ai14-346622.05.02.01
#
#      ims63x_go_no_go  ephys_seal_gohm
# 3894       63x no go         2.461183
# 3895          63x go         2.897146
# 3896       63x no go         1.669511
# 3897          63x go         0.952281
# 3899       63x no go         3.079292

# %%
df1.tail(30)
# Out:
#        recording_date     project                     cell_specimen_name  \
# 5429  2/16/2018 19:22       T301x      Cux2-CreERT2;Ai14-375868.06.02.02
# 5430  2/16/2018 19:24       T301x    Rbp4-Cre_KL100;Ai14-374885.07.02.04
# 5432  2/16/2018 21:57       T301x      Cux2-CreERT2;Ai14-375864.06.02.02
# 5433  2/16/2018 22:24       T301x      Cux2-CreERT2;Ai14-375864.06.02.03
# 5863              NaN       T301x     Gad2-IRES-Cre;Ai14-350671.06.02.01
# 5865              NaN       T301x   Htr3a-Cre_NO152;Ai14-349020.03.02.01
# 5866              NaN       T301x   Htr3a-Cre_NO152;Ai14-349020.03.02.02
# 5867              NaN       T301x   Htr3a-Cre_NO152;Ai14-349020.03.02.03
# 5868              NaN       T301x   Htr3a-Cre_NO152;Ai14-349020.03.02.04
# 5874              NaN  mIVSCC-MET    Nkx2-1-CreERT2;Ai14-357183.04.01.01
# 5879              NaN  mIVSCC-MET   Ntsr1-Cre_GN220;Ai14-361815.03.01.01
# 5881              NaN  mIVSCC-MET   Ntsr1-Cre_GN220;Ai14-361815.04.02.01
# ...

# %% [markdown]
# ### Tried simple plot with only 63x csv

# %%
sns.countplot(x = 'project',
              hue = 'ims63x_go_no_go', 
              data = df1, 
              palette = "Set1")
#.set_title("Title")
#plt.xlabel("X")
#plt.ylabel("Y")
