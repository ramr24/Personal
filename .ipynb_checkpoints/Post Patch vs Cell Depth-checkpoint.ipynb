# %% [markdown]
# ## Analysis Project: Post Patch vs Cell Depth

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from scipy import stats
import math
import seaborn as sns
# %matplotlib inline

# %%
ps = pd.read_csv("patch_seq_log_mouse.csv")

# %%
select = ["Date", "Depth (um)", "Post patch?", "Nucleus sucked in?", "Post patch pipette R", "PCR cycles", "SM_QC_PF", "Bad dates"]
ps = ps[select]

#Changing Date Format
ps["Date"] = pd.to_datetime(ps["Date"], format = "%y%m%d")
#Categories
ps["Post patch?"].astype("category")
ps["Nucleus sucked in?"].astype("category")
ps["SM_QC_PF"] = ps["SM_QC_PF"].astype("category")
#Filtering Columns
ps = ps[ps["PCR cycles"] == 21]
ps = ps[ps["SM_QC_PF"] != "cnt"] 
ps = ps[ps["Bad dates"] != "x"]

#ps.dropna(subset = ["Post patch?", "Nucleus sucked in?"], returns start date 10/02/17 and data after that date
ps.dropna(subset = ["Post patch?", "SM_QC_PF"])
# Out:
#            Date Depth (um)      Post patch? Nucleus sucked in?  \
# 4968 2017-04-19       56.3      Outside-Out                NaN
# 4969 2017-04-19       28.5      Outside-Out                NaN
# 4970 2017-04-19       53.8          No-Seal                NaN
# 4971 2017-04-19       24.5        Nucleated                NaN
# 4972 2017-04-19       40.7      Outside-Out                NaN
# 4973 2017-04-19       17.6        Nucleated                NaN
# 4974 2017-04-19       19.3          No-Seal                NaN
# 4975 2017-04-19       40.2        Nucleated                NaN
# 4978 2017-04-19         38          No-Seal                NaN
# 4979 2017-04-19         45          No-Seal                NaN
# 4980 2017-04-19         31          No-Seal                NaN
# 4981 2017-04-19        NaN          No-Seal                NaN
# 4988 2017-04-20       56.2        Nucleated                NaN
# 4989 2017-04-20       44.9          No-Seal                NaN
# 4990 2017-04-20       53.1          No-Seal                NaN
# 4991 2017-04-20       42.1          No-Seal                NaN
# 4992 2017-04-20       37.1          No-Seal                NaN
# 4993 2017-04-20       60.5          No-Seal                NaN
# 4994 2017-04-20       54.7          No-Seal                NaN
# 4995 2017-04-20       39.4          No-Seal                NaN
# 4996 2017-04-20       38.9  Partial-Nucleus                NaN
# 4997 2017-04-20       55.4        Nucleated                NaN
# 5000 2017-04-20       27.5          No-Seal                NaN
# 5001 2017-04-20       20.2      Outside-Out                NaN
# 5002 2017-04-20       39.5      Entire-Cell                NaN
# 5003 2017-04-20       40.1          No-Seal                NaN
# 5004 2017-04-20       32.5          No-Seal                NaN
# 5005 2017-04-20       62.5          No-Seal                NaN
# 5006 2017-04-20       28.3          No-Seal                NaN
# 5007 2017-04-20       37.4          No-Seal                NaN
# ...         ...        ...              ...                ...
# 7567 2017-10-16        NaN   nucleus_absent                 no
# 7568 2017-10-16        NaN  nucleus_present  not_intentionally
# 7569 2017-10-16        NaN  nucleus_present  not_intentionally
# 7570 2017-10-16        NaN   nucleus_absent                 no
# 7571 2017-10-16        NaN  nucleus_present  not_intentionally
# 7572 2017-10-16        NaN  nucleus_present                 no
# 7573 2017-10-16        NaN  nucleus_present                 no
# 7574 2017-10-16        NaN  nucleus_present                 no
# 7575 2017-10-16        NaN  nucleus_present                 no
# 7576 2017-10-16        NaN  nucleus_present                 no
# 7577 2017-10-16        NaN  nucleus_present                 no
# 7578 2017-10-17        NaN   nucleus_absent                 no
# 7579 2017-10-17        NaN   nucleus_absent                 no
# 7580 2017-10-17        NaN  nucleus_present                 no
# 7581 2017-10-17        NaN   nucleus_absent                 no
# 7582 2017-10-17        NaN  nucleus_present                 no
# 7583 2017-10-17        NaN   nucleus_absent                 no
# 7584 2017-10-18        NaN  nucleus_present  not_intentionally
# 7585 2017-10-18        NaN   nucleus_absent                 no
# 7586 2017-10-18        NaN  nucleus_present                 no
# 7587 2017-10-18        NaN      entire_cell                 no
# 7588 2017-10-18        NaN      entire_cell                 no
# 7589 2017-10-18        NaN   nucleus_absent                 no
# 7590 2017-10-18        NaN   nucleus_absent                 no
# 7591 2017-10-18        NaN   nucleus_absent                 no
# 7592 2017-10-18        NaN  nucleus_present      intentionally
# 7593 2017-10-18        NaN  nucleus_present  not_intentionally
# 7594 2017-10-18        NaN   nucleus_absent                 no
# 7595 2017-10-18        NaN  nucleus_present      intentionally
# 7596 2017-10-18        NaN  nucleus_present                 no
#
#       Post patch pipette R  PCR cycles SM_QC_PF Bad dates
# 4968                   NaN        21.0     fail       NaN
# 4969                   NaN        21.0     pass       NaN
# 4970                   NaN        21.0     fail       NaN
# 4971                   NaN        21.0     pass       NaN
# 4972                   NaN        21.0     pass       NaN
# 4973                   NaN        21.0     pass       NaN
# 4974                   NaN        21.0     pass       NaN
# 4975                   NaN        21.0     pass       NaN
# 4978                   NaN        21.0     fail       NaN
# 4979                   NaN        21.0     pass       NaN
# 4980                   NaN        21.0     pass       NaN
# 4981                   NaN        21.0     pass       NaN
# 4988                   NaN        21.0     pass       NaN
# 4989                   NaN        21.0     pass       NaN
# 4990                   NaN        21.0     pass       NaN
# 4991                   NaN        21.0     pass       NaN
# 4992                   NaN        21.0     pass       NaN
# 4993                   NaN        21.0     pass       NaN
# 4994                   NaN        21.0     pass       NaN
# 4995                   NaN        21.0     pass       NaN
# 4996                   NaN        21.0     pass       NaN
# 4997                   NaN        21.0     pass       NaN
# 5000                   NaN        21.0     pass       NaN
# 5001                   NaN        21.0     pass       NaN
# 5002                   NaN        21.0     pass       NaN
# 5003                   NaN        21.0     pass       NaN
# 5004                   NaN        21.0     pass       NaN
# 5005                   NaN        21.0     pass       NaN
# 5006                   NaN        21.0     pass       NaN
# 5007                   NaN        21.0     pass       NaN
# ...                    ...         ...      ...       ...
# 7567                 300.0        21.0     fail       NaN
# 7568                   3.0        21.0     fail       NaN
# 7569                   3.6        21.0     pass       NaN
# 7570                   3.5        21.0     fail       NaN
# 7571                   6.0        21.0     pass       NaN
# 7572                1000.0        21.0     fail       NaN
# 7573                2000.0        21.0     pass       NaN
# 7574                2000.0        21.0     pass       NaN
# 7575                2000.0        21.0     pass       NaN
# 7576                2000.0        21.0     pass       NaN
# 7577                1000.0        21.0     pass       NaN
# 7578                  10.0        21.0     fail       NaN
# 7579                  15.0        21.0     pass       NaN
# 7580                1500.0        21.0     pass       NaN
# 7581                  50.0        21.0     fail       NaN
# 7582                1000.0        21.0     pass       NaN
# 7583                  10.0        21.0     pass       NaN
# 7584                  10.0        21.0     fail       NaN
# 7585                   4.0        21.0     fail       NaN
# 7586                1000.0        21.0     pass       NaN
# 7587                   7.0        21.0     fail       NaN
# 7588                  10.0        21.0     pass       NaN
# 7589                  10.0        21.0     fail       NaN
# 7590                  10.0        21.0     pass       NaN
# 7591                   5.0        21.0     fail       NaN
# 7592                 100.0        21.0     fail       NaN
# 7593                  20.0        21.0     pass       NaN
# 7594                  10.0        21.0     pass       NaN
# 7595                1000.0        21.0     pass       NaN
# 7596                1000.0        21.0     pass       NaN
#
# [1861 rows x 8 columns]

# %% [markdown]
# ## Misc

# %% [markdown]
# ps["Post patch?"].value_counts()
# ps["Nucleus sucked in?"].value_counts()
# ps.dtypes
# ps.info()

# %% [markdown]
# All categories for post patch...up till 10/02/2017
# All categories for nucleus sucked in?... starts at 10/02/2017
# For post patch pipette R and nucleus sucked in?... starts at 10/02/2017
#
# depth = numerical
# post patch? = categorical
# post patch pipette R = numerical
# nucleus sucked in? = categorical
