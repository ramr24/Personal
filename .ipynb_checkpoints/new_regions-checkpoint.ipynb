# %%
import pandas as pd
import seaborn as sns
import logging

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
sns.set(context = "notebook", style = "ticks", font="verdana", font_scale = 1.35)
pd.set_option("display.max_colwidth",150) #Expands the number of characters shown in the columns
pd.set_option('display.max_columns', None)

# %%
def read_all_csv(fields=None):
    global json
    csv_path = "C:/Users/ramr/Documents/Github/analysis_projects/csv/"
    csv_file = "jem_metadata.csv"
    json = pd.read_csv(csv_path + csv_file, usecols=fields)
    logger.info("Read jem metadata csv (date: 1/08/2020)")

# %% [markdown]
# ##### Column Fields

# %%
json_fields=["date", "organism_name", "name", "cell_depth", "approach.creCell", "container"]

# %%
read_all_csv()
# Out:
# INFO:__main__:Read jem metadata csv (date: 1/08/2020)

# %% [markdown]
# ##### Output csv

# %%
json
# Out:
#       organism_name                                                      name  \
# 0             Mouse                         Oxtr-T2A-Cre;Ai14-351467.03.01.01
# 1             Mouse                         Oxtr-T2A-Cre;Ai14-351467.05.02.02
# 2             Mouse                         Oxtr-T2A-Cre;Ai14-351467.05.02.01
# 3             Mouse                         Oxtr-T2A-Cre;Ai14-351467.05.02.03
# 4             Mouse           Nos1-CreERT2;Sst-IRES-FlpO;Ai65-350934.04.01.02
# ...             ...                                                       ...
# 11991         Mouse  Sst-IRES-Cre;Pvalb-T2A-FlpO;Ai193-hyg-490656.08.06.01.01
# 11992         Human                                 H19.06.363.11.05.01.01.01
# 11993         Human                                       H18.29.127.11.31.01
# 11994         Mouse   Vip-IRES-Cre;Sst-IRES-FlpO;Ai193-hyg-502011.08.06.01.08
# 11995         Mouse                                         GT_Lab_Test.01.02
#
# ...

# %%
json
# Out:
#       organism_name                                                      name  \
# 0             Mouse                         Oxtr-T2A-Cre;Ai14-351467.03.01.01
# 1             Mouse                         Oxtr-T2A-Cre;Ai14-351467.05.02.02
# 2             Mouse                         Oxtr-T2A-Cre;Ai14-351467.05.02.01
# 3             Mouse                         Oxtr-T2A-Cre;Ai14-351467.05.02.03
# 4             Mouse           Nos1-CreERT2;Sst-IRES-FlpO;Ai65-350934.04.01.02
# ...             ...                                                       ...
# 11991         Mouse  Sst-IRES-Cre;Pvalb-T2A-FlpO;Ai193-hyg-490656.08.06.01.01
# 11992         Human                                 H19.06.363.11.05.01.01.01
# 11993         Human                                       H18.29.127.11.31.01
# 11994         Mouse   Vip-IRES-Cre;Sst-IRES-FlpO;Ai193-hyg-502011.08.06.01.08
# 11995         Mouse                                         GT_Lab_Test.01.02
#
# ...
