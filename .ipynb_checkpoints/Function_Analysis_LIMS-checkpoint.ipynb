# %% [markdown]
# # Report on the number of slices used per mouse(Only in LIMS)

# %%
import pg8000 #Access SQL database
import pandas as pd
import jem_funcs #Agata's python script

# %% [markdown]
# ### Project Query

# %%
pd.options.display.max_columns = None

# %%
lims_query_str = "SELECT * FROM projects"
proj = pd.DataFrame(jem_funcs.limsquery(lims_query_str))

# %%
proj.head()
# Out:
#                       code                 created_at  current_directory  \
# 0  DeepscopeSLMDevelopment 2017-06-29 16:56:30.337080                  0
# 1                     0343 2008-01-22 18:38:21.911294                 23
# 2             MVISp-tax1.0 2015-08-28 18:45:37.031549                  0
# 3                     0371 2009-06-18 10:09:17.183892                  0
# 4                     0325 2009-03-26 14:46:25.010494                  2
#
#                                   failed_trigger_dir  \
# 0  /allen/programs/braintv/production/incoming/ne...
# 1      /projects/incoming/spinalcord/failed_trigger/
# 2  /allen/programs/celltypes/production/incoming/...
# 3                                         /dev/null/
# 4  /allen/programs/celltypes/production/incoming/...
#
#                                         file_storage         id  \
# 0   /allen/programs/braintv/production/neuralcoding/  599330204
# 1                         /projects/spinalcord/vol1/   79534207
# 2  /allen/programs/celltypes/production/mousecell...  485954191
# 3                                        /data/0371/         14
# 4      /allen/programs/celltypes/production/general/         10
#
#   incoming_directory                                               name  \
# 0               None                  BrainTV Deepscope SLM development
# 1               None                        Puchalski Mouse Spinal Cord
# 2               None  Mouse VISp cellular taxonomy by single cell tr...
# 3               None                                    Mini Projectome
# 4               None                         0325 Microarray Validation
#
#   non_cached_schema_name  process_triggers  subdirectory_count  \
# 0                   None              True                  12
# 1            spinal_cord             False                 909
# 2                   None              True                   0
# 3                   None             False                   0
# 4                   None             False                   0
#
#                                          trigger_dir  \
# 0  /allen/programs/braintv/production/incoming/ne...
# 1             /projects/incoming/spinalcord/trigger/
# 2  /allen/programs/celltypes/production/incoming/...
# 3                                         /dev/null/
# 4  /allen/programs/celltypes/production/incoming/...
#
#                   updated_at
# 0 2018-05-02 18:50:37.856392
# 1 2012-11-02 18:46:01.480485
# 2 2017-05-22 21:59:13.775750
# 3 2011-01-14 03:49:16.235667
# 4 2017-09-21 20:43:37.524090

# %% [markdown]
# ### Sample Query

# %%
lims_query_str = "SELECT * FROM specimens"
sample = pd.DataFrame(jem_funcs.limsquery(lims_query_str))

# %%
sample.tail()
# Out:
#         alignment3d_id     barcode biophysical_model_state carousel_well_name  \
# 458131             NaN  0670343682         review_required               None
# 458132             NaN  0669864819         review_required               None
# 458133             NaN  0669865467         review_required               None
# 458134             NaN  0670340941         review_required               None
# 458135             NaN  0670184306         review_required   MET_180306_03_12
#
#         cell_depth cell_label  cell_prep_id  cell_reporter_id  \
# 458131        71.4       None           NaN               NaN
# 458132         NaN       None           NaN               NaN
# 458133         NaN       None           NaN               NaN
# 458134        65.2       None           NaN       491913822.0
# 458135         NaN       None           NaN               NaN
#
#         cortex_layer_id                 created_at created_by  data  \
# 458131              NaN 2018-03-07 00:40:37.808746       None  None
# 458132              NaN 2018-03-06 11:16:12.018033       None  None
# 458133              NaN 2018-03-06 11:20:49.144852       None  None
# 458134              NaN 2018-03-07 00:15:35.404405       None  None
# 458135              NaN 2018-03-06 20:30:23.011481       None  None
#
#          donor_id  ephys_cell_plan_id  ephys_neural_tissue_plan_id  \
# 458131  668456824         497008862.0                  668457000.0
# 458132  667489947                 NaN                          NaN
# 458133  667489947                 NaN                          NaN
# 458134  668456846         497008862.0                  668457030.0
# 458135  668456846                 NaN                  668457030.0
#
#        ephys_qc_result  ephys_roi_result_id ephys_start_time_sec  \
# 458131            None          670343615.0                 None
# 458132            None          669864814.0                 None
# 458133            None          669865423.0                 None
# 458134            None          670340851.0                 None
# 458135            None                  NaN                 None
#
#        external_specimen_name  facs_well_id  flipped_specimen_id frozen_at  \
# 458131                   None           NaN            561557765      None
# 458132                   None           NaN            561557765      None
# 458133                   None           NaN            561557765      None
# 458134                   None           NaN            561557765      None
# 458135                   None           NaN            561557767      None
#
#         hemisphere_id    histology_well_name         id  location_id  \
# 458131            NaN                   None  670343682          NaN
# 458132            NaN                   None  669864819          NaN
# 458133            NaN                   None  669865467          NaN
# 458134            NaN                   None  670340941          NaN
# 458135            NaN  EPhys_180305_02_A01_M  670184306          NaN
#
#                                                    name  \
# 458131              Pvalb-IRES-Cre;Ai14-378390.04.02.01
# 458132                   Nr5a1-Cre;Ai14-378059.10.06.01
# 458133                   Nr5a1-Cre;Ai14-378059.11.06.01
# 458134  Nos1-CreERT2;Sst-IRES-FlpO;Ai65-377372.06.02.01
# 458135     Nos1-CreERT2;Sst-IRES-FlpO;Ai65-377372.06.02
#
#         normalization_group_id operation_id    parent_id  parent_x_coord  \
# 458131                     NaN         None  670160877.0             0.0
# 458132                     NaN         None  669360887.0             0.0
# 458133                     NaN         None  669362043.0             0.0
# 458134                     NaN         None  670184306.0             0.0
# 458135                     NaN         None  670153709.0             2.0
#
#         parent_y_coord  parent_z_coord patched_cell_container  pinned_radius  \
# 458131             0.0             1.0    PBS4_180306_502_A01            NaN
# 458132             0.0             1.0                   None            NaN
# 458133             0.0             1.0                   None            NaN
# 458134             0.0             1.0    P8S4_180306_356_A01            NaN
# 458135             0.0             0.0                   None            NaN
#
#         plane_of_section_id  postmortem_interval_id  preparation_method_id  \
# 458131                   11                     NaN                    NaN
# 458132                    2                     NaN                    NaN
# 458133                    2                     NaN                    NaN
# 458134                   11                     NaN                    NaN
# 458135                   11                     NaN                    NaN
#
#         priority  project_id  reference_space_id  rna_integrity_number  \
# 458131       NaN   636998207                 NaN                   NaN
# 458132       NaN   639457164                 NaN                   NaN
# 458133       NaN   639457164                 NaN                   NaN
# 458134       NaN   636998207                 NaN                   NaN
# 458135       NaN   636998207                 NaN                   NaN
#
#         specimen_preparation_method_id  specimen_set_id  starter_cell_count  \
# 458131                             NaN              NaN                 NaN
# 458132                             NaN              NaN                 NaN
# 458133                             NaN              NaN                 NaN
# 458134                             NaN              NaN                 NaN
# 458135                             NaN      672503430.0                 NaN
#
#                                         storage_directory  structure_id  \
# 458131                                               None         385.0
# 458132                                               None           NaN
# 458133                                               None           NaN
# 458134  /allen/programs/celltypes/production/mousecell...         385.0
# 458135  /allen/programs/celltypes/production/mousecell...           NaN
#
#        task_flow_id  tissue_ph  tissue_processing_id  \
# 458131         None        NaN           668456995.0
# 458132         None        NaN                   NaN
# 458133         None        NaN                   NaN
# 458134         None        NaN           668457025.0
# 458135         None        NaN           668457025.0
#
#                        updated_at updated_by x_coord y_coord
# 458131 2018-03-07 01:17:46.483882       None    None    None
# 458132 2018-03-07 11:24:49.314160       None    None    None
# 458133 2018-03-07 11:24:49.760271       None    None    None
# 458134 2018-05-02 18:07:13.669737       None    None    None
# 458135 2018-03-13 19:01:53.906088       None    None    None

# %% [markdown]
# ## Function slice_per_mouse

# %% [markdown]
# def slice_per_mouse(recording_date):
#     """Reports the number of slices used per mouse that have histology well names in LIMS."""
#
#     recording_date = 'YYMMDD'
#     recording_date_query = "%" + recording_date + "%"
#
#     my_query = "SELECT s.name, s.histology_well_name, s.patched_cell_container \
#     FROM specimens s \
#     JOIN projects proj ON s.project_id = proj.id \
#     WHERE proj.code = 'mIVSCC-MET'"
#     AND histology_well_name IS NOT NULL"
#     AND histology_well_name LIKE '%s'" %recording_date_query
#
#     #%s lets you insert and format a string
#     #IS NOT NULL = displays everything except blanks, NONE, N/A

# %%
lims_query_str="SELECT s.name, s.histology_well_name \
FROM specimens s JOIN projects proj ON s.project_id = proj.id \
WHERE proj.code = 'mIVSCC-MET'\
AND histology_well_name IS NOT NULL \
AND histology_well_name LIKE '%hys_180423%'"

df = pd.DataFrame(jem_funcs.limsquery(lims_query_str))

# %%
df
# Out:
#       histology_well_name                                               name
# 0   EPhys_180423_03_B03_M                Chat-IRES-Cre-neo;Ai14-386649.04.02
# 1   EPhys_180423_01_A01_M                     Sst-IRES-Cre;Ai14-386474.03.01
# 2   EPhys_180423_01_A02_M                     Sst-IRES-Cre;Ai14-386474.05.02
# 3   EPhys_180423_01_A03_M                     Sst-IRES-Cre;Ai14-386474.04.02
# 4   EPhys_180423_01_A04_M                     Sst-IRES-Cre;Ai14-386474.05.01
# 5   EPhys_180423_01_A05_M  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-38574...
# 6   EPhys_180423_01_A06_M                     Th-P2A-FlpO;Ai65F-385997.04.01
# 7   EPhys_180423_01_B01_M                     Sst-IRES-Cre;Ai14-386474.03.02
# 8   EPhys_180423_01_B02_M  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-38574...
# 9   EPhys_180423_01_B03_M                     Th-P2A-FlpO;Ai65F-385997.05.01
# 10  EPhys_180423_01_B04_M  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-38574...
# 11  EPhys_180423_01_B05_M                   Pvalb-IRES-Cre;Ai14-384390.04.02
# 12  EPhys_180423_01_B06_M                   Pvalb-IRES-Cre;Ai14-384390.03.01
# 13  EPhys_180423_01_C01_M                     Sst-IRES-Cre;Ai14-386476.04.02
# 14  EPhys_180423_01_C02_M                     Sst-IRES-Cre;Ai14-386476.05.01
# 15  EPhys_180423_01_C03_M                     Sst-IRES-Cre;Ai14-386476.04.01
# 16  EPhys_180423_01_C04_M                     Sst-IRES-Cre;Ai14-386476.03.01
# 17  EPhys_180423_01_C05_M                     Nos1-CreERT2;Ai14-386167.04.02
# 18  EPhys_180423_01_C06_M                     Th-P2A-FlpO;Ai65F-385998.03.01
# 19  EPhys_180423_01_D01_M                     Th-P2A-FlpO;Ai65F-385998.04.02
# 20  EPhys_180423_01_D02_M  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-38574...
# 21  Ephys_180423_01_D03_M                     Th-P2A-FlpO;Ai65F-385998.02.02
# 22  EPhys_180423_01_D04_M                     Nos1-CreERT2;Ai14-386167.04.01
# 23  EPhys_180423_01_D05_M                     Sst-IRES-Cre;Ai14-386478.05.02
# 24  EPhys_180423_01_D06_M                     Sst-IRES-Cre;Ai14-386478.05.01
# 25  EPhys_180423_03_A01_M                     Sst-IRES-Cre;Ai14-386478.03.02
# 26  EPhys_180423_03_A02_M                   Pvalb-IRES-Cre;Ai14-384391.04.02
# 27  EPhys_180423_03_A03_M                     Th-P2A-FlpO;Ai65F-385999.04.02
# 28  EPhys_180423_03_A04_M                     Nos1-CreERT2;Ai14-386169.04.01
# 29  EPhys_180423_03_A05_M                     Nos1-CreERT2;Ai14-386169.04.02
# 30  EPhys_180423_03_A06_M                     Th-P2A-FlpO;Ai65F-385999.03.02
# 31  EPhys_180423_03_B01_M                     Th-P2A-FlpO;Ai65F-385999.04.01
# 32  EPhys_180423_03_B02_M                     Nos1-CreERT2;Ai14-386169.03.01
# 33  EPhys_180423_03_B04_M                Chat-IRES-Cre-neo;Ai14-386651.04.02
# 34  EPhys_180423_03_B05_M                Chat-IRES-Cre-neo;Ai14-386651.03.01
# 35  EPhys_180423_03_B06_M                Chat-IRES-Cre-neo;Ai14-386651.05.02
# 36  EPhys_180423_03_C01_M                Chat-IRES-Cre-neo;Ai14-386651.05.01
# 37  Ephys_180423_03_C02_M                Chat-IRES-Cre-neo;Ai14-386651.04.01
# 38  EPhys_180423_03_C03_M                    Gad2-IRES-Cre;Ai14-386058.02.01
# 39  EPhys_180423_03_C04_M                    Gad2-IRES-Cre;Ai14-386058.04.02
# 40  EPhys_180423_03_C05_M                    Gad2-IRES-Cre;Ai14-386058.03.02
# 41  EPhys_180423_03_C06_M                    Gad2-IRES-Cre;Ai14-386058.03.01
# 42  EPhys_180423_03_D01_M                    Gad2-IRES-Cre;Ai14-386058.04.01

# %%
#recording_date = 'YYMMDD'

lims_query_str = "SELECT name, histology_well_name \
FROM specimens \
WHERE histology_well_name IS NOT NULL \
AND histology_well_name LIKE '%hys_180423%'"#

#Need to only output mIVSCC-MET

slices = pd.DataFrame(jem_funcs.limsquery(lims_query_str))
slices['name'] = slices['name'].str[:-6] #Slicing to use common name for counts

# %%
slices
# Out:
#       histology_well_name                                             name
# 0   EPhys_180423_03_B03_M                    Chat-IRES-Cre-neo;Ai14-386649
# 1   EPhys_180423_01_A01_M                         Sst-IRES-Cre;Ai14-386474
# 2   EPhys_180423_01_A02_M                         Sst-IRES-Cre;Ai14-386474
# 3   EPhys_180423_01_A03_M                         Sst-IRES-Cre;Ai14-386474
# 4   EPhys_180423_01_A04_M                         Sst-IRES-Cre;Ai14-386474
# 5   EPhys_180423_01_A05_M  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-385740
# 6   EPhys_180423_01_A06_M                         Th-P2A-FlpO;Ai65F-385997
# 7   EPhys_180423_01_B01_M                         Sst-IRES-Cre;Ai14-386474
# 8   EPhys_180423_01_B02_M  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-385740
# 9   EPhys_180423_01_B03_M                         Th-P2A-FlpO;Ai65F-385997
# 10  EPhys_180423_01_B04_M  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-385740
# 11  EPhys_180423_01_B05_M                       Pvalb-IRES-Cre;Ai14-384390
# 12  EPhys_180423_01_B06_M                       Pvalb-IRES-Cre;Ai14-384390
# 13  EPhys_180423_01_C01_M                         Sst-IRES-Cre;Ai14-386476
# 14  EPhys_180423_01_C02_M                         Sst-IRES-Cre;Ai14-386476
# 15  EPhys_180423_01_C03_M                         Sst-IRES-Cre;Ai14-386476
# 16  EPhys_180423_01_C04_M                         Sst-IRES-Cre;Ai14-386476
# 17  EPhys_180423_01_C05_M                         Nos1-CreERT2;Ai14-386167
# 18  EPhys_180423_01_C06_M                         Th-P2A-FlpO;Ai65F-385998
# 19  EPhys_180423_01_D01_M                         Th-P2A-FlpO;Ai65F-385998
# 20  EPhys_180423_01_D02_M  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-385743
# 21  Ephys_180423_01_D03_M                         Th-P2A-FlpO;Ai65F-385998
# 22  EPhys_180423_01_D04_M                         Nos1-CreERT2;Ai14-386167
# 23  EPhys_180423_01_D05_M                         Sst-IRES-Cre;Ai14-386478
# 24  EPhys_180423_01_D06_M                         Sst-IRES-Cre;Ai14-386478
# 25  EPhys_180423_02_A01_H                                       H18.03.009
# 26  EPhys_180423_02_A02_H                                       H18.03.009
# 27  EPhys_180423_02_A03_H                                       H18.03.009
# 28  EPhys_180423_02_A04_H                                       H18.03.009
# 29  EPhys_180423_03_A01_M                         Sst-IRES-Cre;Ai14-386478
# 30  EPhys_180423_03_A02_M                       Pvalb-IRES-Cre;Ai14-384391
# 31  EPhys_180423_03_A03_M                         Th-P2A-FlpO;Ai65F-385999
# 32  EPhys_180423_03_A04_M                         Nos1-CreERT2;Ai14-386169
# 33  EPhys_180423_03_A05_M                         Nos1-CreERT2;Ai14-386169
# 34  EPhys_180423_03_A06_M                         Th-P2A-FlpO;Ai65F-385999
# 35  EPhys_180423_03_B01_M                         Th-P2A-FlpO;Ai65F-385999
# 36  EPhys_180423_03_B02_M                         Nos1-CreERT2;Ai14-386169
# 37  EPhys_180423_03_B04_M                    Chat-IRES-Cre-neo;Ai14-386651
# 38  EPhys_180423_03_B05_M                    Chat-IRES-Cre-neo;Ai14-386651
# 39  EPhys_180423_03_B06_M                    Chat-IRES-Cre-neo;Ai14-386651
# 40  EPhys_180423_03_C01_M                    Chat-IRES-Cre-neo;Ai14-386651
# 41  Ephys_180423_03_C02_M                    Chat-IRES-Cre-neo;Ai14-386651
# 42  EPhys_180423_03_C03_M                        Gad2-IRES-Cre;Ai14-386058
# 43  EPhys_180423_03_C04_M                        Gad2-IRES-Cre;Ai14-386058
# 44  EPhys_180423_03_C05_M                        Gad2-IRES-Cre;Ai14-386058
# 45  EPhys_180423_03_C06_M                        Gad2-IRES-Cre;Ai14-386058
# 46  EPhys_180423_03_D01_M                        Gad2-IRES-Cre;Ai14-386058

# %%
slices['counts'] = slices.groupby('name')['name'].transform('count')

# %%
slices
# Out:
#       histology_well_name                                             name  \
# 0   EPhys_180423_03_B03_M                    Chat-IRES-Cre-neo;Ai14-386649
# 1   EPhys_180423_01_A01_M                         Sst-IRES-Cre;Ai14-386474
# 2   EPhys_180423_01_A02_M                         Sst-IRES-Cre;Ai14-386474
# 3   EPhys_180423_01_A03_M                         Sst-IRES-Cre;Ai14-386474
# 4   EPhys_180423_01_A04_M                         Sst-IRES-Cre;Ai14-386474
# 5   EPhys_180423_01_A05_M  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-385740
# 6   EPhys_180423_01_A06_M                         Th-P2A-FlpO;Ai65F-385997
# 7   EPhys_180423_01_B01_M                         Sst-IRES-Cre;Ai14-386474
# 8   EPhys_180423_01_B02_M  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-385740
# 9   EPhys_180423_01_B03_M                         Th-P2A-FlpO;Ai65F-385997
# 10  EPhys_180423_01_B04_M  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-385740
# 11  EPhys_180423_01_B05_M                       Pvalb-IRES-Cre;Ai14-384390
# 12  EPhys_180423_01_B06_M                       Pvalb-IRES-Cre;Ai14-384390
# 13  EPhys_180423_01_C01_M                         Sst-IRES-Cre;Ai14-386476
# 14  EPhys_180423_01_C02_M                         Sst-IRES-Cre;Ai14-386476
# 15  EPhys_180423_01_C03_M                         Sst-IRES-Cre;Ai14-386476
# 16  EPhys_180423_01_C04_M                         Sst-IRES-Cre;Ai14-386476
# 17  EPhys_180423_01_C05_M                         Nos1-CreERT2;Ai14-386167
# 18  EPhys_180423_01_C06_M                         Th-P2A-FlpO;Ai65F-385998
# 19  EPhys_180423_01_D01_M                         Th-P2A-FlpO;Ai65F-385998
# 20  EPhys_180423_01_D02_M  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-385743
# 21  Ephys_180423_01_D03_M                         Th-P2A-FlpO;Ai65F-385998
# 22  EPhys_180423_01_D04_M                         Nos1-CreERT2;Ai14-386167
# 23  EPhys_180423_01_D05_M                         Sst-IRES-Cre;Ai14-386478
# 24  EPhys_180423_01_D06_M                         Sst-IRES-Cre;Ai14-386478
# 25  EPhys_180423_02_A01_H                                       H18.03.009
# 26  EPhys_180423_02_A02_H                                       H18.03.009
# 27  EPhys_180423_02_A03_H                                       H18.03.009
# 28  EPhys_180423_02_A04_H                                       H18.03.009
# 29  EPhys_180423_03_A01_M                         Sst-IRES-Cre;Ai14-386478
# 30  EPhys_180423_03_A02_M                       Pvalb-IRES-Cre;Ai14-384391
# 31  EPhys_180423_03_A03_M                         Th-P2A-FlpO;Ai65F-385999
# 32  EPhys_180423_03_A04_M                         Nos1-CreERT2;Ai14-386169
# 33  EPhys_180423_03_A05_M                         Nos1-CreERT2;Ai14-386169
# 34  EPhys_180423_03_A06_M                         Th-P2A-FlpO;Ai65F-385999
# 35  EPhys_180423_03_B01_M                         Th-P2A-FlpO;Ai65F-385999
# 36  EPhys_180423_03_B02_M                         Nos1-CreERT2;Ai14-386169
# 37  EPhys_180423_03_B04_M                    Chat-IRES-Cre-neo;Ai14-386651
# 38  EPhys_180423_03_B05_M                    Chat-IRES-Cre-neo;Ai14-386651
# 39  EPhys_180423_03_B06_M                    Chat-IRES-Cre-neo;Ai14-386651
# 40  EPhys_180423_03_C01_M                    Chat-IRES-Cre-neo;Ai14-386651
# 41  Ephys_180423_03_C02_M                    Chat-IRES-Cre-neo;Ai14-386651
# 42  EPhys_180423_03_C03_M                        Gad2-IRES-Cre;Ai14-386058
# 43  EPhys_180423_03_C04_M                        Gad2-IRES-Cre;Ai14-386058
# 44  EPhys_180423_03_C05_M                        Gad2-IRES-Cre;Ai14-386058
# 45  EPhys_180423_03_C06_M                        Gad2-IRES-Cre;Ai14-386058
# 46  EPhys_180423_03_D01_M                        Gad2-IRES-Cre;Ai14-386058
#
#     counts
# 0        1
# 1        5
# 2        5
# 3        5
# 4        5
# 5        3
# 6        2
# 7        5
# 8        3
# 9        2
# 10       3
# 11       2
# 12       2
# 13       4
# 14       4
# 15       4
# 16       4
# 17       2
# 18       3
# 19       3
# 20       1
# 21       3
# 22       2
# 23       3
# 24       3
# 25       4
# 26       4
# 27       4
# 28       4
# 29       3
# 30       1
# 31       3
# 32       3
# 33       3
# 34       3
# 35       3
# 36       3
# 37       5
# 38       5
# 39       5
# 40       5
# 41       5
# 42       5
# 43       5
# 44       5
# 45       5
# 46       5

# %%
#Steps
#1) User types in specific date (displays for the day)
#OR user types in monday of the week (displays for the week)
#2) Outputs

# %%
#Usually 12 slices in each carousel 
#6 Left and 6 Right hemispheres
#Left Hemi = .01
#Right Hemi = .02
#Slice numbers = 1-6
